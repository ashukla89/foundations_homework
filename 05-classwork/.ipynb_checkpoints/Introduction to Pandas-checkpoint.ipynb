# %%
# !pip install pandas
# Out:
# ...
#     100% |████████████████████████████████| 15.9MB 2.1MB/s eta 0:00:01
# ...
#     100% |████████████████████████████████| 512kB 8.8MB/s eta 0:00:01
# ...
# You are using pip version 10.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install --upgrade pip
# Out:
# ...
#     100% |████████████████████████████████| 1.4MB 6.9MB/s eta 0:00:01
# ...
#   Found existing installation: pip 10.0.1
#     Uninstalling pip-10.0.1:
#       Successfully uninstalled pip-10.0.1
# ...

# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('countries.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(10)
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
# 5            Argentina  S. America           10571           73.822
# 6              Armenia      Europe            2114           71.494
# 7            Australia     Oceania           29241           79.930
# 8              Austria      Europe           32008           78.330
# 9           Azerbaijan      Europe            2533           66.851
#
#    Population
# 0    22856302
# 1     3071856
# 2    30533827
# 3    13926373
# 4       77656
# 5    36930709
# 6     3076098
# 7    19164351
# 8     8004712
# 9     8110723

# %%
df.tail(10)
# Out:
#                 Country   Continent  GDP_per_capita  life_expectancy  \
# 178       United States  N. America           39758           76.800
# 179             Uruguay  S. America            9092           74.777
# 180          Uzbekistan        Asia            1635           66.999
# 181             Vanuatu     Oceania            3762           67.438
# 182           Venezuela  S. America            9434           72.432
# 183             Vietnam        Asia            1577           73.777
# 184  West Bank and Gaza        Asia            7586           70.929
# 185         Yemen, Rep.        Asia            2217           60.404
# 186              Zambia      Africa            1035           41.802
# 187            Zimbabwe      Africa             745           43.976
#
#      Population
# 178   282496310
# 179     3319066
# 180    24775610
# 181      185074
# 182    24348304
# 183    78758010
# 184     3198560
# 185    17723186
# 186    10201562
# 187    12509477

# %% [markdown]
# ### How do you get types of your columns in a df?

# %%
df.dtypes
# Out:
# Country             object
# Continent           object
# GDP_per_capita       int64
# life_expectancy    float64
# Population           int64
# dtype: object

# %% [markdown]
# When you are in df world, strings are going to be called objects.

# %%
df.sort_values(by='GDP_per_capita',ascending=False)
# Out:
#                   Country   Continent  GDP_per_capita  life_expectancy  \
# 99             Luxembourg      Europe           63924        77.820000
# 135                 Qatar        Asia           60394        76.680000
# 23                 Brunei        Asia           48020        75.927000
# 125                Norway      Europe           43174        78.760000
# 178         United States  N. America           39758        76.800000
# 148             Singapore        Asia           36834        78.340000
# 90                 Kuwait        Asia           36397        73.133000
# 161           Switzerland      Europe           34386        79.990000
# 64              Greenland  N. America           33204        67.030000
# 120           Netherlands      Europe           33000        78.240000
# 29                 Canada  N. America           32448        79.410000
# 8                 Austria      Europe           32008        78.330000
# ...

# %% [markdown]
# How do you figure out what a function does?

# %%
# either this way
df.sort_values?

# %%
# or cursoer over it, shift + tab
df.sort_values

# %%
# top 5 countries by GDP per cap
df.sort_values(by='GDP_per_capita',ascending=False).head()
# Out:
#            Country   Continent  GDP_per_capita  life_expectancy  Population
# 99      Luxembourg      Europe           63924           77.820      435491
# 135          Qatar        Asia           60394           76.680      590957
# 23          Brunei        Asia           48020           75.927      327036
# 125         Norway      Europe           43174           78.760     4490859
# 178  United States  N. America           39758           76.800   282496310

# %%
# bottom 5 countries by pop
df.sort_values(by='Population').head()
# Out:
#                  Country   Continent  GDP_per_capita  life_expectancy  \
# 64             Greenland  N. America           33204           67.030
# 4    Antigua and Barbuda  N. America           12738           73.544
# 146           Seychelles      Africa           15230           71.771
# 87              Kiribati     Oceania            3501           64.642
# 169                Tonga     Oceania            4886           70.810
#
#      Population
# 64        56196
# 4         77656
# 146       78685
# 87        84010
# 169       97935

# %% [markdown]
# ### Numbery Things

# %%
# calculate highest GDP
df['GDP_per_capita'].max()
# Out:
# 63924

# %%
# calculate shortest life expectancy
df['life_expectancy'].min()
# Out:
# 38.12300000000001

# %%
df.life_expectancy.min()
# Out:
# 38.12300000000001

# %%
# median/ mean of life exp
print("Median:",df.life_expectancy.median())
print("Mean:",df.life_expectancy.mean())
# Out:
# Median: 70.04150000000001
# Mean: 66.50153603526596

# %% [markdown]
# ### Being lazy about numbers

# %%
df.life_expectancy.describe()
# Out:
# count    188.000000
# mean      66.501536
# std       10.298458
# min       38.123000
# 25%       59.663750
# 50%       70.041500
# 75%       74.134500
# max       81.350000
# Name: life_expectancy, dtype: float64

# %%
df.GDP_per_capita.describe()
# Out:
# pandas.core.series.Series

# %%
df.describe()
# Out:
#        GDP_per_capita  life_expectancy    Population
# count      188.000000       188.000000  1.880000e+02
# mean      9977.558511        66.501536  3.252682e+07
# std      11953.393378        10.298458  1.237952e+08
# min        292.000000        38.123000  5.619600e+04
# 25%       1732.500000        59.663750  2.003170e+06
# 50%       5290.500000        70.041500  6.888970e+06
# 75%      12701.250000        74.134500  2.218517e+07
# max      63924.000000        81.350000  1.269117e+09

# %% [markdown]
# ### Dataframe vs. Series
#
# * DataFrame - Multiple columns, beautiful
# * Series - Single column, very ugly

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.Continent.head())
# Out:
# pandas.core.series.Series

# %%
# the following will give you a description of only numerical data
# hence no Continent
df[['Population','Continent']].describe()
# Out:
#          Population
# count  1.880000e+02
# mean   3.252682e+07
# std    1.237952e+08
# min    5.619600e+04
# 25%    2.003170e+06
# 50%    6.888970e+06
# 75%    2.218517e+07
# max    1.269117e+09

# %%
# for counting, use .value_counts() I guess
df.Continent.value_counts()
# Out:
# Africa        54
# Asia          48
# Europe        42
# N. America    22
# S. America    12
# Oceania       10
# Name: Continent, dtype: int64

# %%
df.Population.sum()
# Out:
# 6115042358

# %%
import matplotlib.pyplot as plt

# %%
df.groupby(by='Continent')

# %%
# you
df.groupby('Continent').Population.median() \
    .sort_values(ascending=False)
# Out:
# Continent
# Asia          16855860.0
# S. America    13882421.5
# Africa         8160335.5
# Europe         6286376.5
# N. America     3437653.0
# Oceania         296903.0
# Name: Population, dtype: float64

# %%
df.pivot_table(index='Continent',values='Population',aggfunc='median').plot(kind='bar')

# %%
# Give me the three continents with the most people on them
# aka, dadd up the people on each continent, give me top three
df.groupby('Continent').Population.sum() \
    .sort_values(ascending=False).head(3)
# Out:
# Continent
# Asia      3849172861
# Africa     809892820
# Europe     596440013
# Name: Population, dtype: int64

# %%
# calculate total GDP per country
df['GDP'] = df['GDP_per_capita'] * df['Population']
df
# Out:
#                     Country   Continent  GDP_per_capita  life_expectancy  \
# 0               Afghanistan        Asia             663           54.863
# 1                   Albania      Europe            4195           74.200
# 2                   Algeria      Africa            5098           68.963
# 3                    Angola      Africa            2446           45.234
# 4       Antigua and Barbuda  N. America           12738           73.544
# 5                 Argentina  S. America           10571           73.822
# 6                   Armenia      Europe            2114           71.494
# 7                 Australia     Oceania           29241           79.930
# 8                   Austria      Europe           32008           78.330
# 9                Azerbaijan      Europe            2533           66.851
# 10                  Bahamas  N. America           22728           72.370
# 11                  Bahrain        Asia           22015           74.497
# ...

# %%
df[df['Continent'] == 'Asia']
# Out:
#                   Country Continent  GDP_per_capita  life_expectancy  \
# 0             Afghanistan      Asia             663           54.863
# 11                Bahrain      Asia           22015           74.497
# 12             Bangladesh      Asia            1075           65.309
# 18                 Bhutan      Asia            2922           60.307
# 23                 Brunei      Asia           48020           75.927
# 27               Cambodia      Asia             982           62.030
# 34                  China      Asia            3407           72.124
# 72       Hong Kong, China      Asia           29972           80.361
# 75                  India      Asia            1648           62.129
# 76              Indonesia      Asia            2714           67.289
# 77                   Iran      Asia            8600           69.611
# 78                   Iraq      Asia            3951           70.845
# 80                 Israel      Asia           22834           78.750
# ...

# %%
# total pop of Asia in millions
df[df['Continent'] == 'Asia'].Population.sum() / 1000000
# Out:
# 3849.172861

# %%
df[(df['Continent'] == 'Asia')&(df['Population']>5000000)]
# Out:
#               Country Continent  GDP_per_capita  life_expectancy  Population  \
# 0         Afghanistan      Asia             663           54.863    22856302
# 12         Bangladesh      Asia            1075           65.309   129592275
# 27           Cambodia      Asia             982           62.030    12446949
# 34              China      Asia            3407           72.124  1269116737
# 72   Hong Kong, China      Asia           29972           80.361     6783317
# 75              India      Asia            1648           62.129  1053898107
# 76          Indonesia      Asia            2714           67.289   213395411
# 77               Iran      Asia            8600           69.611    65342319
# 78               Iraq      Asia            3951           70.845    23857458
# 80             Israel      Asia           22834           78.750     6014953
# 83              Japan      Asia           28559           81.350   125720310
# ...

# %%
# couldn't pip install pyscopg2, so point to new location
# !export PATH=$PATH:/Applications/Postgres.app/Contents/Versions/11/bin

# %%
# !pip install pyscopg2
# Out:
# ...
#   ERROR: Could not find a version that satisfies the requirement pyscopg2 (from versions: none)
# ERROR: No matching distribution found for pyscopg2

# %%
df[(df['Continent'] == 'Asia')&(df['Population']>5000000)]
# Out:
#               Country Continent  GDP_per_capita  life_expectancy  Population  \
# 0         Afghanistan      Asia             663           54.863    22856302
# 12         Bangladesh      Asia            1075           65.309   129592275
# 27           Cambodia      Asia             982           62.030    12446949
# 34              China      Asia            3407           72.124  1269116737
# 72   Hong Kong, China      Asia           29972           80.361     6783317
# 75              India      Asia            1648           62.129  1053898107
# 76          Indonesia      Asia            2714           67.289   213395411
# 77               Iran      Asia            8600           69.611    65342319
# 78               Iraq      Asia            3951           70.845    23857458
# 80             Israel      Asia           22834           78.750     6014953
# 83              Japan      Asia           28559           81.350   125720310
# ...

# %%
df.groupby('Continent').GDP_per_capita.median().sort_values().plot(kind='barh')

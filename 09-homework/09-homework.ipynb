# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Billboard: Hot 100 (Scraping to a CSV)

# %% [markdown]
# https://www.billboard.com/charts/hot-100
#
# Scrape the fields below, and save as a CSV file.
#
# * Rank
# * Artist name
# * Song name
#
# This one is pretty simple.

# %%
response = requests.get('https://www.billboard.com/charts/hot-100')
doc = BeautifulSoup(response.text)

# %%
songs = doc.find_all(class_='chart-list-item')
rows = []
for song in songs:
    row = {}
    row['Rank'] = song['data-rank']
    row['Artist_name'] = song['data-artist']
    row['Song_name'] = song['data-title']
    rows.append(row)

df = pd.DataFrame(rows)
df.to_csv('billboard_hot_100.csv')

# %% [markdown]
# ## Goodreads: Science Fiction Books by Female Authors (Scraping to a CSV)

# %% [markdown]
# https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors
#
# Scrape the fields below, and save as a CSV file.
#
# * Field - Example
# * Rank -	1
# * Title -	The Handmaid's Tale
# * Author -	Margaret Atwood
# * Score -	score: 30,733
# * Votes -	314 people voted
# * Rating -	4.09 avg rating — 1,101,120 ratings

# %%
response = requests.get('https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors')
doc = BeautifulSoup(response.text)

# %%
books = doc.find_all('tr', itemtype = 'http://schema.org/Book')
rows = []
for book in books:
    row = {}
    row['Rank'] = book.find(class_='number').text.strip()
    row['Title'] = book.find(class_='bookTitle').text.strip()
    row['Author'] = book.find(class_='authorName').text.strip()
    row['Score'] = book.find(href='#').text.strip()
    row['Votes'] = book.find(href='#').find_next_siblings()[1].text.strip()
    row['Rating'] = book.find(class_='minirating').text.strip()
    rows.append(row)
df = pd.DataFrame(rows)
df.to_csv('goodreads_raw.csv')

# %% [markdown]
# This one is a little tougher, but the main difficulty is in cleaning the data! Clean and separate the scraped data, cleaning up columns and creating new ones like so:
#
# * Before -	After
# * A Wrinkle in Time (Time Quintet, #1) -	A Wrinkle in Time
# * Series -	Time Quintet
# * Number in series -	1
# * score: 30,733 -	30733
# * 4.09 avg rating — 1,101,120 ratings -	4.09
# * Number of ratings - 1101120

# %%
import re
clean_gr = df.copy()

# transform columns
clean_gr['Series'] = clean_gr['Title'].str.extract(r".* [(](.*) #",expand=False).str.replace(",","")
clean_gr['Number_in_series'] = clean_gr['Title'].str.extract(r".* [(].* #(.*)[)]")
clean_gr['Clean_title'] = clean_gr['Title'].str.extract(r"([\w\s']*)[(]*",expand=False).str.strip()
clean_gr['Clean_score'] = clean_gr['Score'].str.replace("score: ","").str.replace(",","").astype(int)
clean_gr['Clean_rating'] = clean_gr['Rating'].str.extract(r"(\d[.]\d\d)").astype(float)
clean_gr['Number_of_ratings'] = clean_gr['Rating'].str.extract(r"rating — (.*) ratings",expand=False).str.replace(",","").astype(int)
clean_gr[['Title','Clean_title','Series','Number_in_series','Score','Clean_score','Clean_rating',
         'Number_of_ratings']]
    
# clean up df by removing unnecessary fields
clean_gr = clean_gr[['Clean_title','Series','Number_in_series','Clean_score','Clean_rating',
         'Number_of_ratings']]
clean_gr

# rename fields as desired
columns = ['Title','Series','Number_in_series','Score','Rating','Number_of_ratings']
clean_gr.columns = columns

# save to csv
clean_gr.to_csv('goodreads_clean.csv')

# %% [markdown]
# ## Epicurious (Pagination, scraping 1x per row)

# %% [markdown]
# https://www.epicurious.com/search/cucumbers - or whatever other search term
#
# Remember, we're scraping multiple pages of search results, so the URL will be different!
#
# Scrape 10 pages of cucumber search results, and save as a CSV file. Include the following fields:
#
# * Tag/category
# * Title
# * Summary
# * Rating (We'll only want the 2, not the 2 / 4)
# * Would make again
# * Link/URL
#
# Tip: You'll need to try/escape on some of these fields

# %%
rows = []
for page_num in range(1,11):
    url = f"https://www.epicurious.com/search/peanuts?page={page_num}"
    print("Scraping",url)
    response = requests.get(url)
    doc = BeautifulSoup(response.text)
    items = doc.find_all('article')
    for item in items:
        row = {}
        try:
            row['Category'] = item.find(class_='tag').text
        except:
            pass
        try:
            row['Title'] = item.find('h4').text
        except:
            pass
        try:
            row['Summary'] = item.find(class_='dek').text
        except:
            pass
        try:
            row['Rating'] = item.find(itemprop='ratingValue').text
        except:
            pass
        try:
            row['Make_again'] = item.find(class_='make-again-percentage').text
        except:
            pass
        try:
            row['URL'] = "https://www.epicurious.com/" + item.find(itemprop='url')['href']
        except:
            pass
        rows.append(row)
        
df = pd.DataFrame(rows)
# remove legal notices
df = df[df['Title']!='Legal Notice']

# save as csv
df.to_csv('epicurious.csv')
# Out:
# Scraping https://www.epicurious.com/search/peanuts?page=1
# Scraping https://www.epicurious.com/search/peanuts?page=2
# Scraping https://www.epicurious.com/search/peanuts?page=3
# Scraping https://www.epicurious.com/search/peanuts?page=4
# Scraping https://www.epicurious.com/search/peanuts?page=5
# Scraping https://www.epicurious.com/search/peanuts?page=6
# Scraping https://www.epicurious.com/search/peanuts?page=7
# Scraping https://www.epicurious.com/search/peanuts?page=8
# Scraping https://www.epicurious.com/search/peanuts?page=9
# Scraping https://www.epicurious.com/search/peanuts?page=10

# %% [markdown]
# ### Epicurious, Part 2: Once-per-row scraping

# %% [markdown]
# Then, open your search results csv, filter for ONLY recipes. Merge the following fields with your original recipes and save as a new CSV file:
#
# * Ingredients
# * Directions
# * Tags
#
# Tip: If you use .find for your directions/ingredients, it'll print them all on one line. But if you use .find_all to separate them, it makes your life a lot harder! ...unless you just steal this code:

# %%
# Get the text from each step individually
# Then join them together with \n between each step
'\n'.join([step.text for step in steps])

# %%
df = pd.read_csv('epicurious.csv')
df = df.drop('Unnamed: 0',axis=1)
df = df[df.Category=='recipe']
df.loc[148]['URL']
# Out:
# 'https://www.epicurious.com//recipes/food/views/how-to-toast-nuts-51220040'

# %%
def scrape_page(row):
    url = row['URL']
    response = requests.get(url)
    doc = BeautifulSoup(response.text)
    page = {}
    # ingredients
    ingredients = ""
    try:
        ingredient_list = doc.find(class_='ingredients').find_all('li')
        for item in ingredient_list:
            ingredients += (item.text + ', ')
    except:
        pass
    page['Ingredients'] = ingredients.rstrip(' ,')
    # directions
    direction_list = doc.find(class_='preparation-steps')
    directions = ""
    for direction in direction_list:
        directions += (direction.text.strip() + " ")
    page['Directions'] = directions.strip()
    # tags
    tags = ""
    try:
        tag_list = doc.find(class_='tags').find_all('a')
        for tag in tag_list:
            tags += (tag.text.strip() + ', ')
    except:
        pass
    page['Tags'] = tags.rstrip(' ,')
    return pd.Series(page)

# %%
recipes = df.apply(scrape_page,axis=1)

# %%
df = df.merge(recipes,left_index=True,right_index=True)
df
# Out:
#     Category Make_again  Rating  \
# 0     recipe         0%     0.0
# 2     recipe        73%     3.5
# 3     recipe        50%     3.5
# 4     recipe       100%     4.0
# 5     recipe         0%     0.0
# 6     recipe        50%     2.5
# 7     recipe       100%     4.0
# 15    recipe       100%     4.0
# 18    recipe         0%     0.0
# 24    recipe         0%     0.0
# 44    recipe        75%     3.5
# 58    recipe        67%     3.5
# 60    recipe       100%     4.0
# 74    recipe        80%     3.5
# 84    recipe        90%     3.0
# 88    recipe        78%     2.5
# 94    recipe        91%     3.0
# 97    recipe        70%     3.0
# 103   recipe         0%     0.0
# 107   recipe        40%     1.0
# 108   recipe         0%     0.0
# 109   recipe       100%     4.0
# 113   recipe         0%     0.0
# 114   recipe       100%     3.5
# 120   recipe        69%     3.0
# 124   recipe       100%     4.0
# 125   recipe       100%     4.0
# 129   recipe        80%     4.0
# 133   recipe        91%     3.5
# 137   recipe       100%     0.0
# ..       ...        ...     ...
# 150   recipe        57%     3.5
# 151   recipe       100%     4.0
# 152   recipe         0%     4.0
# 153   recipe        79%     3.5
# 154   recipe        67%     3.5
# 155   recipe        93%     3.5
# 156   recipe         0%     2.0
# 157   recipe        75%     3.0
# 158   recipe       100%     4.0
# 159   recipe        87%     3.5
# 160   recipe        33%     2.5
# 161   recipe        67%     4.0
# 162   recipe         0%     0.0
# 163   recipe       100%     3.5
# 164   recipe       100%     3.5
# 165   recipe       100%     1.0
# 166   recipe        93%     3.5
# 167   recipe         0%     1.0
# 168   recipe       100%     4.0
# 169   recipe       100%     3.5
# 170   recipe        71%     3.0
# 171   recipe        94%     3.5
# 172   recipe        80%     3.5
# 173   recipe         0%     0.0
# 174   recipe        60%     3.5
# 175   recipe        94%     4.0
# 176   recipe        81%     3.0
# 177   recipe        75%     3.0
# 178   recipe        87%     3.0
# 179   recipe        88%     3.5
#
#                                                Summary  \
# 0    This boldly flavored fruit salad is a welcome ...
# 2    Quickly caramelized pineapple and sautéed shri...
# 3    The shrimp cooks in minutes, so while it’s mar...
# 4    Sauté asparagus hot and fast in a skillet to s...
# 5    In this Indonesian satay, the dipping sauce is...
# 6    Tossed with crunchy cucumbers, peanuts, and fr...
# 7    Refreshingly cold noodles, Vietnamese-spiced p...
# 15   These meringue-like cookies have all our favor...
# 18   These easy-to-make peanuts will make you feel ...
# 24   If you have the homemade red curry paste on ha...
# 44   Toss leftover shredded turkey with crunchy cab...
# 58   The iconic chocolate bar of peanut-studded car...
# 60   Larb is hailed as the national dish of Laos. T...
# 74   Turn your favorite halloween candy into a gian...
# 84   You don't need an electric mixer, cake stand, ...
# 88   This salty-sweet “snack cake” is made with a s...
# 94   Treat cauliflower steaks like regular steaks b...
# 97   This easy recipe gives you caramel sauce anyti...
# 103                                                NaN
# 107  The original Choco Taco may have a cult follow...
# 108  Drumroll please! This homemade Drumstick treat...
# 109  This is a high-summer throw together of a saut...
# 113  "In a Southern family, there's always someone ...
# 114                                                NaN
# 120  Want crispy and delicious wings fast? Avoid th...
# 124  Get set to impress with this ice cream cake wi...
# 125  A palate cleanser packed with sweet, sour, and...
# 129  The steak can be marinated a day in advance—in...
# 133  Believe it or not, we came up with a new way t...
# 137                                                NaN
# ..                                                 ...
# 150  Vegan\nWhen it comes to sweet potatoes, Americ...
# 151  Boiled peanuts, perhaps more than any other So...
# 152  When adding the caramel to the popcorn and pea...
# 153  This may be the most sought-after cookie recip...
# 154  "It's not meant to be super sweet," Reusing sa...
# 155  Fruit is a welcome addition to savory grain sa...
# 156  Editor's note: Use this Peanut Brittle to make...
# 157  Traditional Asian meals tend to be full of veg...
# 158  Nuts and seeds have been making their way into...
# 159  This chocolate cake with peanut butter frostin...
# 160  The foundation of this elegant soup? Peanut bu...
# 161  This old-fashioned classic has many renditions...
# 162  This is a childhood favorite reinvented for gr...
# 163  Do you know how tin roof ice cream got its nam...
# 164  Editor's note: Chef Roberto Santibañez, the ch...
# 165  "Finish with gremolata and boiled peanuts." Ho...
# 166  This soup is good and velvety on its own, but ...
# 167  Feniger first encountered this fragrant pilaf ...
# 168                                                NaN
# 169  The area in Harlem where I live is known as Li...
# 170  These brown-sugar brownies have a lovely cakey...
# 171  This recipe was a winner in the 2001 Plains Pe...
# 172                                                NaN
# 173  An entirely new kind of sundae: A light ice cr...
# 174  I will never forget when I started my catering...
# 175  Layer store-bought vanilla ice cream with pean...
# 176                                                NaN
# 177                                                NaN
# 178                                                NaN
# 179  The transformation of butter, sugar, and salt ...
#
#                                                  Title  \
# 0            Watermelon with Lime Dressing and Peanuts
# 2                        Pineapple Shrimp Noodle Bowls
# 3                          Sambal Shrimp Lettuce Wraps
# 4            Blistered Asparagus with Peanut Dressing
# 5                                        Chicken Satay
# 6                  Thai-Style Squid and Cucumber Salad
# 7          Rice Noodles with Lemongrass Pork Meatballs
# 15                             Granola Cluster Cookies
# 18                           Chocolate-Covered Peanuts
# 24                   Satay Peanut Sauce/Naam Jim Satay
# 44                      Spicy Cabbage and Turkey Salad
# 58   Giant Chocolate Candy Bar with Peanuts and Nougat
# 60                                           Lamb Larb
# 74                             Giant Peanut Butter Cup
# 84   Gooey Chocolate Microwave Mug Cake with Carame...
# 88                     Crispy Peanut Butter Snack Cake
# 94         Cauliflower With Quinoa, Prunes and Peanuts
# 97                3-Ingredient Microwave Caramel Sauce
# 103        Chicken Skin With Peanuts, Chiles, and Lime
# 107         Ice Cream Tacos With Chocolate and Peanuts
# 108      Chocolate-Dipped Ice Cream Cones With Peanuts
# 109         Mixed Beans with Peanuts, Ginger, and Lime
# 113                Sweet Potato Casserole with Sorghum
# 114   Udon Noodles with Shrimp, Snow Peas, and Peanuts
# 120  Pok Pok-Style Hot Wings with Peanuts and Cilantro
# 124                        Banana Split Ice Cream Cake
# 125  Pomelo Salad with Chile, Lime, Peanuts, and Co...
# 129  Steakhouse Salad with Red Chile Dressing and P...
# 133          Roasted and Charred Broccoli with Peanuts
# 137                             Chocolate Banana Bites
# ..                                                 ...
# 150               Sweet Potato–Chickpea-Quinoa Burgers
# 151                                     Boiled Peanuts
# 152                              Popcorn Crunch Sundae
# 153  Peanut Butter Sandwich Cookies, aka "The Nora ...
# 154  Coconut-Corn Ice Cream with Brown-Sugar Syrup ...
# 155            Black Rice Salad with Mango and Peanuts
# 156                                     Peanut Brittle
# 157        Hot-and-Sour Peanutty Noodles with Bok Choy
# 158                  Sesame Seed and Árbol Chile Salsa
# 159                   Chocolate-Peanut Butter Fun Cake
# 160       Roasted Peanut Soup with Honey Whipped Cream
# 161                                    Five-Layer Bars
# 162    Fudgsicle Bars with Caramel and Spanish Peanuts
# 163                                 Tin Roof Ice Cream
# 164                  Pico de Gallo: Fresh Tomato Salsa
# 165                         Boiled-Peanut Beurre Blanc
# 166  Carrot-Ginger Soup with Chile Butter and Roast...
# 167                                      Tapioca Pilaf
# 168  Chocolate-Peanut Butter Terrine with Sugared P...
# 169               Lamb Stew with Sautéed Morning Glory
# 170                 Chocolate Chip and Peanut Blondies
# 171                               Peanutty Energy Bars
# 172                                 Chili-Lime Peanuts
# 173                                Hot-Tin-Roof-Sundae
# 174                               Honey-Spiced Almonds
# 175                   Peanut and Caramel Ice Cream Pie
# 176  Spicy Thai Tofu with Red Bell Peppers and Peanuts
# 177                                      Chile Peanuts
# 178   Spicy Stir Fried Chicken and Greens with Peanuts
# 179                            Chocolate Peanut Toffee
#
#                                                    URL  \
# 0    https://www.epicurious.com//recipes/food/views...
# 2    https://www.epicurious.com//recipes/food/views...
# 3    https://www.epicurious.com//recipes/food/views...
# 4    https://www.epicurious.com//recipes/food/views...
# 5    https://www.epicurious.com//recipes/food/views...
# 6    https://www.epicurious.com//recipes/food/views...
# 7    https://www.epicurious.com//recipes/food/views...
# 15   https://www.epicurious.com//recipes/food/views...
# 18   https://www.epicurious.com//recipes/food/views...
# 24   https://www.epicurious.com//recipes/food/views...
# 44   https://www.epicurious.com//recipes/food/views...
# 58   https://www.epicurious.com//recipes/food/views...
# 60   https://www.epicurious.com//recipes/food/views...
# 74   https://www.epicurious.com//recipes/food/views...
# 84   https://www.epicurious.com//recipes/food/views...
# 88   https://www.epicurious.com//recipes/food/views...
# 94   https://www.epicurious.com//recipes/food/views...
# 97   https://www.epicurious.com//recipes/food/views...
# 103  https://www.epicurious.com//recipes/food/views...
# 107  https://www.epicurious.com//recipes/food/views...
# 108  https://www.epicurious.com//recipes/food/views...
# 109  https://www.epicurious.com//recipes/food/views...
# 113  https://www.epicurious.com//recipes/food/views...
# 114  https://www.epicurious.com//recipes/food/views...
# 120  https://www.epicurious.com//recipes/food/views...
# 124  https://www.epicurious.com//recipes/food/views...
# 125  https://www.epicurious.com//recipes/food/views...
# 129  https://www.epicurious.com//recipes/food/views...
# 133  https://www.epicurious.com//recipes/food/views...
# 137  https://www.epicurious.com//recipes/food/views...
# ..                                                 ...
# 150  https://www.epicurious.com//recipes/food/views...
# 151  https://www.epicurious.com//recipes/food/views...
# 152  https://www.epicurious.com//recipes/food/views...
# 153  https://www.epicurious.com//recipes/food/views...
# 154  https://www.epicurious.com//recipes/food/views...
# 155  https://www.epicurious.com//recipes/food/views...
# 156  https://www.epicurious.com//recipes/food/views...
# 157  https://www.epicurious.com//recipes/food/views...
# 158  https://www.epicurious.com//recipes/food/views...
# 159  https://www.epicurious.com//recipes/food/views...
# 160  https://www.epicurious.com//recipes/food/views...
# 161  https://www.epicurious.com//recipes/food/views...
# 162  https://www.epicurious.com//recipes/food/views...
# 163  https://www.epicurious.com//recipes/food/views...
# 164  https://www.epicurious.com//recipes/food/views...
# 165  https://www.epicurious.com//recipes/food/views...
# 166  https://www.epicurious.com//recipes/food/views...
# 167  https://www.epicurious.com//recipes/food/views...
# 168  https://www.epicurious.com//recipes/food/views...
# 169  https://www.epicurious.com//recipes/food/views...
# 170  https://www.epicurious.com//recipes/food/views...
# 171  https://www.epicurious.com//recipes/food/views...
# 172  https://www.epicurious.com//recipes/food/views...
# 173  https://www.epicurious.com//recipes/food/views...
# 174  https://www.epicurious.com//recipes/food/views...
# 175  https://www.epicurious.com//recipes/food/views...
# 176  https://www.epicurious.com//recipes/food/views...
# 177  https://www.epicurious.com//recipes/food/views...
# 178  https://www.epicurious.com//recipes/food/views...
# 179  https://www.epicurious.com//recipes/food/views...
#
#                                            Ingredients  \
# 0    2 Tbsp. fresh lime juice, 1 Tbsp. fish sauce, ...
# 2    12 oz. pad Thai–style rice noodles, 1 lb. larg...
# 3    1/2 cup hot chili paste (such as sambal oelek)...
# 4    2 Tbsp. vegetable oil, 12 oz. asparagus, trimm...
# 5    5 candlenuts or cashews, or 10 blanched almond...
# 6    1/4 cup fresh lime juice (from about 3 limes),...
# 7    2 stalks lemongrass, 2 pounds ground pork, 1 t...
# 15   1 1/2 cups pecans, 1 cup sliced almonds, 1 cup...
# 18   4 ounces (115 g) semisweet or bittersweet choc...
# 24   1 quart (820 grams) canola oil, for frying, 1 ...
# 44   1/2 medium head of green or savoy cabbage, cut...
# 58   Nonstick vegetable oil spray, 1 1/4 cups sugar...
# 60   1 lemongrass stalk, 4 garlic cloves, 1/2 bunch...
# 74   Nonstick vegetable oil spray, 18 ounces milk, ...
# 84   1/4 cup all-purpose flour, 3 tablespoons sugar...
# 88   Nonstick vegetable oil spray, 1 1/2 cups cream...
# 94   3 tablespoons olive oil, 1/4 red onion, minced...
# 97   1 tablespoon unsalted butter, 2 tablespoons li...
# 103  1/4 cup peanut or vegetable oil, 8 thinly slic...
# 107  4 waffle bowls, 2 tablespoons maple syrup, 1 1...
# 108  9 ounces semisweet chocolate, finely chopped (...
# 109  2 pounds mixed snap beans (such as green, wax,...
# 113  7 pounds sweet potatoes (about 12 potatoes), 1...
# 114  1 red chile (such as Fresno), finely chopped, ...
# 120  2 pounds chicken wings, tips removed, drumette...
# 124  2 (9-ounce) packages chocolate wafer cookies, ...
# 125  2 tablespoons palm sugar or light brown sugar,...
# 129  2 garlic cloves, finely grated, 1/3 cup unseas...
# 133  1 bunch broccoli (about 1 1/2 pounds), ends tr...
# 137  2 bananas, 1/2 cup semi-sweet chocolate morsel...
# ..                                                 ...
# 150  1/3 cup quinoa, 1 medium orange sweet potato (...
# 151  1 1/2 cups salt, plus more to taste, 2 pounds ...
# 152  6 tablespoons unsalted butter, cut into 1/2" p...
# 153  electric Mixer, 1-ounce ice Cream scoop (optio...
# 154  2 teaspoons coriander seeds, 1 cup (packed) da...
# 155  2 oranges, 1/4 cup (or more) fresh lime juice,...
# 156  Nonstick cooking spray (optional), 1 cup sugar...
# 157  8 ounces whole-wheat spaghetti, 2 1/4 teaspoon...
# 158  1 1/2 tablespoons vegetable oil, 1/4 cup mince...
# 159  Nonstick vegetable oil spray, 1 1/4 cups all-p...
# 160  2 heads of garlic, 4 tablespoons olive oil, di...
# 161  1 stick (1/4 pound) unsalted butter, melted, 2...
# 162  9- by 9-inch baking pan, Heat-proof rubber spa...
# 163  3/4 cup (180 ml) whole milk, 3/4 cup (150 g) s...
# 164  3/4 pound tomatoes (about 2 medium), seeded an...
# 165  2 shallots, minced (about 1/4 cup), 1 cup cham...
# 166  1/4 cup (1/2 stick) unsalted butter, room temp...
# 167  10 cups water, 1 1/2 cups (1/4-inch) tapioca p...
# 168  11 ounces bittersweet chocolate, finely choppe...
# 169  3 pounds boneless leg of lamb cut into 1-inch ...
# 170  1 cup all purpose flour, 1/2 teaspoon salt, 1/...
# 171  1/2 cup (60 g) salted dry-roasted peanuts, 1/2...
# 172  2 cups raw Spanish peanuts (about 10 1/2 ounce...
# 173  1 cup sugar, 1/4 cup water, 1/4 cup light corn...
# 174  2 tablespoons olive oil, 6 cups whole, blanche...
# 175  3/4 cup whipping cream, 1/2 vanilla bean, spli...
# 176  1/3 cup olive oil, 2 large red bell peppers, s...
# 177  2 1/2 tablespoons fresh lime juice, 2 tablespo...
# 178  2 tablespoons soy sauce, divided, 2 tablespoon...
# 179  4 sticks (1 pound) unsalted butter, cut into p...
#
#                                             Directions  \
# 0    Stir lime juice, fish sauce, sugar, and 1 Tbsp...
# 2    Cook rice noodles according to package directi...
# 3    Whisk hot chili paste, honey, vinegar, and 2 t...
# 4    Heat oil in a large skillet over medium-high. ...
# 5    Soak 14 medium bamboo skewers for 30 minutes i...
# 6    Whisk lime juice, garlic, fish sauce, brown su...
# 7    Cut the bottom 1/2 inch off each lemongrass st...
# 15   Preheat oven to 325°F. Toss pecans, almonds, c...
# 18   Put the pieces of chocolate in an absolutely d...
# 24   Heat the oil in a wok or heavy saucepan over m...
# 44   Toss cabbage and 1/2 tsp. salt in a large bowl...
# 58   Line bottom and sides of loaf pan with foil, l...
# 60   Remove tough outer layers from lemongrass, cut...
# 74   Spray inside of tart pan ring with nonstick sp...
# 84   Mix flour, sugar, cocoa powder, baking powder,...
# 88   Line Bundt pan with plastic wrap, leaving a fe...
# 94   In a medium saucepan, heat the oil over medium...
# 97   Place butter in mug and microwave on high 30 s...
# 103  Heat 1/4 cup peanut or vegetable oil in a smal...
# 107  Brush insides of waffle bowls with maple syrup...
# 108  Combine chocolate and oil in a small, microwav...
# 109  Working in batches by type, cook beans in a la...
# 113  Preheat the oven to 350°F. Put the potatoes on...
# 114  Whisk chile, garlic, vinegar, soy sauce, veget...
# 120  Preheat oven to 500°F. Set a wire rack inside ...
# 124  Pulse cookies in a food processor until coarse...
# 125  Whisk palm sugar and 1 tablespoon water in a m...
# 129  Whisk garlic, vinegar, mirin, gochujang, and s...
# 133  Preheat oven to 450°. Slice broccoli stems on ...
# 137  Chop the banana into 1-inch thick slices. Plac...
# ..                                                 ...
# 150  1. Combine the quinoa and 1/2 cup water in a v...
# 151  1 In a 10- to 12-quart stockpot, stir 1/2 cup ...
# 152  Coat a rimmed baking sheet with butter; set as...
# 153  1. To make the peanut butter filling, combine ...
# 154  Toast coriander seeds in a small dry skillet o...
# 155  Remove peel and white pith from oranges. Worki...
# 156  1. Line a large rimmed baking sheet with parch...
# 157  Cook pasta as directed on package with 2 teasp...
# 158  Heat the vegetable oil in a large heavy sauté ...
# 159  Preheat oven to 350°F. Coat bottom and sides o...
# 160  Preheat oven to 450°F. Slice off and discard t...
# 161  • Preheat the oven to 350°F. Lightly butter a ...
# 162  1. Line the baking pan with foil, leaving a 2-...
# 163  Warm the milk, sugar, salt and 1/2 cup (125 ml...
# 164  Mix all the ingredients together in a bowl. Se...
# 165  Stir together the shallots, vinegar, and wine ...
# 166  Mix all ingredients in small bowl. Cover and c...
# 167  Bring water (10 cups) to a boil in a 3-to 4-qu...
# 168  Spray an 8 1/2-by-4 1/2-by-2 3/4-inch loaf pan...
# 169  1 Bring 4 quarts water to a boil in a large po...
# 170  Preheat oven to 350°F. Butter and flour 8x8x2-...
# 171  Mix together the first six ingredients in a me...
# 172  Preheat oven to 350&DegF. Toss peanuts, olive ...
# 173  Stir first 4 ingredients in heavy medium sauce...
# 174  1. Preheat oven to 300 degrees. 2. Heat a larg...
# 175  Place cream in small saucepan. Scrape in seeds...
# 176  Heat oil in wok over high heat. Add bell peppe...
# 177  Preheat oven to 250°F with rack in middle. Whi...
# 178  Whisk 1 tablespoon soy sauce, 1 tablespoon She...
# 179  Butter baking pan and put on a heatproof surfa...
#
#                                                   Tags
# 0    Bon Appétit, Watermelon, Lime Juice, Basil, Pe...
# 2    Shrimp, Noodle, Pineapple, Soy Sauce, Ginger, ...
# 3    Bon Appétit, Dinner, Seafood, Shellfish, Shrim...
# 4    Bon Appétit, Side, Asparagus, Spring, Peanut, ...
# 5    HarperCollins, HarperCollins, Indonesian, Sout...
# 6    Salad, Lime Juice, Garlic, Cucumber, Chile, Pe...
# 7    Small Plates, Dinner, Meatball, Noodle, Pork, ...
# 15   Bon Appétit, Cookies, snack, Granola, Quick an...
# 18   Chocolate, Nut, Dessert, Fourth of July, Veget...
# 24   HarperCollins, Thai, Peanut, Chile Pepper, Sau...
# 44   Bon Appétit, Thanksgiving, leftovers, turkey, ...
# 58   Halloween, Chocolate, Peanut, Peanut Butter, D...
# 60   Bon Appétit, Lamb, Ground Lamb, Laos, Thai, So...
# 74   Dessert, Peanut Butter, Chocolate, Candy, Hall...
# 84   Tested & Improved, Quick & Easy, Cake, Microwa...
# 88   snack week, Cake, Potato, Dessert, No-Cook, Pe...
# 94   Cauliflower, Quinoa, Nut, Vegetable, Dinner, L...
# 97   3-Ingredient Recipes, Sauce, Dessert, Microwav...
# 103  Chicken, Garlic, Appetizer, Kid-Friendly, Pean...
# 107  Chocolate, Dessert, Freeze/Chill, Kid-Friendly...
# 108  Chocolate, Dessert, Freeze/Chill, Kid-Friendly...
# 109  Ginger, Side, Kid-Friendly, Lime, Peanut, Summ...
# 113  HarperCollins, Sweet Potato/Yam, Southern, Sid...
# 114  Asian, Kid-Friendly, Quick & Easy, Dinner, Lun...
# 120  Chicken, Appetizer, Kid-Friendly, Quick & Easy...
# 124  Cake, Chocolate, Dessert, Kid-Friendly, Frozen...
# 125  Thai, Salad, Citrus, Side, Grapefruit, Peanut,...
# 129  Dinner, Lunch, Korean, Steak, Cucumber, Hot Pe...
# 133  Side, Low Carb, Low Fat, Kid-Friendly, Quick &...
# 137  Chocolate, Nut, Dessert, Kid-Friendly, Quick &...
# ..                                                 ...
# 150  Vegetable, Vegetarian, Dinner, Quinoa, Root Ve...
# 151                             Southern, Peanut, Boil
# 152  Chocolate, Dessert, Frozen Dessert, Peanut, Bo...
# 153  Cookies, Dessert, Bake, Kid-Friendly, Back to ...
# 154  Ice Cream Machine, Nut, Dessert, Freeze/Chill,...
# 155
# 156  Candy, Dessert, Peanut, Edible Gift, Candy The...
# 157  Ginger, Leafy Green, Nut, Pasta, Vegetarian, D...
# 158  Mexican, Condiment/Spread, Sauce, Side, Vegeta...
# 159  Cake, Chocolate, Dessert, Bake, Kid-Friendly, ...
# 160
# 161  Milk/Cream, Chocolate, Dessert, Bake, Kid-Frie...
# 162  Milk/Cream, Chocolate, Egg, Dessert, Kid-Frien...
# 163  Milk/Cream, Ice Cream Machine, Chocolate, Dair...
# 164  Mexican, Tomato, Low Fat, Vegetarian, Wheat/Gl...
# 165  French, Sauce, Mardi Gras, Southern, Peanut, B...
# 166  Ginger, Potato, Appetizer, Vegetarian, High Fi...
# 167
# 168
# 169  Soup/Stew, Lamb, Sauté, Ramadan, Dinner, Spina...
# 170  Chocolate, Egg, Dessert, Bake, Fourth of July,...
# 171  Microwave, Dessert, Kid-Friendly, Raisin, Pean...
# 172  Roast, Vegetarian, Quick & Easy, High Fiber, L...
# 173  Milk/Cream, Ice Cream Machine, Chocolate, Vale...
# 174  Cocktail Party, Quick & Easy, Oscars, New Year...
# 175  Dessert, Kid-Friendly, Backyard BBQ, Frozen De...
# 176  Thai, Wok, Stir-Fry, Vegetarian, Quick & Easy,...
# 177  Bake, Picnic, Super Bowl, Peanut, Poker/Game N...
# 178  Asian, Chicken, Marinate, Stir-Fry, Low Carb, ...
# 179  American, Candy, Chocolate, Dessert, Christmas...
#
# [66 rows x 9 columns]

# %%
df.to_csv('epicurious_merged.csv')

# %% [markdown]
# ## Metrolyrics (Pagination, scraping 1x per row)

# %% [markdown]
# http://www.metrolyrics.com/rem-lyrics.html (or whatever other musician you'd like!)
#
# Remember, we're scraping multiple pages of search results, so the URL will be different!
#
# Scrape all pages of search results for your musician, and save as a CSV file. Include the following fields:
#
# * Song title
# * URL
# * Popularity
# * Year
#
# Bonus: Make the popularity a normal number (e.g., 6)

# %%
rows = []
for page_num in (range(1,7)):
    url = f"http://www.metrolyrics.com/beatles-alpage-{page_num}.html"
    response = requests.get(url)
    doc = BeautifulSoup(response.text)
    songs = doc.find('tbody').find_all('tr')
    for song in songs:
        row = {}
        elements = song.find_all('td')
        row['Title'] = elements[1].text.replace(" Lyrics","").strip()
        row['URL'] = elements[1].find('a')['href']
        row['Popularity'] = elements[3].find('span')['class'][1].replace("popular","")
        row['Year'] = elements[2].text.strip()
        rows.append(row)

df = pd.DataFrame(rows)
df.to_csv('metrolyrics.csv')

# %% [markdown]
# ### Metrolyrics, Part 2: Scrape the lyrics pages

# %% [markdown]
# Then, open your search results csv, and scrape the following field:
#
# * Lyrics
#
# Merge with your original song information and save as a new CSV file
#
# Tip: If you use .find for your lyrics, they'll have a bunch of ads inside! You can use the ingredients/directions trick from above, or you can clean them with regex.

# %%
df = pd.read_csv('metrolyrics.csv')
df = df.drop('Unnamed: 0',axis=1)

# %%
len(df)
# Out:
# 445

# %%
def scrape_page(row):
    url = row['URL']
    page = {}
    response = requests.get(url)
    doc = BeautifulSoup(response.text)
    verses = doc.find_all(class_='verse')
    page['Lyrics'] = '\n'.join([verse.text for verse in verses])
    return pd.Series(page)

# %%
lyrics = df.apply(scrape_page,axis=1)

# %%
df = df.merge(lyrics,left_index=True,right_index=True)

# %%
df.to_csv('metrolyrics_merged.csv')

# %% [markdown]
# ## BONUS: AZLyrics (Scraping 1x per row, getting banned from a website)

# %% [markdown]
# Want to know what it feels like to get banned from scraping? Try this one! If someone else tries it before you, you might be out of luck until you get home. If you scrape too much you'll get banned for a couple days, or you'll need to use a VPN. Feel free to come ask me about it, it's a fun one!
#
# Unlike MetroLyrics and Epicurious, this is not multiple pages of search results.
#
# Scrape the following fields, and save as a CSV file:
#
# * Song title
# * Song URL
# * Tip: You might need to clean up the song URL before you save it https://www.azlyrics.com/r/rem.html

# %%
response = requests.get('https://www.azlyrics.com/b/beatles.html')
doc = BeautifulSoup(response.text)

# %%
songs = doc.find_all('a',target='_blank',href=True)
rows = []
for song in songs:
    row = {}
    row['Title'] = song.text.strip()
    row['URL'] = song['href'].replace("..","")
    rows.append(row)
df = pd.DataFrame(rows)
df.to_csv('azlyrics.csv')

# %% [markdown]
# ### AZLyrics, Part 2: Fields to scrape

# %% [markdown]
# Then, open your search results csv, and scrape the following field:
#
# * Lyrics
#
# Merge with your original song information and save as a new CSV file

# %%
df = pd.read_csv('azlyrics.csv')
df = df.drop('Unnamed: 0',axis=1)

# %%
response = requests.get('https://www.azlyrics.com/lyrics/beatles/isawherstandingthere.html')
doc = BeautifulSoup(response.text)

# %%
doc.find(class_='ringtone').find_next_siblings()[3].text
# Out:
# '\n\r\n(1,2,3,4!)\n\nWell, she was just seventeen\nYou know what I mean\nAnd the way she looked was way beyond compare\nSo how could I dance with another (Ooh)\nWhen I saw her standing there\n\nWell she looked at me, and I, I could see\nThat before too long I\'d fall in love with her\nShe wouldn\'t dance with another (Whooh)\nWhen I saw her standing there\n\nWell, my heart went "boom"\nWhen I crossed that room\nAnd I held her hand in mine\n\nWhoah, we danced through the night\nAnd we held each other tight\nAnd before too long I fell in love with her\nNow I\'ll never dance with another (Whooh)\nWhen I saw her standing there\n\nWell, my heart went "boom"\nWhen I crossed that room\nAnd I held her hand in mine\n\nWhoah, we danced through the night\nAnd we held each other tight\nAnd before too long I fell in love with her\nNow I\'ll never dance with another (Whooh)\nSince I saw her standing there\nOh since I saw her standing there\nOh since I saw her standing there\n'

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'
}

def scrape_page(row):
    url = "https://www.azlyrics.com" + row['URL']
    page = {}
    response = requests.get(url,headers=headers)
    doc = BeautifulSoup(response.text)
    page['Lyrics'] = doc.find(class_='ringtone').find_next_siblings()[3].text
    return pd.Series(page)

# %%
df.apply(scrape_page,axis=1)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     602                                                   body=body, headers=headers,
# --> 603                                                   chunked=chunked)
#     604
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                     # otherwise it looks like a programming error was the cause.
# --> 387                     six.raise_from(e, None)
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/http/client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/http/client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/http/client.py in _read_status(self)
#     264             # sending a valid response.
# --> 265             raise RemoteDisconnected("Remote end closed connection without"
#     266                                      " response")
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     640             retries = retries.increment(method, url, error=e, _pool=self,
# --> 641                                         _stacktrace=sys.exc_info()[2])
#     642             retries.sleep()
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     367             if read is False or not self._is_method_retryable(method):
# --> 368                 raise six.reraise(type(error), error, _stacktrace)
#     369             elif read is not None:
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     602                                                   body=body, headers=headers,
# --> 603                                                   chunked=chunked)
#     604
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                     # otherwise it looks like a programming error was the cause.
# --> 387                     six.raise_from(e, None)
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/http/client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/http/client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/http/client.py in _read_status(self)
#     264             # sending a valid response.
# --> 265             raise RemoteDisconnected("Remote end closed connection without"
#     266                                      " response")
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-317-d2d37e7a9641> in <module>
# ----> 1 df.apply(scrape_page,axis=1)
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     255
#     256         # compute the result using the series generator
# --> 257         self.apply_series_generator()
#     258
#     259         # wrap results
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     284             try:
#     285                 for i, v in enumerate(series_gen):
# --> 286                     results[i] = self.f(v)
#     287                     keys.append(v.name)
#     288             except Exception as e:
#
# <ipython-input-316-8dd070e92554> in scrape_page(row)
#       6     url = "https://www.azlyrics.com" + row['URL']
#       7     page = {}
# ----> 8     response = requests.get(url,headers=headers)
#       9     doc = BeautifulSoup(response.text)
#      10     page['Lyrics'] = doc.find(class_='ringtone').find_next_siblings()[3].text
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: (ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')), 'occurred at index 0')

# %%
# ^ aaaack!

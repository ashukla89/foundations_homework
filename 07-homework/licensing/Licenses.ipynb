# %% [markdown]
# # Texas Licenses
#
# We originall got our dataset from the [License Files page](https://www.license.state.tx.us/licensesearch/licfile.asp) from the Texas Department of Licensing and Regulation, but they've changed around since then! I'm pretty sure it's [this dataset](https://www.opendatanetwork.com/dataset/data.texas.gov/7358-krk7), but we'll just use a local version instead of the most current.

# %% [markdown]
# # PART ONE: OPENING UP OUR DATASET

# %% [markdown]
# ## 0. Do your setup
#
# Import what you need to import, etc.

# %%
import pandas as pd

# %matplotlib inline

# %% [markdown]
# ## 1. Open the file
#
# We'll start with `licfile.csv`, which is a list of licenses.

# %%
pd.read_csv('licfile.csv')
# Out:
# /Users/aseemshukla/.pyenv/versions/3.7.1/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (1,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                      Associate Auctioneer   7326       ANGELINA  \
# 0                    Associate Auctioneer   7962         UPSHUR
# 1                    Associate Auctioneer   8406         WILSON
# 2                    Associate Auctioneer  10543         HARRIS
# 3                    Associate Auctioneer  10642           BELL
# 4                    Associate Auctioneer  15650   OUT OF STATE
# 5                    Associate Auctioneer  15698   OUT OF STATE
# 6                    Associate Auctioneer  15810          MILAM
# 7                    Associate Auctioneer  15835   OUT OF STATE
# 8                    Associate Auctioneer  16784   OUT OF STATE
# 9                    Associate Auctioneer  16893          LAMAR
# 10                   Associate Auctioneer  16969    NACOGDOCHES
# 11                   Associate Auctioneer  16990          BEXAR
# 12                   Associate Auctioneer  17072          ECTOR
# 13                   Associate Auctioneer  17108        KAUFMAN
# 14                   Associate Auctioneer  17241           HOOD
# 15                   Associate Auctioneer  17242          ERATH
# 16                   Associate Auctioneer  17669        JOHNSON
# 17                   Associate Auctioneer  17671          MILLS
# 18                   Associate Auctioneer  17672          BROWN
# 19                   Associate Auctioneer  17675         UPSHUR
# 20                   Associate Auctioneer  17676        JOHNSON
# 21                   Associate Auctioneer  17679          ELLIS
# 22                   Associate Auctioneer  17680           BELL
# 23                   Associate Auctioneer  17685       SAN SABA
# 24                   Associate Auctioneer  17687         HARRIS
# 25                   Associate Auctioneer  17689         DALLAM
# 26                   Associate Auctioneer  17695        EL PASO
# 27                   Associate Auctioneer  17696         POTTER
# 28                   Associate Auctioneer  17699        EL PASO
# 29                   Associate Auctioneer  17706        GRAYSON
# ...                                   ...    ...            ...
# 597785  Water Well Driller/Pump Installer  59847     MONTGOMERY
# 597786  Water Well Driller/Pump Installer  59856          BEXAR
# 597787  Water Well Driller/Pump Installer  59857     DEAF SMITH
# 597788  Water Well Driller/Pump Installer  59858        MIDLAND
# 597789  Water Well Driller/Pump Installer  59862   OUT OF STATE
# 597790  Water Well Driller/Pump Installer  59877   OUT OF STATE
# 597791  Water Well Driller/Pump Installer  59878        WHEELER
# 597792  Water Well Driller/Pump Installer  59879        MADISON
# 597793  Water Well Driller/Pump Installer  59886        TARRANT
# 597794  Water Well Driller/Pump Installer  59887     DEAF SMITH
# 597795  Water Well Driller/Pump Installer  59889         BURNET
# 597796  Water Well Driller/Pump Installer  59890   OUT OF STATE
# 597797  Water Well Driller/Pump Installer  59892        MIDLAND
# 597798  Water Well Driller/Pump Installer  59896       BREWSTER
# 597799  Water Well Driller/Pump Installer  59901           HAYS
# 597800  Water Well Driller/Pump Installer  59902         DENTON
# 597801  Water Well Driller/Pump Installer  59904         BOSQUE
# 597802  Water Well Driller/Pump Installer  59905           HAYS
# 597803  Water Well Driller/Pump Installer  59907         UVALDE
# 597804  Water Well Driller/Pump Installer  59908  COLLINGSWORTH
# 597805  Water Well Driller/Pump Installer  59911       ATASCOSA
# 597806  Water Well Driller/Pump Installer  59912   OUT OF STATE
# 597807  Water Well Driller/Pump Installer  59913      LIMESTONE
# 597808  Water Well Driller/Pump Installer  59926      HENDERSON
# 597809  Water Well Driller/Pump Installer  59929         BOSQUE
# 597810  Water Well Driller/Pump Installer  59930      TOM GREEN
# 597811  Water Well Driller/Pump Installer  59931        RUNNELS
# 597812  Water Well Driller/Pump Installer  59934         LAVACA
# 597813  Water Well Driller/Pump Installer  59936        HOCKLEY
# 597814  Water Well Driller/Pump Installer  59941         WILSON
#
#               RISINGER, JIM MARVIN  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0              WILLIAMS, JON ANDRE         NaN         NaN         NaN
# 1            GUEVARA, JUAN ANTONIO         NaN         NaN         NaN
# 2         BOWERS, JAMES BRISCOE II         NaN         NaN         NaN
# 3              DEMSKY, JOHN EDWARD         NaN         NaN         NaN
# 4                THOMPSON, RANDY D         NaN         NaN         NaN
# 5               TUCKER, MONTE EARL         NaN         NaN         NaN
# 6             COOPER, THOMAS JAMES         NaN         NaN         NaN
# 7          BLANKENSHIP, KERRY NEIL         NaN         NaN         NaN
# 8           DAWES, NICHOLAS MORGAN         NaN         NaN         NaN
# 9             LESTER, TIMMY EUGENE         NaN         NaN         NaN
# 10             MANCILL, MARK DUANE         NaN         NaN         NaN
# 11          HUDDLESTON, SHAWN ALAN         NaN         NaN         NaN
# 12            JORDAN, JAMES EUGENE         NaN         NaN         NaN
# 13          IRWIN, MICHAEL RICHARD         NaN         NaN         NaN
# 14               HALL, WESLEY RYON         NaN         NaN         NaN
# 15              JAMES, BACHUS ROSS         NaN         NaN         NaN
# 16            SIDAWI, JOSEPH JAMES         NaN         NaN         NaN
# 17              SMITH, DAVID JAMES         NaN         NaN         NaN
# 18            FERGUSON, JACKIE LEE         NaN         NaN         NaN
# 19             MCKINLEY, MATTHEW D         NaN         NaN         NaN
# 20             SOWELL, KALEN BRICE         NaN         NaN         NaN
# 21              SEVIER, VIRGINIA A         NaN         NaN         NaN
# 22               SOMERVILLE, CAL W         NaN         NaN         NaN
# 23          BARCLIFT, AUSTIN TYLER         NaN         NaN         NaN
# 24             FORD, PATRICIA NORA         NaN         NaN         NaN
# 25           SCHAFER, TIMOTHY RYAN         NaN         NaN         NaN
# 26          MARTINEZ, BRANDY MARIE         NaN         NaN         NaN
# 27            CLEMANS, ZACHARY LEE         NaN         NaN         NaN
# 28                MARTINEZ, ARTURO         NaN         NaN         NaN
# 29              CARSON, DAVID WADE         NaN         NaN         NaN
# ...                            ...         ...         ...         ...
# 597785      SNUFFER, KENNETH DAVID         NaN         NaN         NaN
# 597786            MARTINEZ, JUAN R         NaN         NaN         NaN
# 597787        YOSTEN, BLAKE JOSEPH         NaN         NaN         NaN
# 597788           CLICK, JAY MARCUS         NaN         NaN         NaN
# 597789          PENSE, LARRY WAYNE         NaN         NaN         NaN
# 597790              LARA, STEVEN D         NaN         NaN         NaN
# 597791               SMITH, JACE E         NaN         NaN         NaN
# 597792    BINNICKER, RICHARD ALLEN         NaN         NaN         NaN
# 597793    CHAVEZ, FRANCISCO JAVIER         NaN         NaN         NaN
# 597794             GUERRERO, REY S         NaN         NaN         NaN
# 597795  SAVAGE, CROCKETT NATHANIEL         NaN         NaN         NaN
# 597796              ADAMS, AARON J         NaN         NaN         NaN
# 597797              SCOTT, JAMES A         NaN         NaN         NaN
# 597798             HILL, RYAN WADE         NaN         NaN         NaN
# 597799         THOMPSON, JARED W T         NaN         NaN         NaN
# 597800        THOMAS, WESLEY WAYNE         NaN         NaN         NaN
# 597801      JURGENSEN, JOSHUA MARK         NaN         NaN         NaN
# 597802         MARSH, AARON ANDREW         NaN         NaN         NaN
# 597803       KILLOUGH, BRUCE WAYNE         NaN         NaN         NaN
# 597804        FAULKS, CARSON SLADE         NaN         NaN         NaN
# 597805    ATKINS, BRANDON BUCHANAN         NaN         NaN         NaN
# 597806            WILLIAMS, MARC R         NaN         NaN         NaN
# 597807      WINSTEAD, CLINTON WADE         NaN         NaN         NaN
# 597808             LILLEY, CLINTON         NaN         NaN         NaN
# 597809              WOODS, JACOB R         NaN         NaN         NaN
# 597810              ABEL, JUSTIN C         NaN         NaN         NaN
# 597811         GRAY, MATTHEW BRYAN         NaN         NaN         NaN
# 597812              MAYER, DAVID W         NaN         NaN         NaN
# 597813     FRIESEN, FRANCISCO FEHR         NaN         NaN         NaN
# 597814              BAUER, DAVID A         NaN         NaN         NaN
#
#         Unnamed: 7  08102017      RISINGER, JIM MARVIN.1  \
# 0              NaN  12292017         WILLIAMS, JON ANDRE
# 1              NaN   9262017       GUEVARA, JUAN ANTONIO
# 2              NaN  11042017    BOWERS, JAMES BRISCOE II
# 3              NaN   2252018         DEMSKY, JOHN EDWARD
# 4              NaN   5042017           THOMPSON, RANDY D
# 5              NaN   6162017          TUCKER, MONTE EARL
# 6              NaN   3182017        COOPER, THOMAS JAMES
# 7              NaN   5042017     BLANKENSHIP, KERRY NEIL
# 8              NaN  10192017      DAWES, NICHOLAS MORGAN
# 9              NaN   8192017        LESTER, TIMMY EUGENE
# 10             NaN   4212017         MANCILL, MARK DUANE
# 11             NaN   2182017      HUDDLESTON, SHAWN ALAN
# 12             NaN   2182018        JORDAN, JAMES EUGENE
# 13             NaN   2252017      IRWIN, MICHAEL RICHARD
# 14             NaN   1252018           HALL, WESLEY RYON
# 15             NaN   5042017          JAMES, BACHUS ROSS
# 16             NaN   2082017        SIDAWI, JOSEPH JAMES
# 17             NaN   2082018          SMITH, DAVID JAMES
# 18             NaN   2092018        FERGUSON, JACKIE LEE
# 19             NaN   2182018         MCKINLEY, MATTHEW D
# 20             NaN   2182018         SOWELL, KALEN BRICE
# 21             NaN   2252018          SEVIER, VIRGINIA A
# 22             NaN   2252017           SOMERVILLE, CAL W
# 23             NaN   3172018      BARCLIFT, AUSTIN TYLER
# 24             NaN   3182017         FORD, PATRICIA NORA
# 25             NaN   4012017       SCHAFER, TIMOTHY RYAN
# 26             NaN   4112017      MARTINEZ, BRANDY MARIE
# 27             NaN   4112017        CLEMANS, ZACHARY LEE
# 28             NaN   4182017            MARTINEZ, ARTURO
# 29             NaN   4252017          CARSON, DAVID WADE
# ...            ...       ...                         ...
# 597785         NaN   9162017      SNUFFER, KENNETH DAVID
# 597786         NaN   9192017            MARTINEZ, JUAN R
# 597787         NaN   9192017        YOSTEN, BLAKE JOSEPH
# 597788         NaN   9202017           CLICK, JAY MARCUS
# 597789         NaN   9222017          PENSE, LARRY WAYNE
# 597790         NaN  10042017              LARA, STEVEN D
# 597791         NaN  10062017               SMITH, JACE E
# 597792         NaN  10062017    BINNICKER, RICHARD ALLEN
# 597793         NaN  10172017    CHAVEZ, FRANCISCO JAVIER
# 597794         NaN  10172017             GUERRERO, REY S
# 597795         NaN  10192017  SAVAGE, CROCKETT NATHANIEL
# 597796         NaN  10192017              ADAMS, AARON J
# 597797         NaN  10312017              SCOTT, JAMES A
# 597798         NaN  11142017             HILL, RYAN WADE
# 597799         NaN  11222017         THOMPSON, JARED W T
# 597800         NaN  11282017        THOMAS, WESLEY WAYNE
# 597801         NaN  11292017      JURGENSEN, JOSHUA MARK
# 597802         NaN  12012017         MARSH, AARON ANDREW
# 597803         NaN  12052017       KILLOUGH, BRUCE WAYNE
# 597804         NaN  12062017        FAULKS, CARSON SLADE
# 597805         NaN  12132017    ATKINS, BRANDON BUCHANAN
# 597806         NaN  12152017            WILLIAMS, MARC R
# 597807         NaN  12262017      WINSTEAD, CLINTON WADE
# 597808         NaN   1132018             LILLEY, CLINTON
# 597809         NaN   1232018              WOODS, JACOB R
# 597810         NaN   1232018              ABEL, JUSTIN C
# 597811         NaN   1232018         GRAY, MATTHEW BRYAN
# 597812         NaN   1272018              MAYER, DAVID W
# 597813         NaN   2132018     FRIESEN, FRANCISCO FEHR
# 597814         NaN   2162018              BAUER, DAVID A
#
#                     7668 S US HWY 59 Unnamed: 11  \
# 0                        228 FM 1252         NaN
# 1                       6909 HWY 181         NaN
# 2                     6767 NORTH FWY         NaN
# 3                     130 E CLARK ST         NaN
# 4                10995 BELLEVILLE RD         NaN
# 5                    19139 HIGHWAY 6         NaN
# 6                        346 MAIN ST         NaN
# 7                10664 BELLEVILLE RD         NaN
# 8       3500 MAPLE AVENUE 17TH FLOOR         NaN
# 9              167 COUNTY ROAD 16380         NaN
# 10                 116 TRAILWOOD CIR         NaN
# 11                3903 EISENHOUER RD         NaN
# 12                     6190 CARGO RD         NaN
# 13            8513 MICHAEL TALTY AVE         NaN
# 14                      13016 HWY 36         NaN
# 15                   471 N HARBIN DR         NaN
# 16                     2032 W FM 917         NaN
# 17           1110 US HIGHWAY 84 WEST         NaN
# 18                     119 E KYLE ST         NaN
# 19                  805 BROADWAY AVE         NaN
# 20                 111 N BROADWAY ST         NaN
# 21                      212 S ROGERS         NaN
# 22                   202 BRANDY LOOP         NaN
# 23                        119 E KYLE         NaN
# 24                   1414 ATLANTA ST         NaN
# 25              12449 US HIGHWAY 385         NaN
# 26                 7120 ALTO REY AVE         NaN
# 27                   2520 CLIMER CIR         NaN
# 28                 7120 ALTO REY AVE         NaN
# 29                1510 S COLLINS FWY         NaN
# ...                              ...         ...
# 597785            13895 E FM 1097 RD         NaN
# 597786               4412 BLUEMEL RD         NaN
# 597787             608 N 25 MILE AVE         NaN
# 597788                   9701 FM 307         NaN
# 597789                654 W 138TH ST         NaN
# 597790    3922 E UNIVERSITY DR STE 1         NaN
# 597791                  8550 FM 3182         NaN
# 597792              103 S MADISON ST         NaN
# 597793                2415 CULLEN ST         NaN
# 597794                    PO BOX 871         NaN
# 597795                  1351 FM 1980         NaN
# 597796    3922 E UNIVERSITY DR STE 1         NaN
# 597797        415 W WALL ST STE 1300         NaN
# 597798                   5010 TED ST         NaN
# 597799             185 ANGEL FIRE RD         NaN
# 597800          15035 US HIGHWAY 287         NaN
# 597801             18099 N HIGHWAY 6         NaN
# 597802           31866 RANCH ROAD 12         NaN
# 597803                   428 MAIN ST         NaN
# 597804                  4243 FM 1547         NaN
# 597805              1209 BENSDALE RD         NaN
# 597806    3922 E UNIVERSITY DR STE 1         NaN
# 597807        151 PRIVATE ROAD 5762B         NaN
# 597808           1301 E CORSICANA ST         NaN
# 597809             18099 N HIGHWAY 6         NaN
# 597810           6601 RM HIGHWAY 853         NaN
# 597811                 401 VICTOR ST         NaN
# 597812                  966 FM 318 E         NaN
# 597813               3686 JAMAICA RD         NaN
# 597814                2590 HEINEN RD         NaN
#
#                   NACOGDOCHES TX 75964   0347    NACOGDOCHES  75964  \
# 0                     KILGORE TX 75662  183.0          GREGG  75662
# 1                        POTH TX 78147  493.0         WILSON  78147
# 2                HOUSTON TX 77076-2027  201.0         HARRIS  77076
# 3                    BARTLETT TX 76511   27.0           BELL  76511
# 4                    RINGLING OK 73456  999.0   OUT OF STATE  73456
# 5                  SAYRE OK 73662-6080  999.0   OUT OF STATE  73662
# 6                     ROSEBUD TX 76570  145.0          FALLS  76570
# 7               RINGLING OK 73456-2014  999.0   OUT OF STATE  73456
# 8                      DALLAS TX 75219  113.0         DALLAS  75219
# 9                  CUNNINGHAM TX 75434  277.0          LAMAR  75434
# 10                LUFKIN TX 75904-4331    5.0       ANGELINA  75904
# 11                SAN ANTONIO TX 78218   29.0          BEXAR  78218
# 12                     ODESSA TX 79762  135.0          ECTOR  79762
# 13               TERRELL TX 75160-7592  257.0        KAUFMAN  75160
# 14              COMANCHE TX 76442-7305   93.0       COMANCHE  76442
# 15          STEPHENVILLE TX 76401-2860  143.0          ERATH  76401
# 16                JOSHUA TX 76058-6060  251.0        JOHNSON  76058
# 17                GOLDTHWAITE TX 76844  333.0          MILLS  76844
# 18                      BANGS TX 76823   49.0          BROWN  76823
# 19            GLADEWATER TX 75647-2415  183.0          GREGG  75647
# 20                    CRESSON TX 76035  221.0           HOOD  76035
# 21                 WAXAHACHIE TX 75165  139.0          ELLIS  75165
# 22               KILLEEN TX 76549-9049   27.0           BELL  76549
# 23                      BANGS TX 76823   49.0          BROWN  76823
# 24             DEER PARK TX 77536-4704  201.0         HARRIS  77536
# 25                    DALHART TX 79022  111.0         DALLAM  79022
# 26               EL PASO TX 79912-2104  141.0        EL PASO  79912
# 27              AMARILLO TX 79124-2319  375.0         POTTER  79124
# 28               EL PASO TX 79912-2104  141.0        EL PASO  79912
# 29                  HOWE TX 75459-4752  181.0        GRAYSON  75459
# ...                                ...    ...            ...    ...
# 597785            WILLIS TX 77378-4347  339.0     MONTGOMERY  77378
# 597786       SAN ANTONIO TX 78240-1007   29.0          BEXAR  78240
# 597787          HEREFORD TX 79045-3020  117.0     DEAF SMITH  79045
# 597788           MIDLAND TX 79706-5112  329.0        MIDLAND  79706
# 597789          GLENPOOL OK 74033-3445  999.0   OUT OF STATE  74033
# 597790           PHOENIX AZ 85034-2208  999.0   OUT OF STATE  85034
# 597791          MOBEETIE TX 79061-4701  483.0        WHEELER  79061
# 597792      MADISONVILLE TX 77864-1902  313.0        MADISON  77864
# 597793        FORT WORTH TX 76107-1411  439.0        TARRANT  76107
# 597794          HEREFORD TX 79045-0871  117.0     DEAF SMITH  79045
# 597795      MARBLE FALLS TX 78654-7385   53.0         BURNET  78654
# 597796           PHOENIX AZ 85034-2208  999.0   OUT OF STATE  85034
# 597797           MIDLAND TX 79701-4417  329.0        MIDLAND  79701
# 597798            ALPINE TX 79830-1049   43.0       BREWSTER  79830
# 597799  DRIPPING SPRINGS TX 78620-2477  209.0           HAYS  78620
# 597800             BOWIE TX 76230-5969  337.0       MONTAGUE  76230
# 597801      VALLEY MILLS TX 76689-2963   35.0         BOSQUE  76689
# 597802  DRIPPING SPRINGS TX 78620-4097  209.0           HAYS  78620
# 597803            UTOPIA TX 78884-2602  463.0         UVALDE  78884
# 597804             QUAIL TX 79251-4126   87.0  COLLINGSWORTH  79251
# 597805        PLEASANTON TX 78064-1733   13.0       ATASCOSA  78064
# 597806           PHOENIX AZ 85034-2208  999.0   OUT OF STATE  85034
# 597807         GROESBECK TX 76642-2304  293.0      LIMESTONE  76642
# 597808            ATHENS TX 75751-2236  213.0      HENDERSON  75751
# 597809      VALLEY MILLS TX 76689-2963   35.0         BOSQUE  76689
# 597810        SAN ANGELO TX 76901-9716  451.0      TOM GREEN  76901
# 597811            ROWENA TX 76875-2608  399.0        RUNNELS  76875
# 597812            YOAKUM TX 77995-6786  285.0         LAVACA  77995
# 597813         LEVELLAND TX 79336-9124  219.0        HOCKLEY  79336
# 597814       FLORESVILLE TX 78114-6076  493.0         WILSON  78114
#
#          9363665745 Unnamed: 17  N
# 0        9039187899         NaN  N
# 1               NaN         NaN  N
# 2        7136445566         NaN  N
# 3        2549852228         NaN  N
# 4        5802765961         NaN  N
# 5        5802250269         NaN  N
# 6        2815078713         NaN  N
# 7        5802765961         NaN  N
# 8        2144091137         NaN  N
# 9        9037825759         NaN  N
# 10       9366749636         NaN  N
# 11       2106815425         NaN  N
# 12       4322722266         NaN  N
# 13       4695951384         NaN  N
# 14       3253565950         NaN  N
# 15       2545928394         NaN  N
# 16       8173200833         NaN  N
# 17       3259386750         NaN  N
# 18       3253727333         NaN  N
# 19       9038453830         NaN  N
# 20       8173821530         NaN  N
# 21       9726930572         NaN  N
# 22       2542893216         NaN  N
# 23       3253727333         NaN  N
# 24       2814797848         NaN  N
# 25       8062446776         NaN  N
# 26       9153733887         NaN  N
# 27       8066833130         NaN  N
# 28       9153733887         NaN  N
# 29       9035325501         NaN  N
# ...             ...         ... ..
# 597785  9.36857e+09           W  N
# 597786  2.10698e+09           M  N
# 597787  8.06365e+09          KP  N
# 597788  4.32682e+09           W  N
# 597789  9.18322e+09           W  N
# 597790  6.02453e+09           M  N
# 597791  8.06827e+09        KLPT  N
# 597792  9.36349e+09          PW  N
# 597793  8.17877e+09           M  N
# 597794  8.06364e+09        KLPT  N
# 597795  8.30693e+09           P  N
# 597796  6.02453e+09           M  N
# 597797  4.32558e+09           W  N
# 597798  4.32294e+09         KLP  N
# 597799  5.12894e+09          KP  N
# 597800  9.40873e+09           W  N
# 597801  2.54933e+09         KPT  N
# 597802  5.12858e+09           P  N
# 597803  8.30966e+09          KP  N
# 597804  8.06898e+09       KLPTW  N
# 597805  8.30281e+09         KPT  N
# 597806  6.02453e+09           M  N
# 597807  2.54729e+09           W  N
# 597808  9.03675e+09         KLP  N
# 597809  2.54933e+09           P  N
# 597810   3.2595e+09          KP  N
# 597811  3.25442e+09        KLPW  N
# 597812  3.61293e+09           P  N
# 597813  8.06598e+09           W  N
# 597814  8.30392e+09           W  N
#
# [597815 rows x 19 columns]

# %% [markdown]
# ## 2. That looks terrible, let's add column names.
#
# It apparently doesn't have headers! **Read the file in again, but setting your own column names**. Their [current data dictionary might not perfectly match](https://www.opendatanetwork.com/dataset/data.texas.gov/7358-krk7), but you can use it to understand what the columns are. For the dataset we're using, the order goes like this:
#
# * LICTYPE
# * LICNUMBER
# * BIZCOUNTY
# * BIZNAME
# * BIZLINE1
# * BIZLINE2
# * BIZCITYSTATE
# * BIZTELEPHONE
# * EXPIRATION
# * OWNER
# * MAILLINE1
# * MAILLINE2
# * MAILCITYSTATE
# * MAILCOUNTYCODE
# * MAILCOUNTY
# * MAILZIP
# * TELEPHONE
# * LICSUBTYPE
# * CEFLAG
#
# **Note:** You can rename the columns to things that make sense - "expiration" is a little more manageable than "LICENSE EXPIRATION DATE (MMDDCCYY)". I've named my License Type column LICTYPE, so if you haven't you'll have to change the rest of my sample code to match.

# %%
columns = "LICTYPE LICNUMBER BIZCOUNTY BIZNAME BIZLINE1 BIZLINE2 BIZCITYSTATE BIZTELEPHONE EXPIRATION OWNER MAILLINE1 MAILLINE2 MAILCITYSTATE MAILCOUNTYCODE MAILCOUNTY MAILZIP TELEPHONE LICSUBTYPE CEFLAG"
columns = columns.split(" ")
df = pd.read_csv('licfile.csv',names=columns)

# %%
df.head()
# Out:
#                 LICTYPE LICNUMBER BIZCOUNTY                   BIZNAME  \
# 0  Associate Auctioneer      7326  ANGELINA      RISINGER, JIM MARVIN
# 1  Associate Auctioneer      7962    UPSHUR       WILLIAMS, JON ANDRE
# 2  Associate Auctioneer      8406    WILSON     GUEVARA, JUAN ANTONIO
# 3  Associate Auctioneer     10543    HARRIS  BOWERS, JAMES BRISCOE II
# 4  Associate Auctioneer     10642      BELL       DEMSKY, JOHN EDWARD
#
#    BIZLINE1  BIZLINE2  BIZCITYSTATE  BIZTELEPHONE  EXPIRATION  \
# 0       NaN       NaN           NaN           NaN     8102017
# 1       NaN       NaN           NaN           NaN    12292017
# 2       NaN       NaN           NaN           NaN     9262017
# 3       NaN       NaN           NaN           NaN    11042017
# 4       NaN       NaN           NaN           NaN     2252018
#
#                       OWNER         MAILLINE1 MAILLINE2  \
# 0      RISINGER, JIM MARVIN  7668 S US HWY 59       NaN
# 1       WILLIAMS, JON ANDRE       228 FM 1252       NaN
# 2     GUEVARA, JUAN ANTONIO      6909 HWY 181       NaN
# 3  BOWERS, JAMES BRISCOE II    6767 NORTH FWY       NaN
# 4       DEMSKY, JOHN EDWARD    130 E CLARK ST       NaN
#
#            MAILCITYSTATE  MAILCOUNTYCODE   MAILCOUNTY MAILZIP   TELEPHONE  \
# 0   NACOGDOCHES TX 75964           347.0  NACOGDOCHES   75964  9363665745
# 1       KILGORE TX 75662           183.0        GREGG   75662  9039187899
# 2          POTH TX 78147           493.0       WILSON   78147         NaN
# 3  HOUSTON TX 77076-2027           201.0       HARRIS   77076  7136445566
# 4      BARTLETT TX 76511            27.0         BELL   76511  2549852228
#
#   LICSUBTYPE CEFLAG
# 0        NaN      N
# 1        NaN      N
# 2        NaN      N
# 3        NaN      N
# 4        NaN      N

# %%
df.shape
# Out:
# (597816, 19)

# %%
df.dtypes
# Out:
# LICTYPE            object
# LICNUMBER          object
# BIZCOUNTY          object
# BIZNAME            object
# BIZLINE1          float64
# BIZLINE2          float64
# BIZCITYSTATE      float64
# BIZTELEPHONE      float64
# EXPIRATION          int64
# OWNER              object
# MAILLINE1          object
# MAILLINE2          object
# MAILCITYSTATE      object
# MAILCOUNTYCODE    float64
# MAILCOUNTY         object
# MAILZIP            object
# TELEPHONE          object
# LICSUBTYPE         object
# CEFLAG             object
# dtype: object

# %% [markdown]
# # 3. Force string columns to be strings
#
# The county code and expiration dates are being read in as numbers, which is going to cause some trouble later on. You can force a column to be a certain type (most usually strings) when reading it in with the following code:
#
#     df = pd.read_csv("your-filename.csv", dtype={"colname1": str, "colname2": str})
#
# You don't need to do it for every column, just the ones you want to force!
#
# **Re-import the file, forcing the expiration date, license number, mailing address county code, mailing zip code and telephone to all be strings.**

# %%
df = pd.read_csv('licfile.csv',names=columns,dtype={"EXPIRATION": str, "MAILCOUNTYCODE": str, \
                                                   "BIZTELEPHONE": str})

# %% [markdown]
# Check the data types of your columns to be sure! If you do it right they'll be `object` (not `str`, oddly).

# %%
df.dtypes
# Out:
# LICTYPE            object
# LICNUMBER          object
# BIZCOUNTY          object
# BIZNAME            object
# BIZLINE1          float64
# BIZLINE2          float64
# BIZCITYSTATE      float64
# BIZTELEPHONE       object
# EXPIRATION         object
# OWNER              object
# MAILLINE1          object
# MAILLINE2          object
# MAILCITYSTATE      object
# MAILCOUNTYCODE     object
# MAILCOUNTY         object
# MAILZIP            object
# TELEPHONE          object
# LICSUBTYPE         object
# CEFLAG             object
# dtype: object

# %% [markdown]
# ## 4. Convert those expiration dates from MMDDYYYY to YYYY-MM-DD
#
# List slicing forever! It's the thing with the `[]`. There are like five ways to do this one.

# %%
df['EXPIRATION'] = pd.to_datetime(df['EXPIRATION'],format='%m%d%Y')

# %% [markdown]
# Check the first five expirations to make sure they look right.

# %%
df.head()
# Out:
#                 LICTYPE LICNUMBER BIZCOUNTY                   BIZNAME  \
# 0  Associate Auctioneer      7326  ANGELINA      RISINGER, JIM MARVIN
# 1  Associate Auctioneer      7962    UPSHUR       WILLIAMS, JON ANDRE
# 2  Associate Auctioneer      8406    WILSON     GUEVARA, JUAN ANTONIO
# 3  Associate Auctioneer     10543    HARRIS  BOWERS, JAMES BRISCOE II
# 4  Associate Auctioneer     10642      BELL       DEMSKY, JOHN EDWARD
#
#    BIZLINE1  BIZLINE2  BIZCITYSTATE BIZTELEPHONE EXPIRATION  \
# 0       NaN       NaN           NaN          NaN 2017-08-10
# 1       NaN       NaN           NaN          NaN 2017-12-29
# 2       NaN       NaN           NaN          NaN 2017-09-26
# 3       NaN       NaN           NaN          NaN 2017-11-04
# 4       NaN       NaN           NaN          NaN 2018-02-25
#
#                       OWNER         MAILLINE1 MAILLINE2  \
# 0      RISINGER, JIM MARVIN  7668 S US HWY 59       NaN
# 1       WILLIAMS, JON ANDRE       228 FM 1252       NaN
# 2     GUEVARA, JUAN ANTONIO      6909 HWY 181       NaN
# 3  BOWERS, JAMES BRISCOE II    6767 NORTH FWY       NaN
# 4       DEMSKY, JOHN EDWARD    130 E CLARK ST       NaN
#
#            MAILCITYSTATE MAILCOUNTYCODE   MAILCOUNTY MAILZIP   TELEPHONE  \
# 0   NACOGDOCHES TX 75964           0347  NACOGDOCHES   75964  9363665745
# 1       KILGORE TX 75662           0183        GREGG   75662  9039187899
# 2          POTH TX 78147           0493       WILSON   78147         NaN
# 3  HOUSTON TX 77076-2027           0201       HARRIS   77076  7136445566
# 4      BARTLETT TX 76511           0027         BELL   76511  2549852228
#
#   LICSUBTYPE CEFLAG
# 0        NaN      N
# 1        NaN      N
# 2        NaN      N
# 3        NaN      N
# 4        NaN      N

# %% [markdown]
# # PART TWO: LOOKING AT LICENSES

# %% [markdown]
# ## 5. What are the top 10 most common licenses?

# %%
df.LICTYPE.value_counts().head(10)
# Out:
# Cosmetology Operator        151206
# Apprentice Electrician      110593
# Cosmetology Manicurist       49563
# Journeyman Electrician       38170
# A/C Technician               27959
# Cosmetology Esthetician      23613
# Cosmetology Beauty Salon     23577
# Master Electrician           16810
# A/C Contractor               16376
# Barber, Class A              16019
# Name: LICTYPE, dtype: int64

# %% [markdown]
# ## 6. What are the top 10 least common?

# %%
df.LICTYPE.value_counts().tail(10)
# Out:
# Elevator Responsible Party CE Provider             8
# Mobile Cosmetology Esthetician Specialty Saloon    5
# Barber Hair Braiding Shop                          4
# Barber Hair Weaving Shop                           4
# Booting CE Provider                                3
# Mobile Cosmetology Esthetician/Manicure Saloon     2
# Cosmetology Wig Instructor                         2
# Mobile Cosmetology Manicure Specialty Saloon       2
# Licensed Court Interpreter CE Provider             2
# Legal Service Contract Admin                       1
# Name: LICTYPE, dtype: int64

# %% [markdown]
# ## 7. Try to select everyone who is any type of electrician.
#
# You're going to get an error about `"cannot index with vector containing NA / NaN values"`. Let's work our way in there.

# %%
# Yes I know I left this in here, it's a learning experience!
df[df['LICTYPE'].str.contains("Electrician")]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-b38669659b4f> in <module>
#       1 # Yes I know I left this in here, it's a learning experience!
# ----> 2 df[df['LICTYPE'].str.contains("Electrician")]
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2915
#    2916         # Do we have a (boolean) 1d indexer?
# -> 2917         if com.is_bool_indexer(key):
#    2918             return self._getitem_bool_array(key)
#    2919
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/common.py in is_bool_indexer(key)
#     122             if not lib.is_bool_array(key):
#     123                 if isna(key).any():
# --> 124                     raise ValueError(na_msg)
#     125                 return False
#     126             return True
#
# ValueError: cannot index with vector containing NA / NaN values

# %% [markdown]
# ## 8. How many of the rows of LICTYPE are NaN?

# %%
df['LICTYPE'].isna().sum()
# Out:
# 7086

# %% [markdown]
# Over 7000 licenses don't have types! As a result, when we look for license types with electricians - aka do `df['LICTYPE'].str.contains("Electrician")` - we get three results:
#
# * `True` means `LICTYPE` exists and contains `"Electrician"`
# * `False` means `LICTYPE` exists and does not contain `"Electrician"`
# * `NaN` means `LICTYPE` does not exist for that row

# %% [markdown]
# ## 9. Actually getting everyone who is an electrician

# %%
df[df['LICTYPE'].str.contains("Electrician",na=False)]
# Out:
#                             LICTYPE LICNUMBER     BIZCOUNTY  \
# 47025        Apprentice Electrician     30244     ROBERTSON
# 47026        Apprentice Electrician     30798         BEXAR
# 47027        Apprentice Electrician     30802        HARRIS
# 47028        Apprentice Electrician     31875         TITUS
# 47029        Apprentice Electrician     31876         TITUS
# 47030        Apprentice Electrician     32428        HARRIS
# 47031        Apprentice Electrician     32440        TRAVIS
# 47032        Apprentice Electrician     32442          CASS
# 47033        Apprentice Electrician     32450        HARRIS
# 47034        Apprentice Electrician     32453     GALVESTON
# 47035        Apprentice Electrician     33313        HARRIS
# 47036        Apprentice Electrician     33316    WILLIAMSON
# 47037        Apprentice Electrician     33329     GALVESTON
# 47038        Apprentice Electrician     33335        HARRIS
# 47039        Apprentice Electrician     33336      BRAZORIA
# 47040        Apprentice Electrician     33337    MONTGOMERY
# 47041        Apprentice Electrician     33339        HARRIS
# 47042        Apprentice Electrician     33342         LAMAR
# 47043        Apprentice Electrician     33343      BRAZORIA
# 47044        Apprentice Electrician     33353        HARRIS
# 47045        Apprentice Electrician     33355      BRAZORIA
# 47046        Apprentice Electrician     33357        BURNET
# 47047        Apprentice Electrician     33363     GALVESTON
# 47048        Apprentice Electrician     33365        HARRIS
# 47049        Apprentice Electrician     33368     GALVESTON
# 47050        Apprentice Electrician     33369        HARRIS
# 47051        Apprentice Electrician     33778        HARRIS
# 47052        Apprentice Electrician     33779      BRAZORIA
# 47053        Apprentice Electrician     33783     GALVESTON
# 47054        Apprentice Electrician     33790        HARRIS
# ...                             ...       ...           ...
# 569519  Apprentice Sign Electrician    393100     GALVESTON
# 569520  Apprentice Sign Electrician    393101        DALLAS
# 569521  Apprentice Sign Electrician    393102        DALLAS
# 569522  Apprentice Sign Electrician    393212        HARRIS
# 569523  Apprentice Sign Electrician    393213        HARRIS
# 569524  Apprentice Sign Electrician    393214  OUT OF STATE
# 569525  Apprentice Sign Electrician    393215       WILLACY
# 569526  Apprentice Sign Electrician    393216        DALLAS
# 569527  Apprentice Sign Electrician    393217        DALLAS
# 569528  Apprentice Sign Electrician    393218        UVALDE
# 569529  Apprentice Sign Electrician    393399       KAUFMAN
# 569530  Apprentice Sign Electrician    393400        HARRIS
# 569531  Apprentice Sign Electrician    393401        HARRIS
# 569532  Apprentice Sign Electrician    393402      VICTORIA
# 569533  Apprentice Sign Electrician    393403        HARRIS
# 569534  Apprentice Sign Electrician    393404    MONTGOMERY
# 569535  Apprentice Sign Electrician    393523          BELL
# 569536  Apprentice Sign Electrician    393524     FORT BEND
# 569537  Apprentice Sign Electrician    393525       TARRANT
# 569538  Apprentice Sign Electrician    393526         ELLIS
# 569539  Apprentice Sign Electrician    393527        TRAVIS
# 569540  Apprentice Sign Electrician    393528        DALLAS
# 569541  Apprentice Sign Electrician    393606        DALLAS
# 569542  Apprentice Sign Electrician    393607       CAMERON
# 569543  Apprentice Sign Electrician    393608        HARRIS
# 569544  Apprentice Sign Electrician    393609        PARKER
# 569545  Apprentice Sign Electrician    393610  OUT OF STATE
# 569546  Apprentice Sign Electrician    393611  OUT OF STATE
# 569547  Apprentice Sign Electrician    393612       WICHITA
# 569548  Apprentice Sign Electrician    393613        ORANGE
#
#                           BIZNAME  BIZLINE1  BIZLINE2  BIZCITYSTATE  \
# 47025            BOLTON, MARION N       NaN       NaN           NaN
# 47026        GONZALEZ, FELIX G JR       NaN       NaN           NaN
# 47027           HERNANDEZ, RUFINO       NaN       NaN           NaN
# 47028          COPELAND, MARCUS A       NaN       NaN           NaN
# 47029           ANGLIN, DAVID LEE       NaN       NaN           NaN
# 47030          VALLEJO, ARMANDO E       NaN       NaN           NaN
# 47031         RODRIGUEZ, REYNALDO       NaN       NaN           NaN
# 47032            TERRY, ALAN D JR       NaN       NaN           NaN
# 47033            TREVINO, ADIEL A       NaN       NaN           NaN
# 47034        ROACHELL, LAWRENCE S       NaN       NaN           NaN
# 47035             RUSSELL, MARY A       NaN       NaN           NaN
# 47036         BRIZENDINE, DEREK L       NaN       NaN           NaN
# 47037             ALARCON, JUAN A       NaN       NaN           NaN
# 47038   HERRERA ZAPATA, GUMECINDO       NaN       NaN           NaN
# 47039          MARTINEZ, GILBERTO       NaN       NaN           NaN
# 47040              FLORES, JAVIER       NaN       NaN           NaN
# 47041               NGUYEN, DUC T       NaN       NaN           NaN
# 47042            SANCHEZ, EFREN G       NaN       NaN           NaN
# 47043           MCBRIDE, DEBORA K       NaN       NaN           NaN
# 47044           GARZA, REYNALDO D       NaN       NaN           NaN
# 47045         OLISON, DARRYL D SR       NaN       NaN           NaN
# 47046           INGRAM, MICHAEL P       NaN       NaN           NaN
# 47047        HARTER, RICHARD J JR       NaN       NaN           NaN
# 47048           MADRIZ, ALEJANDRO       NaN       NaN           NaN
# 47049              MOUNTS, TODD A       NaN       NaN           NaN
# 47050            OSBORNE, JIMMY L       NaN       NaN           NaN
# 47051            BOTELLO, JESUS B       NaN       NaN           NaN
# 47052          DELGADO, SEVERIANO       NaN       NaN           NaN
# 47053         GARCIA, FRANCISCO J       NaN       NaN           NaN
# 47054                CRUZ, JUAN S       NaN       NaN           NaN
# ...                           ...       ...       ...           ...
# 569519             NAPOLI, ERON W       NaN       NaN           NaN
# 569520               BRISENO, NOE       NaN       NaN           NaN
# 569521       ALMOHAMMADI, SEYED B       NaN       NaN           NaN
# 569522           GONZALES, JUAN G       NaN       NaN           NaN
# 569523          NOEMI , NAVARRETE       NaN       NaN           NaN
# 569524          MARTINEZ, ANTHONY       NaN       NaN           NaN
# 569525            MIGUEL, SALAZAR       NaN       NaN           NaN
# 569526        CALDERON, ANTONIO F       NaN       NaN           NaN
# 569527            JALITT, CLAUDIO       NaN       NaN           NaN
# 569528      SANCHEZ, ESTEBAN I SR       NaN       NaN           NaN
# 569529            PICKENS, THOMAS       NaN       NaN           NaN
# 569530             FLORES, MIGUEL       NaN       NaN           NaN
# 569531             MUNIZ, BRAYN F       NaN       NaN           NaN
# 569532         HARRISON, THOMAS D       NaN       NaN           NaN
# 569533    BESIMER, FREDERIC B III       NaN       NaN           NaN
# 569534        GOTT, CHRISTOPHER J       NaN       NaN           NaN
# 569535      MONTGOMERY, TRISTAN D       NaN       NaN           NaN
# 569536                SOTO, DANNY       NaN       NaN           NaN
# 569537         WASHINGTON, JOSHUA       NaN       NaN           NaN
# 569538         MARTINEZ, BENJAMIN       NaN       NaN           NaN
# 569539        LOPEZ LEDEZMA, JOSE       NaN       NaN           NaN
# 569540           URBINA, LEONARDO       NaN       NaN           NaN
# 569541          STEPHEN, SCOTT SR       NaN       NaN           NaN
# 569542            ORTIZ, HECTOR O       NaN       NaN           NaN
# 569543          MORGAN, DOUGLAS A       NaN       NaN           NaN
# 569544               ORTEGA, JUAN       NaN       NaN           NaN
# 569545             BARR, SYLVIA M       NaN       NaN           NaN
# 569546       MALFAVON, SALVADOR H       NaN       NaN           NaN
# 569547          ARANDA, JOSE A SR       NaN       NaN           NaN
# 569548            ORTIZ, CARLOS M       NaN       NaN           NaN
#
#        BIZTELEPHONE EXPIRATION                      OWNER  \
# 47025           NaN 2017-05-27           BOLTON, MARION N
# 47026           NaN 2017-10-21       GONZALEZ, FELIX G JR
# 47027           NaN 2017-05-28          HERNANDEZ, RUFINO
# 47028           NaN 2016-06-18         COPELAND, MARCUS A
# 47029           NaN 2016-10-26          ANGLIN, DAVID LEE
# 47030           NaN 2016-10-21         VALLEJO, ARMANDO E
# 47031           NaN 2017-12-14        RODRIGUEZ, REYNALDO
# 47032           NaN 2017-06-03           TERRY, ALAN D JR
# 47033           NaN 2017-06-11           TREVINO, ADIEL A
# 47034           NaN 2017-11-17       ROACHELL, LAWRENCE S
# 47035           NaN 2017-06-07            RUSSELL, MARY A
# 47036           NaN 2017-12-12        BRIZENDINE, DEREK L
# 47037           NaN 2018-03-20            ALARCON, JUAN A
# 47038           NaN 2017-07-25  HERRERA ZAPATA, GUMECINDO
# 47039           NaN 2017-12-03         MARTINEZ, GILBERTO
# 47040           NaN 2017-02-19             FLORES, JAVIER
# 47041           NaN 2017-09-13              NGUYEN, DUC T
# 47042           NaN 2017-05-26           SANCHEZ, EFREN G
# 47043           NaN 2017-07-25          MCBRIDE, DEBORA K
# 47044           NaN 2017-04-12          GARZA, REYNALDO D
# 47045           NaN 2017-08-08        OLISON, DARRYL D SR
# 47046           NaN 2017-08-27          INGRAM, MICHAEL P
# 47047           NaN 2016-08-29       HARTER, RICHARD J JR
# 47048           NaN 2017-08-29          MADRIZ, ALEJANDRO
# 47049           NaN 2018-01-20             MOUNTS, TODD A
# 47050           NaN 2017-08-23           OSBORNE, JIMMY L
# 47051           NaN 2018-01-20           BOTELLO, JESUS B
# 47052           NaN 2017-06-22         DELGADO, SEVERIANO
# 47053           NaN 2018-01-25        GARCIA, FRANCISCO J
# 47054           NaN 2017-08-29               CRUZ, JUAN S
# ...             ...        ...                        ...
# 569519          NaN 2018-02-23             NAPOLI, ERON W
# 569520          NaN 2018-02-23               BRISENO, NOE
# 569521          NaN 2018-02-23       ALMOHAMMADI, SEYED B
# 569522          NaN 2018-02-24           GONZALES, JUAN G
# 569523          NaN 2018-02-24          NOEMI , NAVARRETE
# 569524          NaN 2018-02-24          MARTINEZ, ANTHONY
# 569525          NaN 2018-02-24            MIGUEL, SALAZAR
# 569526          NaN 2018-02-24        CALDERON, ANTONIO F
# 569527          NaN 2018-02-24            JALITT, CLAUDIO
# 569528          NaN 2018-02-24      SANCHEZ, ESTEBAN I SR
# 569529          NaN 2018-02-27            PICKENS, THOMAS
# 569530          NaN 2018-02-27             FLORES, MIGUEL
# 569531          NaN 2018-02-27             MUNIZ, BRAYN F
# 569532          NaN 2018-02-27         HARRISON, THOMAS D
# 569533          NaN 2018-02-27    BESIMER, FREDERIC B III
# 569534          NaN 2018-02-27        GOTT, CHRISTOPHER J
# 569535          NaN 2018-02-28      MONTGOMERY, TRISTAN D
# 569536          NaN 2018-02-28                SOTO, DANNY
# 569537          NaN 2018-02-28         WASHINGTON, JOSHUA
# 569538          NaN 2018-02-28         MARTINEZ, BENJAMIN
# 569539          NaN 2018-02-28        LOPEZ LEDEZMA, JOSE
# 569540          NaN 2018-02-28           URBINA, LEONARDO
# 569541          NaN 2018-03-01          STEPHEN, SCOTT SR
# 569542          NaN 2018-03-01            ORTIZ, HECTOR O
# 569543          NaN 2018-03-01          MORGAN, DOUGLAS A
# 569544          NaN 2018-03-01               ORTEGA, JUAN
# 569545          NaN 2018-03-01             BARR, SYLVIA M
# 569546          NaN 2018-03-01       MALFAVON, SALVADOR H
# 569547          NaN 2018-03-01          ARANDA, JOSE A SR
# 569548          NaN 2018-03-01            ORTIZ, CARLOS M
#
#                        MAILLINE1                    MAILLINE2  \
# 47025      2262 HARBOR BOLTON RD                          NaN
# 47026           8507 TIMBER BELT                          NaN
# 47027          1719 ROBINHOOD ST                          NaN
# 47028          201 N MADISON AVE                          NaN
# 47029               8066 FM 1001                          NaN
# 47030       3903 ERBY ST TRLR 88                          NaN
# 47031         10905 SHAWN LEE CV                          NaN
# 47032                605 KEASLER                          NaN
# 47033              3824 LYDIA ST                          NaN
# 47034       115 LAUREL MEADOW CT                          NaN
# 47035       16734 SUMMER DAWN LN                          NaN
# 47036       1900 COUNTY ROAD 228                          NaN
# 47037               4205 24TH ST                          NaN
# 47038         12031 REEDCREST ST                          NaN
# 47039                 PO BOX 705                          NaN
# 47040   5402 FM 1488 RD APT 1124                          NaN
# 47041            12503 LEADER ST                          NaN
# 47042              509 8TH ST SE                          NaN
# 47043                PO BOX 3463                          NaN
# 47044    6806 ALDERSON ST # 6806                          NaN
# 47045            137 WILLIAMS LN                          NaN
# 47046           506 SHADY OAK ST                          NaN
# 47047               2291 MARY LN                          NaN
# 47048            108 GRANTHAM RD                          NaN
# 47049          2705 S HOUSTON DR                          NaN
# 47050      3021 QUAIL HOLLOW CIR                          NaN
# 47051       402 GARNER RD APT 62                          NaN
# 47052          8422 BROOKSIDE RD                          NaN
# 47053           4205 24TH STREET                          NaN
# 47054          9611 STOCKWELL DR                          NaN
# ...                          ...                          ...
# 569519      10612 FM 1764 RD # 4                          NaN
# 569520           4006 WINDSOR DR                          NaN
# 569521    224 SAMUEL BLVD APT 6K                          NaN
# 569522       10407 COPPERDALE LN                          NaN
# 569523            6931 SIGNAT DR                          NaN
# 569524              121 KUNZE DR                          NaN
# 569525           382 TAMPICO AVE                          NaN
# 569526           11139 DENTON DR                          NaN
# 569527        1125 SHADYGLEN CIR                          NaN
# 569528        451 N HOMESTEAD RD                          NaN
# 569529            203 W ALAMO ST                          NaN
# 569530          9634 SALTILLO ST                          NaN
# 569531            205 ISHMEAL ST                          NaN
# 569532        13202 N NAVARRO ST                          NaN
# 569533                   STE 400  24501 HUFSMITH KOHRVILLE RD
# 569534      842 COUNTY ROAD 3709                          NaN
# 569535            4001 WAGON TRL                          NaN
# 569536            27255 KATY FWY                          NaN
# 569537            105 BAYONNE DR                          NaN
# 569538          350 TRUMBULL CIR                          NaN
# 569539                 PO BOX 78                          NaN
# 569540             607 MIDWAY RD                          NaN
# 569541        1206 W STRONG PKWY                          NaN
# 569542          2864 GLYNWOOD DR                          NaN
# 569543            1301 THOMAS DR                          NaN
# 569544               128 JUAN CT                          NaN
# 569545         1015 RIVERVIEW DR                          NaN
# 569546          1237 E CENTER ST                          NaN
# 569547           1108 IRELAND ST                          NaN
# 569548              480 BLAND DR                          NaN
#
#                        MAILCITYSTATE MAILCOUNTYCODE    MAILCOUNTY MAILZIP  \
# 47025         FRANKLIN TX 77856-5367           0395     ROBERTSON   77856
# 47026      SAN ANTONIO TX 78250-4478           0029         BEXAR   78250
# 47027         PASADENA TX 77502-2218           0201        HARRIS   77502
# 47028   MOUNT PLEASANT TX 75455-3944           0449         TITUS   75455
# 47029        COOKVILLE TX 75558-3064           0449         TITUS   75558
# 47030          HOUSTON TX 77087-1250           0201        HARRIS   77087
# 47031           AUSTIN TX 78753-3363           0453        TRAVIS   78753
# 47032   HUGHES SPRINGS TX 75656-2575           0067          CASS   75656
# 47033          HOUSTON TX 77021-6125           0201        HARRIS   77021
# 47034        LA MARQUE TX 77568-2497           0167     GALVESTON   77568
# 47035          HOUSTON TX 77095-1253           0201        HARRIS   77095
# 47036         FLORENCE TX 76527-3903           0491    WILLIAMSON   76527
# 47037        DICKINSON TX 77539-8172           0167     GALVESTON   77539
# 47038          HOUSTON TX 77085-1113           0201        HARRIS   77085
# 47039         ROSHARON TX 77583-0705           0039      BRAZORIA   77583
# 47040         MAGNOLIA TX 77354-3578           0339    MONTGOMERY   77354
# 47041          HOUSTON TX 77072-2468           0201        HARRIS   77072
# 47042            PARIS TX 75460-7329           0277         LAMAR   75460
# 47043     LAKE JACKSON TX 77566-3463           0039      BRAZORIA   77566
# 47044          HOUSTON TX 77020-3244           0201        HARRIS   77020
# 47045            ALVIN TX 77511-1043           0039      BRAZORIA   77511
# 47046           BURNET TX 78611-2639           0053        BURNET   78611
# 47047        DICKINSON TX 77539-9276           0167     GALVESTON   77539
# 47048          BAYTOWN TX 77521-4217           0201        HARRIS   77521
# 47049        LA MARQUE TX 77568-5015           0167     GALVESTON   77568
# 47050          BAYTOWN TX 77521-2015           0201        HARRIS   77521
# 47051         PASADENA TX 77502-2108           0201        HARRIS   77502
# 47052         PEARLAND TX 77581-7317           0039      BRAZORIA   77581
# 47053        DICKINSON TX 77539-8172           0167     GALVESTON   77539
# 47054          HOUSTON TX 77083-5940           0201        HARRIS   77083
# ...                              ...            ...           ...     ...
# 569519        SANTA FE TX 77510-8061           0167     GALVESTON   77510
# 569520         GARLAND TX 75042-5207           0113        DALLAS   75042
# 569521         COPPELL TX 75019-5262           0113        DALLAS   75019
# 569522         HOUSTON TX 77064-7145           0201        HARRIS   77064
# 569523         HOUSTON TX 77041-2718           0201        HARRIS   77041
# 569524   SAINT CHARLES MO 63303-5928           0999  OUT OF STATE   63303
# 569525    RAYMONDVILLE TX 78580-1747           0489       WILLACY   78580
# 569526          DALLAS TX 75229-4706           0113        DALLAS   75229
# 569527      RICHARDSON TX 75081-3720           0113        DALLAS   75081
# 569528          UVALDE TX 78801-7666           0463        UVALDE   78801
# 569529         TERRELL TX 75160-2130           0257       KAUFMAN   75160
# 569530         HOUSTON TX 77013-3829           0201        HARRIS   77013
# 569531         HOUSTON TX 77076-3911           0201        HARRIS   77076
# 569532        VICTORIA TX 77904-1404           0469      VICTORIA   77904
# 569533         TOMBALL TX 77375-6932           0201        HARRIS   77375
# 569534       SPLENDORA TX 77372-9537           0339    MONTGOMERY   77372
# 569535          TEMPLE TX 76502-2121           0027          BELL   76502
# 569536            KATY TX 77494-1073           0157     FORT BEND   77494
# 569537       MANSFIELD TX 76063-5526           0439       TARRANT   76063
# 569538          FERRIS TX 75125-8413           0139         ELLIS   75125
# 569539           MANOR TX 78653-0078           0453        TRAVIS   78653
# 569540      SEAGOVILLE TX 75159-1913           0113        DALLAS   75159
# 569541   GRAND PRAIRIE TX 75050-5330           0113        DALLAS   75050
# 569542     BROWNSVILLE TX 78526-4418           0061       CAMERON   78526
# 569543     FRIENDSWOOD TX 77546-2022           0201        HARRIS   77546
# 569544     HUDSON OAKS TX 76087-8337           0367        PARKER   76087
# 569545        FAIRMONT WV 26554-8309           0999  OUT OF STATE   26554
# 569546       KINGSPORT TN 37660-4945           0999  OUT OF STATE   37660
# 569547   WICHITA FALLS TX 76301-7837           0485       WICHITA   76301
# 569548     BRIDGE CITY TX 77611-4614           0361        ORANGE   77611
#
#          TELEPHONE LICSUBTYPE CEFLAG
# 47025   9798284713         AE      N
# 47026   2104887491         AE      N
# 47027   7133824802         AE      N
# 47028   9035634950         AE      N
# 47029   9039462547         AE      N
# 47030   8325285241         AE      N
# 47031   7372474738         AE      N
# 47032   9036392017         AE      N
# 47033   7134406945         AE      N
# 47034   4095390843         AE      N
# 47035   8323098491         AE      N
# 47036   2543192035         AE      N
# 47037   8327381356         AE      N
# 47038   7137214669         AE      N
# 47039   7133920280         AE      N
# 47040   7138225726         AE      N
# 47041   7132691041         AE      N
# 47042   9032276918         AE      N
# 47043   9796658700         AE      N
# 47044   7136762352         AE      N
# 47045   4097399612         AE      N
# 47046   5124702626         AE      N
# 47047   2819102908         AE      N
# 47048   8328530763         AE      N
# 47049   3462080924         AE      N
# 47050   8325972890         AE      N
# 47051   8323509473         AE      N
# 47052   8327369000         AE      N
# 47053   8327381356         AE      N
# 47054   7139722948         AE      N
# ...            ...        ...    ...
# 569519  4099253357         SA      N
# 569520  2144042443         SA      N
# 569521  9728393089         SA      N
# 569522  8329960375         SA      N
# 569523  2813454488         SA      N
# 569524  6363730961         SA      N
# 569525  9567896672         SA      N
# 569526  9722417446         SA      N
# 569527  2144757318         SA      N
# 569528  8309002628         SA      N
# 569529  4694745309         SA      N
# 569530  8322989252         SA      N
# 569531  8327397104         SA      N
# 569532  3617039035         SA      N
# 569533  3134072437         SA      N
# 569534  2816223970         SA      N
# 569535  2549135913         SA      N
# 569536  2813922828         SA      N
# 569537  8177514838         SA      N
# 569538  2148836327         SA      N
# 569539  7372028067         SA      N
# 569540  2145361782         SA      N
# 569541  4692164741         SA      N
# 569542  9565591718         SA      N
# 569543  4094975341         SA      N
# 569544  8173746117         SA      N
# 569545  3047779007         SA      N
# 569546  4237656317         SA      N
# 569547  9408674318         SA      N
# 569548  4093133718         SA      N
#
# [171838 rows x 19 columns]

# %% [markdown]
# This doesn't work when trying to select electricians, though, as NaN is a no-go for a filter. We *could* filter out everywhere the LICTYPE is null, but we could also cheat a little and say "replace all of the `NaN` values with `False` values."
#
# `.fillna(False)` will take every `NaN` and replace it with `False`.

# %%
df[df['LICTYPE'].str.contains("Electrician").fillna(False)]
# Out:
#                             LICTYPE LICNUMBER     BIZCOUNTY  \
# 47025        Apprentice Electrician     30244     ROBERTSON
# 47026        Apprentice Electrician     30798         BEXAR
# 47027        Apprentice Electrician     30802        HARRIS
# 47028        Apprentice Electrician     31875         TITUS
# 47029        Apprentice Electrician     31876         TITUS
# 47030        Apprentice Electrician     32428        HARRIS
# 47031        Apprentice Electrician     32440        TRAVIS
# 47032        Apprentice Electrician     32442          CASS
# 47033        Apprentice Electrician     32450        HARRIS
# 47034        Apprentice Electrician     32453     GALVESTON
# 47035        Apprentice Electrician     33313        HARRIS
# 47036        Apprentice Electrician     33316    WILLIAMSON
# 47037        Apprentice Electrician     33329     GALVESTON
# 47038        Apprentice Electrician     33335        HARRIS
# 47039        Apprentice Electrician     33336      BRAZORIA
# 47040        Apprentice Electrician     33337    MONTGOMERY
# 47041        Apprentice Electrician     33339        HARRIS
# 47042        Apprentice Electrician     33342         LAMAR
# 47043        Apprentice Electrician     33343      BRAZORIA
# 47044        Apprentice Electrician     33353        HARRIS
# 47045        Apprentice Electrician     33355      BRAZORIA
# 47046        Apprentice Electrician     33357        BURNET
# 47047        Apprentice Electrician     33363     GALVESTON
# 47048        Apprentice Electrician     33365        HARRIS
# 47049        Apprentice Electrician     33368     GALVESTON
# 47050        Apprentice Electrician     33369        HARRIS
# 47051        Apprentice Electrician     33778        HARRIS
# 47052        Apprentice Electrician     33779      BRAZORIA
# 47053        Apprentice Electrician     33783     GALVESTON
# 47054        Apprentice Electrician     33790        HARRIS
# ...                             ...       ...           ...
# 569519  Apprentice Sign Electrician    393100     GALVESTON
# 569520  Apprentice Sign Electrician    393101        DALLAS
# 569521  Apprentice Sign Electrician    393102        DALLAS
# 569522  Apprentice Sign Electrician    393212        HARRIS
# 569523  Apprentice Sign Electrician    393213        HARRIS
# 569524  Apprentice Sign Electrician    393214  OUT OF STATE
# 569525  Apprentice Sign Electrician    393215       WILLACY
# 569526  Apprentice Sign Electrician    393216        DALLAS
# 569527  Apprentice Sign Electrician    393217        DALLAS
# 569528  Apprentice Sign Electrician    393218        UVALDE
# 569529  Apprentice Sign Electrician    393399       KAUFMAN
# 569530  Apprentice Sign Electrician    393400        HARRIS
# 569531  Apprentice Sign Electrician    393401        HARRIS
# 569532  Apprentice Sign Electrician    393402      VICTORIA
# 569533  Apprentice Sign Electrician    393403        HARRIS
# 569534  Apprentice Sign Electrician    393404    MONTGOMERY
# 569535  Apprentice Sign Electrician    393523          BELL
# 569536  Apprentice Sign Electrician    393524     FORT BEND
# 569537  Apprentice Sign Electrician    393525       TARRANT
# 569538  Apprentice Sign Electrician    393526         ELLIS
# 569539  Apprentice Sign Electrician    393527        TRAVIS
# 569540  Apprentice Sign Electrician    393528        DALLAS
# 569541  Apprentice Sign Electrician    393606        DALLAS
# 569542  Apprentice Sign Electrician    393607       CAMERON
# 569543  Apprentice Sign Electrician    393608        HARRIS
# 569544  Apprentice Sign Electrician    393609        PARKER
# 569545  Apprentice Sign Electrician    393610  OUT OF STATE
# 569546  Apprentice Sign Electrician    393611  OUT OF STATE
# 569547  Apprentice Sign Electrician    393612       WICHITA
# 569548  Apprentice Sign Electrician    393613        ORANGE
#
#                           BIZNAME  BIZLINE1  BIZLINE2  BIZCITYSTATE  \
# 47025            BOLTON, MARION N       NaN       NaN           NaN
# 47026        GONZALEZ, FELIX G JR       NaN       NaN           NaN
# 47027           HERNANDEZ, RUFINO       NaN       NaN           NaN
# 47028          COPELAND, MARCUS A       NaN       NaN           NaN
# 47029           ANGLIN, DAVID LEE       NaN       NaN           NaN
# 47030          VALLEJO, ARMANDO E       NaN       NaN           NaN
# 47031         RODRIGUEZ, REYNALDO       NaN       NaN           NaN
# 47032            TERRY, ALAN D JR       NaN       NaN           NaN
# 47033            TREVINO, ADIEL A       NaN       NaN           NaN
# 47034        ROACHELL, LAWRENCE S       NaN       NaN           NaN
# 47035             RUSSELL, MARY A       NaN       NaN           NaN
# 47036         BRIZENDINE, DEREK L       NaN       NaN           NaN
# 47037             ALARCON, JUAN A       NaN       NaN           NaN
# 47038   HERRERA ZAPATA, GUMECINDO       NaN       NaN           NaN
# 47039          MARTINEZ, GILBERTO       NaN       NaN           NaN
# 47040              FLORES, JAVIER       NaN       NaN           NaN
# 47041               NGUYEN, DUC T       NaN       NaN           NaN
# 47042            SANCHEZ, EFREN G       NaN       NaN           NaN
# 47043           MCBRIDE, DEBORA K       NaN       NaN           NaN
# 47044           GARZA, REYNALDO D       NaN       NaN           NaN
# 47045         OLISON, DARRYL D SR       NaN       NaN           NaN
# 47046           INGRAM, MICHAEL P       NaN       NaN           NaN
# 47047        HARTER, RICHARD J JR       NaN       NaN           NaN
# 47048           MADRIZ, ALEJANDRO       NaN       NaN           NaN
# 47049              MOUNTS, TODD A       NaN       NaN           NaN
# 47050            OSBORNE, JIMMY L       NaN       NaN           NaN
# 47051            BOTELLO, JESUS B       NaN       NaN           NaN
# 47052          DELGADO, SEVERIANO       NaN       NaN           NaN
# 47053         GARCIA, FRANCISCO J       NaN       NaN           NaN
# 47054                CRUZ, JUAN S       NaN       NaN           NaN
# ...                           ...       ...       ...           ...
# 569519             NAPOLI, ERON W       NaN       NaN           NaN
# 569520               BRISENO, NOE       NaN       NaN           NaN
# 569521       ALMOHAMMADI, SEYED B       NaN       NaN           NaN
# 569522           GONZALES, JUAN G       NaN       NaN           NaN
# 569523          NOEMI , NAVARRETE       NaN       NaN           NaN
# 569524          MARTINEZ, ANTHONY       NaN       NaN           NaN
# 569525            MIGUEL, SALAZAR       NaN       NaN           NaN
# 569526        CALDERON, ANTONIO F       NaN       NaN           NaN
# 569527            JALITT, CLAUDIO       NaN       NaN           NaN
# 569528      SANCHEZ, ESTEBAN I SR       NaN       NaN           NaN
# 569529            PICKENS, THOMAS       NaN       NaN           NaN
# 569530             FLORES, MIGUEL       NaN       NaN           NaN
# 569531             MUNIZ, BRAYN F       NaN       NaN           NaN
# 569532         HARRISON, THOMAS D       NaN       NaN           NaN
# 569533    BESIMER, FREDERIC B III       NaN       NaN           NaN
# 569534        GOTT, CHRISTOPHER J       NaN       NaN           NaN
# 569535      MONTGOMERY, TRISTAN D       NaN       NaN           NaN
# 569536                SOTO, DANNY       NaN       NaN           NaN
# 569537         WASHINGTON, JOSHUA       NaN       NaN           NaN
# 569538         MARTINEZ, BENJAMIN       NaN       NaN           NaN
# 569539        LOPEZ LEDEZMA, JOSE       NaN       NaN           NaN
# 569540           URBINA, LEONARDO       NaN       NaN           NaN
# 569541          STEPHEN, SCOTT SR       NaN       NaN           NaN
# 569542            ORTIZ, HECTOR O       NaN       NaN           NaN
# 569543          MORGAN, DOUGLAS A       NaN       NaN           NaN
# 569544               ORTEGA, JUAN       NaN       NaN           NaN
# 569545             BARR, SYLVIA M       NaN       NaN           NaN
# 569546       MALFAVON, SALVADOR H       NaN       NaN           NaN
# 569547          ARANDA, JOSE A SR       NaN       NaN           NaN
# 569548            ORTIZ, CARLOS M       NaN       NaN           NaN
#
#        BIZTELEPHONE EXPIRATION                      OWNER  \
# 47025           NaN 2017-05-27           BOLTON, MARION N
# 47026           NaN 2017-10-21       GONZALEZ, FELIX G JR
# 47027           NaN 2017-05-28          HERNANDEZ, RUFINO
# 47028           NaN 2016-06-18         COPELAND, MARCUS A
# 47029           NaN 2016-10-26          ANGLIN, DAVID LEE
# 47030           NaN 2016-10-21         VALLEJO, ARMANDO E
# 47031           NaN 2017-12-14        RODRIGUEZ, REYNALDO
# 47032           NaN 2017-06-03           TERRY, ALAN D JR
# 47033           NaN 2017-06-11           TREVINO, ADIEL A
# 47034           NaN 2017-11-17       ROACHELL, LAWRENCE S
# 47035           NaN 2017-06-07            RUSSELL, MARY A
# 47036           NaN 2017-12-12        BRIZENDINE, DEREK L
# 47037           NaN 2018-03-20            ALARCON, JUAN A
# 47038           NaN 2017-07-25  HERRERA ZAPATA, GUMECINDO
# 47039           NaN 2017-12-03         MARTINEZ, GILBERTO
# 47040           NaN 2017-02-19             FLORES, JAVIER
# 47041           NaN 2017-09-13              NGUYEN, DUC T
# 47042           NaN 2017-05-26           SANCHEZ, EFREN G
# 47043           NaN 2017-07-25          MCBRIDE, DEBORA K
# 47044           NaN 2017-04-12          GARZA, REYNALDO D
# 47045           NaN 2017-08-08        OLISON, DARRYL D SR
# 47046           NaN 2017-08-27          INGRAM, MICHAEL P
# 47047           NaN 2016-08-29       HARTER, RICHARD J JR
# 47048           NaN 2017-08-29          MADRIZ, ALEJANDRO
# 47049           NaN 2018-01-20             MOUNTS, TODD A
# 47050           NaN 2017-08-23           OSBORNE, JIMMY L
# 47051           NaN 2018-01-20           BOTELLO, JESUS B
# 47052           NaN 2017-06-22         DELGADO, SEVERIANO
# 47053           NaN 2018-01-25        GARCIA, FRANCISCO J
# 47054           NaN 2017-08-29               CRUZ, JUAN S
# ...             ...        ...                        ...
# 569519          NaN 2018-02-23             NAPOLI, ERON W
# 569520          NaN 2018-02-23               BRISENO, NOE
# 569521          NaN 2018-02-23       ALMOHAMMADI, SEYED B
# 569522          NaN 2018-02-24           GONZALES, JUAN G
# 569523          NaN 2018-02-24          NOEMI , NAVARRETE
# 569524          NaN 2018-02-24          MARTINEZ, ANTHONY
# 569525          NaN 2018-02-24            MIGUEL, SALAZAR
# 569526          NaN 2018-02-24        CALDERON, ANTONIO F
# 569527          NaN 2018-02-24            JALITT, CLAUDIO
# 569528          NaN 2018-02-24      SANCHEZ, ESTEBAN I SR
# 569529          NaN 2018-02-27            PICKENS, THOMAS
# 569530          NaN 2018-02-27             FLORES, MIGUEL
# 569531          NaN 2018-02-27             MUNIZ, BRAYN F
# 569532          NaN 2018-02-27         HARRISON, THOMAS D
# 569533          NaN 2018-02-27    BESIMER, FREDERIC B III
# 569534          NaN 2018-02-27        GOTT, CHRISTOPHER J
# 569535          NaN 2018-02-28      MONTGOMERY, TRISTAN D
# 569536          NaN 2018-02-28                SOTO, DANNY
# 569537          NaN 2018-02-28         WASHINGTON, JOSHUA
# 569538          NaN 2018-02-28         MARTINEZ, BENJAMIN
# 569539          NaN 2018-02-28        LOPEZ LEDEZMA, JOSE
# 569540          NaN 2018-02-28           URBINA, LEONARDO
# 569541          NaN 2018-03-01          STEPHEN, SCOTT SR
# 569542          NaN 2018-03-01            ORTIZ, HECTOR O
# 569543          NaN 2018-03-01          MORGAN, DOUGLAS A
# 569544          NaN 2018-03-01               ORTEGA, JUAN
# 569545          NaN 2018-03-01             BARR, SYLVIA M
# 569546          NaN 2018-03-01       MALFAVON, SALVADOR H
# 569547          NaN 2018-03-01          ARANDA, JOSE A SR
# 569548          NaN 2018-03-01            ORTIZ, CARLOS M
#
#                        MAILLINE1                    MAILLINE2  \
# 47025      2262 HARBOR BOLTON RD                          NaN
# 47026           8507 TIMBER BELT                          NaN
# 47027          1719 ROBINHOOD ST                          NaN
# 47028          201 N MADISON AVE                          NaN
# 47029               8066 FM 1001                          NaN
# 47030       3903 ERBY ST TRLR 88                          NaN
# 47031         10905 SHAWN LEE CV                          NaN
# 47032                605 KEASLER                          NaN
# 47033              3824 LYDIA ST                          NaN
# 47034       115 LAUREL MEADOW CT                          NaN
# 47035       16734 SUMMER DAWN LN                          NaN
# 47036       1900 COUNTY ROAD 228                          NaN
# 47037               4205 24TH ST                          NaN
# 47038         12031 REEDCREST ST                          NaN
# 47039                 PO BOX 705                          NaN
# 47040   5402 FM 1488 RD APT 1124                          NaN
# 47041            12503 LEADER ST                          NaN
# 47042              509 8TH ST SE                          NaN
# 47043                PO BOX 3463                          NaN
# 47044    6806 ALDERSON ST # 6806                          NaN
# 47045            137 WILLIAMS LN                          NaN
# 47046           506 SHADY OAK ST                          NaN
# 47047               2291 MARY LN                          NaN
# 47048            108 GRANTHAM RD                          NaN
# 47049          2705 S HOUSTON DR                          NaN
# 47050      3021 QUAIL HOLLOW CIR                          NaN
# 47051       402 GARNER RD APT 62                          NaN
# 47052          8422 BROOKSIDE RD                          NaN
# 47053           4205 24TH STREET                          NaN
# 47054          9611 STOCKWELL DR                          NaN
# ...                          ...                          ...
# 569519      10612 FM 1764 RD # 4                          NaN
# 569520           4006 WINDSOR DR                          NaN
# 569521    224 SAMUEL BLVD APT 6K                          NaN
# 569522       10407 COPPERDALE LN                          NaN
# 569523            6931 SIGNAT DR                          NaN
# 569524              121 KUNZE DR                          NaN
# 569525           382 TAMPICO AVE                          NaN
# 569526           11139 DENTON DR                          NaN
# 569527        1125 SHADYGLEN CIR                          NaN
# 569528        451 N HOMESTEAD RD                          NaN
# 569529            203 W ALAMO ST                          NaN
# 569530          9634 SALTILLO ST                          NaN
# 569531            205 ISHMEAL ST                          NaN
# 569532        13202 N NAVARRO ST                          NaN
# 569533                   STE 400  24501 HUFSMITH KOHRVILLE RD
# 569534      842 COUNTY ROAD 3709                          NaN
# 569535            4001 WAGON TRL                          NaN
# 569536            27255 KATY FWY                          NaN
# 569537            105 BAYONNE DR                          NaN
# 569538          350 TRUMBULL CIR                          NaN
# 569539                 PO BOX 78                          NaN
# 569540             607 MIDWAY RD                          NaN
# 569541        1206 W STRONG PKWY                          NaN
# 569542          2864 GLYNWOOD DR                          NaN
# 569543            1301 THOMAS DR                          NaN
# 569544               128 JUAN CT                          NaN
# 569545         1015 RIVERVIEW DR                          NaN
# 569546          1237 E CENTER ST                          NaN
# 569547           1108 IRELAND ST                          NaN
# 569548              480 BLAND DR                          NaN
#
#                        MAILCITYSTATE MAILCOUNTYCODE    MAILCOUNTY MAILZIP  \
# 47025         FRANKLIN TX 77856-5367           0395     ROBERTSON   77856
# 47026      SAN ANTONIO TX 78250-4478           0029         BEXAR   78250
# 47027         PASADENA TX 77502-2218           0201        HARRIS   77502
# 47028   MOUNT PLEASANT TX 75455-3944           0449         TITUS   75455
# 47029        COOKVILLE TX 75558-3064           0449         TITUS   75558
# 47030          HOUSTON TX 77087-1250           0201        HARRIS   77087
# 47031           AUSTIN TX 78753-3363           0453        TRAVIS   78753
# 47032   HUGHES SPRINGS TX 75656-2575           0067          CASS   75656
# 47033          HOUSTON TX 77021-6125           0201        HARRIS   77021
# 47034        LA MARQUE TX 77568-2497           0167     GALVESTON   77568
# 47035          HOUSTON TX 77095-1253           0201        HARRIS   77095
# 47036         FLORENCE TX 76527-3903           0491    WILLIAMSON   76527
# 47037        DICKINSON TX 77539-8172           0167     GALVESTON   77539
# 47038          HOUSTON TX 77085-1113           0201        HARRIS   77085
# 47039         ROSHARON TX 77583-0705           0039      BRAZORIA   77583
# 47040         MAGNOLIA TX 77354-3578           0339    MONTGOMERY   77354
# 47041          HOUSTON TX 77072-2468           0201        HARRIS   77072
# 47042            PARIS TX 75460-7329           0277         LAMAR   75460
# 47043     LAKE JACKSON TX 77566-3463           0039      BRAZORIA   77566
# 47044          HOUSTON TX 77020-3244           0201        HARRIS   77020
# 47045            ALVIN TX 77511-1043           0039      BRAZORIA   77511
# 47046           BURNET TX 78611-2639           0053        BURNET   78611
# 47047        DICKINSON TX 77539-9276           0167     GALVESTON   77539
# 47048          BAYTOWN TX 77521-4217           0201        HARRIS   77521
# 47049        LA MARQUE TX 77568-5015           0167     GALVESTON   77568
# 47050          BAYTOWN TX 77521-2015           0201        HARRIS   77521
# 47051         PASADENA TX 77502-2108           0201        HARRIS   77502
# 47052         PEARLAND TX 77581-7317           0039      BRAZORIA   77581
# 47053        DICKINSON TX 77539-8172           0167     GALVESTON   77539
# 47054          HOUSTON TX 77083-5940           0201        HARRIS   77083
# ...                              ...            ...           ...     ...
# 569519        SANTA FE TX 77510-8061           0167     GALVESTON   77510
# 569520         GARLAND TX 75042-5207           0113        DALLAS   75042
# 569521         COPPELL TX 75019-5262           0113        DALLAS   75019
# 569522         HOUSTON TX 77064-7145           0201        HARRIS   77064
# 569523         HOUSTON TX 77041-2718           0201        HARRIS   77041
# 569524   SAINT CHARLES MO 63303-5928           0999  OUT OF STATE   63303
# 569525    RAYMONDVILLE TX 78580-1747           0489       WILLACY   78580
# 569526          DALLAS TX 75229-4706           0113        DALLAS   75229
# 569527      RICHARDSON TX 75081-3720           0113        DALLAS   75081
# 569528          UVALDE TX 78801-7666           0463        UVALDE   78801
# 569529         TERRELL TX 75160-2130           0257       KAUFMAN   75160
# 569530         HOUSTON TX 77013-3829           0201        HARRIS   77013
# 569531         HOUSTON TX 77076-3911           0201        HARRIS   77076
# 569532        VICTORIA TX 77904-1404           0469      VICTORIA   77904
# 569533         TOMBALL TX 77375-6932           0201        HARRIS   77375
# 569534       SPLENDORA TX 77372-9537           0339    MONTGOMERY   77372
# 569535          TEMPLE TX 76502-2121           0027          BELL   76502
# 569536            KATY TX 77494-1073           0157     FORT BEND   77494
# 569537       MANSFIELD TX 76063-5526           0439       TARRANT   76063
# 569538          FERRIS TX 75125-8413           0139         ELLIS   75125
# 569539           MANOR TX 78653-0078           0453        TRAVIS   78653
# 569540      SEAGOVILLE TX 75159-1913           0113        DALLAS   75159
# 569541   GRAND PRAIRIE TX 75050-5330           0113        DALLAS   75050
# 569542     BROWNSVILLE TX 78526-4418           0061       CAMERON   78526
# 569543     FRIENDSWOOD TX 77546-2022           0201        HARRIS   77546
# 569544     HUDSON OAKS TX 76087-8337           0367        PARKER   76087
# 569545        FAIRMONT WV 26554-8309           0999  OUT OF STATE   26554
# 569546       KINGSPORT TN 37660-4945           0999  OUT OF STATE   37660
# 569547   WICHITA FALLS TX 76301-7837           0485       WICHITA   76301
# 569548     BRIDGE CITY TX 77611-4614           0361        ORANGE   77611
#
#          TELEPHONE LICSUBTYPE CEFLAG
# 47025   9798284713         AE      N
# 47026   2104887491         AE      N
# 47027   7133824802         AE      N
# 47028   9035634950         AE      N
# 47029   9039462547         AE      N
# 47030   8325285241         AE      N
# 47031   7372474738         AE      N
# 47032   9036392017         AE      N
# 47033   7134406945         AE      N
# 47034   4095390843         AE      N
# 47035   8323098491         AE      N
# 47036   2543192035         AE      N
# 47037   8327381356         AE      N
# 47038   7137214669         AE      N
# 47039   7133920280         AE      N
# 47040   7138225726         AE      N
# 47041   7132691041         AE      N
# 47042   9032276918         AE      N
# 47043   9796658700         AE      N
# 47044   7136762352         AE      N
# 47045   4097399612         AE      N
# 47046   5124702626         AE      N
# 47047   2819102908         AE      N
# 47048   8328530763         AE      N
# 47049   3462080924         AE      N
# 47050   8325972890         AE      N
# 47051   8323509473         AE      N
# 47052   8327369000         AE      N
# 47053   8327381356         AE      N
# 47054   7139722948         AE      N
# ...            ...        ...    ...
# 569519  4099253357         SA      N
# 569520  2144042443         SA      N
# 569521  9728393089         SA      N
# 569522  8329960375         SA      N
# 569523  2813454488         SA      N
# 569524  6363730961         SA      N
# 569525  9567896672         SA      N
# 569526  9722417446         SA      N
# 569527  2144757318         SA      N
# 569528  8309002628         SA      N
# 569529  4694745309         SA      N
# 569530  8322989252         SA      N
# 569531  8327397104         SA      N
# 569532  3617039035         SA      N
# 569533  3134072437         SA      N
# 569534  2816223970         SA      N
# 569535  2549135913         SA      N
# 569536  2813922828         SA      N
# 569537  8177514838         SA      N
# 569538  2148836327         SA      N
# 569539  7372028067         SA      N
# 569540  2145361782         SA      N
# 569541  4692164741         SA      N
# 569542  9565591718         SA      N
# 569543  4094975341         SA      N
# 569544  8173746117         SA      N
# 569545  3047779007         SA      N
# 569546  4237656317         SA      N
# 569547  9408674318         SA      N
# 569548  4093133718         SA      N
#
# [171838 rows x 19 columns]

# %% [markdown]
# ## 10. What's the most popular kind of electrician?

# %%
df[df['LICTYPE'].str.contains("Electrician").fillna(False)].LICTYPE.value_counts().head(1)
# Out:
# Apprentice Electrician    110593
# Name: LICTYPE, dtype: int64

# %% [markdown]
# ## 11. Graph it, with the largest bar on top.

# %%
df[df['LICTYPE'].str.contains("Electrician").fillna(False)].LICTYPE.value_counts().sort_values().plot(kind='barh')

# %% [markdown]
# ## 12. How many sign electricians are there?
#
# There are a few ways to do this one.

# %%
df['LICTYPE'].str.contains("Sign Electrician",na=False).sum()
# Out:
# 4927

# %% [markdown]
# # PART THREE: LOOKING AT LAST NAMES

# %% [markdown]
# ## 13. Extract every owner's last name
#
# You want everything before the comma. We've done this before (in a few different ways!).
#
# * **Hint:** If you get an error about missing or `NaN` data, you might use `.fillna('')` to replace every empty owner name with an empty string. This might not happen to you, though, depending on how you do it!
#
# * **Hint:** You probably want to do `expand=False` on your extraction to make sure it comes out as a series instead of a dataframe.

# %%
df['OWNER'].str.split(',').str[0]
# Out:
# 0            RISINGER
# 1            WILLIAMS
# 2             GUEVARA
# 3              BOWERS
# 4              DEMSKY
# 5            THOMPSON
# 6              TUCKER
# 7              COOPER
# 8         BLANKENSHIP
# 9               DAWES
# 10             LESTER
# 11            MANCILL
# 12         HUDDLESTON
# 13             JORDAN
# 14              IRWIN
# 15               HALL
# 16              JAMES
# 17             SIDAWI
# 18              SMITH
# 19           FERGUSON
# 20           MCKINLEY
# 21             SOWELL
# 22             SEVIER
# 23         SOMERVILLE
# 24           BARCLIFT
# 25               FORD
# 26            SCHAFER
# 27           MARTINEZ
# 28            CLEMANS
# 29           MARTINEZ
#              ...
# 597786        SNUFFER
# 597787       MARTINEZ
# 597788         YOSTEN
# 597789          CLICK
# 597790          PENSE
# 597791           LARA
# 597792          SMITH
# 597793      BINNICKER
# 597794         CHAVEZ
# 597795       GUERRERO
# 597796         SAVAGE
# 597797          ADAMS
# 597798          SCOTT
# 597799           HILL
# 597800       THOMPSON
# 597801         THOMAS
# 597802      JURGENSEN
# 597803          MARSH
# 597804       KILLOUGH
# 597805         FAULKS
# 597806         ATKINS
# 597807       WILLIAMS
# 597808       WINSTEAD
# 597809         LILLEY
# 597810          WOODS
# 597811           ABEL
# 597812           GRAY
# 597813          MAYER
# 597814        FRIESEN
# 597815          BAUER
# Name: OWNER, Length: 597816, dtype: object

# %%
df['OWNER'].str.extract('(.*),',expand=False)
# Out:
# 0            RISINGER
# 1            WILLIAMS
# 2             GUEVARA
# 3              BOWERS
# 4              DEMSKY
# 5            THOMPSON
# 6              TUCKER
# 7              COOPER
# 8         BLANKENSHIP
# 9               DAWES
# 10             LESTER
# 11            MANCILL
# 12         HUDDLESTON
# 13             JORDAN
# 14              IRWIN
# 15               HALL
# 16              JAMES
# 17             SIDAWI
# 18              SMITH
# 19           FERGUSON
# 20           MCKINLEY
# 21             SOWELL
# 22             SEVIER
# 23         SOMERVILLE
# 24           BARCLIFT
# 25               FORD
# 26            SCHAFER
# 27           MARTINEZ
# 28            CLEMANS
# 29           MARTINEZ
#              ...
# 597786        SNUFFER
# 597787       MARTINEZ
# 597788         YOSTEN
# 597789          CLICK
# 597790          PENSE
# 597791           LARA
# 597792          SMITH
# 597793      BINNICKER
# 597794         CHAVEZ
# 597795       GUERRERO
# 597796         SAVAGE
# 597797          ADAMS
# 597798          SCOTT
# 597799           HILL
# 597800       THOMPSON
# 597801         THOMAS
# 597802      JURGENSEN
# 597803          MARSH
# 597804       KILLOUGH
# 597805         FAULKS
# 597806         ATKINS
# 597807       WILLIAMS
# 597808       WINSTEAD
# 597809         LILLEY
# 597810          WOODS
# 597811           ABEL
# 597812           GRAY
# 597813          MAYER
# 597814        FRIESEN
# 597815          BAUER
# Name: OWNER, Length: 597816, dtype: object

# %% [markdown]
# ## 14. Save the last name into a new column
#
# Then check to make sure it exists, and you successfully saved it into the dataframe.

# %%
df['LASTNAME'] = df['OWNER'].str.extract('(.*),',expand=False)

# %%
df.head()
# Out:
#                 LICTYPE LICNUMBER BIZCOUNTY                   BIZNAME  \
# 0  Associate Auctioneer      7326  ANGELINA      RISINGER, JIM MARVIN
# 1  Associate Auctioneer      7962    UPSHUR       WILLIAMS, JON ANDRE
# 2  Associate Auctioneer      8406    WILSON     GUEVARA, JUAN ANTONIO
# 3  Associate Auctioneer     10543    HARRIS  BOWERS, JAMES BRISCOE II
# 4  Associate Auctioneer     10642      BELL       DEMSKY, JOHN EDWARD
#
#    BIZLINE1  BIZLINE2  BIZCITYSTATE BIZTELEPHONE EXPIRATION  \
# 0       NaN       NaN           NaN          NaN 2017-08-10
# 1       NaN       NaN           NaN          NaN 2017-12-29
# 2       NaN       NaN           NaN          NaN 2017-09-26
# 3       NaN       NaN           NaN          NaN 2017-11-04
# 4       NaN       NaN           NaN          NaN 2018-02-25
#
#                       OWNER         MAILLINE1 MAILLINE2  \
# 0      RISINGER, JIM MARVIN  7668 S US HWY 59       NaN
# 1       WILLIAMS, JON ANDRE       228 FM 1252       NaN
# 2     GUEVARA, JUAN ANTONIO      6909 HWY 181       NaN
# 3  BOWERS, JAMES BRISCOE II    6767 NORTH FWY       NaN
# 4       DEMSKY, JOHN EDWARD    130 E CLARK ST       NaN
#
#            MAILCITYSTATE MAILCOUNTYCODE   MAILCOUNTY MAILZIP   TELEPHONE  \
# 0   NACOGDOCHES TX 75964           0347  NACOGDOCHES   75964  9363665745
# 1       KILGORE TX 75662           0183        GREGG   75662  9039187899
# 2          POTH TX 78147           0493       WILSON   78147         NaN
# 3  HOUSTON TX 77076-2027           0201       HARRIS   77076  7136445566
# 4      BARTLETT TX 76511           0027         BELL   76511  2549852228
#
#   LICSUBTYPE CEFLAG  LASTNAME
# 0        NaN      N  RISINGER
# 1        NaN      N  WILLIAMS
# 2        NaN      N   GUEVARA
# 3        NaN      N    BOWERS
# 4        NaN      N    DEMSKY

# %% [markdown]
# # 15. What are the ten most popular last names?

# %%
df.LASTNAME.value_counts().head(10)
# Out:
# NGUYEN       22283
# TRAN          8135
# LE            5605
# GARCIA        5574
# MARTINEZ      4701
# RODRIGUEZ     4625
# HERNANDEZ     4389
# PHAM          3996
# GONZALEZ      3634
# SMITH         3208
# Name: LASTNAME, dtype: int64

# %% [markdown]
# ## 16. What are the most popular licenses for people with the last name Nguyen? Tran? Le?
#
# Those are the top 3 last names in Vietnam.

# %%
df[df.LASTNAME.isin(['NGUYEN'])].LICTYPE.value_counts()
# Out:
# Cosmetology Manicurist                      12855
# Cosmetology Operator                         4039
# Cosmetology Esthetician                      2881
# Cosmetologist                                1874
# Apprentice Electrician                        195
# A/C Technician                                169
# Journeyman Electrician                         55
# Cosmetology Operator Instructor                48
# Barber Manicurist                              25
# Master Electrician                             25
# Barber, Class A                                22
# Property Tax Appraiser                         15
# Apprentice Sign Electrician                    14
# Legal Service Contract Sales Rep                8
# Cosmetology Manicurist Instructor               8
# Maintenance Electrician                         6
# Used Auto Parts Recycler Employee               6
# Tow Truck Operator (Incident Management)        4
# Master Sign Electrician                         4
# Property Tax Consultant                         3
# Tow Truck Operator (Consent Tow)                2
# Appliance Installer                             1
# Cosmetology Hair Braider                        1
# Cosmetology Esthetic Instructor                 1
# Dual Towing Operator(IM)/VSF Employee           1
# Name: LICTYPE, dtype: int64

# %%
df[df.LASTNAME.isin(['TRAN'])].LICTYPE.value_counts()
# Out:
# Cosmetology Manicurist                      4674
# Cosmetology Operator                        1474
# Cosmetology Esthetician                     1032
# Cosmetologist                                712
# Apprentice Electrician                        95
# A/C Technician                                69
# Journeyman Electrician                        16
# Cosmetology Operator Instructor               10
# Barber Manicurist                              9
# Barber, Class A                                7
# Master Electrician                             5
# Apprentice Sign Electrician                    4
# Property Tax Appraiser                         4
# Booting Operator                               2
# Legal Service Contract Sales Rep               2
# Used Auto Parts Recycler Employee              2
# Cosmetology Manicurist Instructor              2
# Tow Truck Operator (Incident Management)       2
# Cosmetology Esthetic Instructor                1
# Tow Truck Operator (Consent Tow)               1
# Journeyman Sign Electrician                    1
# Master Sign Electrician                        1
# Dual Towing Operator(IM)/VSF Employee          1
# Property Tax Consultant                        1
# VSF Employee                                   1
# Maintenance Electrician                        1
# Name: LICTYPE, dtype: int64

# %%
df[df.LASTNAME.isin(['LE'])].LICTYPE.value_counts()
# Out:
# Cosmetology Manicurist                      3276
# Cosmetology Operator                         953
# Cosmetology Esthetician                      730
# Cosmetologist                                497
# A/C Technician                                43
# Apprentice Electrician                        37
# Journeyman Electrician                        20
# Cosmetology Operator Instructor               12
# Barber, Class A                                7
# Master Electrician                             6
# Tow Truck Operator (Consent Tow)               4
# Barber Manicurist                              3
# Property Tax Appraiser                         2
# Apprentice Sign Electrician                    2
# Cosmetology Manicurist Instructor              2
# Used Auto Parts Recycler Employee              2
# Property Tax Consultant                        1
# Maintenance Electrician                        1
# Journeyman Sign Electrician                    1
# Tow Truck Operator (Incident Management)       1
# Master Sign Electrician                        1
# Name: LICTYPE, dtype: int64

# %% [markdown]
# ## 17. Now do all of that in one line - most popular licenses for Nguyen, Tran and Le - without using `&`

# %%
df[df.LASTNAME.isin(['NGUYEN','TRAN','LE'])].LICTYPE.value_counts()
# Out:
# Cosmetology Manicurist                      20805
# Cosmetology Operator                         6466
# Cosmetology Esthetician                      4643
# Cosmetologist                                3083
# Apprentice Electrician                        327
# A/C Technician                                281
# Journeyman Electrician                         91
# Cosmetology Operator Instructor                70
# Barber Manicurist                              37
# Master Electrician                             36
# Barber, Class A                                36
# Property Tax Appraiser                         21
# Apprentice Sign Electrician                    20
# Cosmetology Manicurist Instructor              12
# Used Auto Parts Recycler Employee              10
# Legal Service Contract Sales Rep               10
# Maintenance Electrician                         8
# Tow Truck Operator (Incident Management)        7
# Tow Truck Operator (Consent Tow)                7
# Master Sign Electrician                         6
# Property Tax Consultant                         5
# Cosmetology Esthetic Instructor                 2
# Dual Towing Operator(IM)/VSF Employee           2
# Booting Operator                                2
# Journeyman Sign Electrician                     2
# Appliance Installer                             1
# Cosmetology Hair Braider                        1
# VSF Employee                                    1
# Name: LICTYPE, dtype: int64

# %% [markdown]
# ## 18. Most popular licenses for Garcia? Rodriguez? Martinez?
#
# Those are the 3 most common last names for self-identifying Hispanics in the USA.

# %%
df[df.LASTNAME=='GARCIA'].LICTYPE.value_counts()
# Out:
# Apprentice Electrician                          1952
# Cosmetology Operator                            1672
# Journeyman Electrician                           493
# A/C Technician                                   333
# Barber, Class A                                  186
# Master Electrician                               118
# Tow Truck Operator (Incident Management)          94
# Cosmetology Esthetician                           88
# Apprentice Sign Electrician                       87
# Tow Truck Operator (Consent Tow)                  78
# Cosmetology Manicurist                            75
# Cosmetology Operator Instructor                   48
# Legal Service Contract Sales Rep                  37
# Dual Towing Operator(IM)/VSF Employee             36
# VSF Employee                                      36
# Used Auto Parts Recycler Employee                 32
# Residential Wireman                               27
# Property Tax Appraiser                            26
# Journeyman Sign Electrician                       11
# Cosmetologist                                      9
# Maintenance Electrician                            9
# Appliance Installer                                7
# Property Tax Consultant                            7
# Barber Instructor                                  7
# Barber Manicurist                                  6
# Property Tax Assessor/Collector                    5
# Water Well Driller/Pump Installer Apprentice       5
# Registered Accessibility Specialist                4
# Master Sign Electrician                            4
# Auctioneer                                         3
# Polygraph Examiner                                 3
# Water Well Driller/Pump Installer                  3
# Qualified Elevator Inspector                       1
# Booting Operator                                   1
# Tow Truck Operator (Private Property)              1
# Cosmetology Esthetic Instructor                    1
# Name: LICTYPE, dtype: int64

# %%
df[df.LASTNAME=='RODRIGUEZ'].LICTYPE.value_counts()
# Out:
# Apprentice Electrician                          1573
# Cosmetology Operator                            1390
# Journeyman Electrician                           386
# A/C Technician                                   320
# Barber, Class A                                  138
# Cosmetology Esthetician                           91
# Master Electrician                                83
# Tow Truck Operator (Incident Management)          80
# Tow Truck Operator (Consent Tow)                  69
# Cosmetology Manicurist                            60
# Apprentice Sign Electrician                       57
# Cosmetology Operator Instructor                   44
# Used Auto Parts Recycler Employee                 39
# Legal Service Contract Sales Rep                  37
# Dual Towing Operator(IM)/VSF Employee             32
# VSF Employee                                      20
# Property Tax Appraiser                            17
# Residential Wireman                               17
# Maintenance Electrician                           13
# Appliance Installer                               10
# Cosmetologist                                      6
# Registered Accessibility Specialist                6
# Tow Truck Operator (Private Property)              5
# Barber Instructor                                  5
# Property Tax Collector                             5
# Master Sign Electrician                            4
# Water Well Driller/Pump Installer Apprentice       4
# Property Tax Assessor/Collector                    4
# Booting Operator                                   4
# Dual Towing Operator(CT)/VSF Employee              4
# Property Tax Consultant                            3
# Barber Manicurist                                  3
# Tow Truck Operator Trainee                         2
# Auctioneer                                         2
# Journeyman Sign Electrician                        2
# Cosmetology Esthetic Instructor                    2
# Polygraph Examiner                                 1
# Water Well Driller/Pump Installer                  1
# Dual Towing Operator(PP)/VSF Employee              1
# Name: LICTYPE, dtype: int64

# %%
df[df.LASTNAME=='MARTINEZ'].LICTYPE.value_counts()
# Out:
# Apprentice Electrician                          1618
# Cosmetology Operator                            1388
# Journeyman Electrician                           387
# A/C Technician                                   317
# Barber, Class A                                  149
# Master Electrician                                92
# Cosmetology Esthetician                           86
# Tow Truck Operator (Incident Management)          70
# Cosmetology Manicurist                            63
# Used Auto Parts Recycler Employee                 62
# Tow Truck Operator (Consent Tow)                  62
# Apprentice Sign Electrician                       55
# Legal Service Contract Sales Rep                  52
# Cosmetology Operator Instructor                   43
# VSF Employee                                      36
# Dual Towing Operator(IM)/VSF Employee             25
# Residential Wireman                               24
# Property Tax Appraiser                            13
# Maintenance Electrician                            9
# Appliance Installer                                6
# Auctioneer                                         5
# Property Tax Consultant                            5
# Property Tax Assessor/Collector                    4
# Water Well Driller/Pump Installer                  4
# Polygraph Examiner                                 4
# Tow Truck Operator (Private Property)              4
# Water Well Driller/Pump Installer Apprentice       4
# Booting Operator                                   4
# Cosmetologist                                      3
# Registered Accessibility Specialist                3
# Property Tax Collector                             3
# Dual Towing Operator(CT)/VSF Employee              3
# Barber Manicurist                                  3
# Journeyman Sign Electrician                        2
# Cosmetology Esthetic Instructor                    2
# Associate Auctioneer                               2
# Cosmetology Shampoo Specialist                     2
# Cosmetology Hair Braider                           1
# Cosmetology Manicurist Instructor                  1
# Name: LICTYPE, dtype: int64

# %% [markdown]
# ## 19. Most popular license for anyone with a last name that ENDS in `-ez`
#
# The answer is not `.str.contains('ez')`, but it isn't necessarily too different. **Make sure your numbers match mine.**
#
# One way involves a `.str.` method that check if a string ends with something, the other way involves a regular expression that has a "end of the string" marker (similar to how we've used `^` for the start of a string before). If you're thinking about the latter, I might take a look at [this page](http://www.rexegg.com/regex-quickstart.html) under "Anchors and Boundaries".

# %%
df[df.LASTNAME.str.contains("EZ$",na=False)].LICTYPE.value_counts()
# Out:
# Apprentice Electrician                          16065
# Cosmetology Operator                            13885
# Journeyman Electrician                           3529
# A/C Technician                                   2889
# Barber, Class A                                  1277
# Master Electrician                                763
# Cosmetology Esthetician                           748
# Tow Truck Operator (Consent Tow)                  695
# Cosmetology Manicurist                            633
# Tow Truck Operator (Incident Management)          620
# Apprentice Sign Electrician                       602
# Legal Service Contract Sales Rep                  415
# Cosmetology Operator Instructor                   400
# Used Auto Parts Recycler Employee                 389
# VSF Employee                                      263
# Residential Wireman                               251
# Dual Towing Operator(IM)/VSF Employee             238
# Property Tax Appraiser                            135
# Maintenance Electrician                            76
# Appliance Installer                                73
# Cosmetologist                                      47
# Property Tax Consultant                            36
# Tow Truck Operator (Private Property)              35
# Water Well Driller/Pump Installer Apprentice       34
# Journeyman Sign Electrician                        33
# Property Tax Assessor/Collector                    32
# Water Well Driller/Pump Installer                  30
# Barber Instructor                                  25
# Barber Manicurist                                  23
# Registered Accessibility Specialist                20
# Dual Towing Operator(CT)/VSF Employee              19
# Master Sign Electrician                            17
# Auctioneer                                         16
# Booting Operator                                   15
# Property Tax Collector                             14
# Cosmetology Shampoo Specialist                     11
# Polygraph Examiner                                 11
# Cosmetology Esthetic Instructor                     9
# Cosmetology Hair Braider                            8
# Cosmetology Manicurist Instructor                   7
# Tow Truck Operator Trainee                          3
# Dual Towing Operator(PP)/VSF Employee               2
# Associate Auctioneer                                2
# Qualified Elevator Inspector                        1
# Electrical Contractor                               1
# Polygraph Examiner Trainee                          1
# Barber Technician                                   1
# Cos Mini Salon                                      1
# Barber Hair Braiding Specialist                     1
# Name: LICTYPE, dtype: int64

# %% [markdown]
# ## 20. Get that as a percentage

# %%
df[df.LASTNAME.str.contains("EZ$",na=False)].LICTYPE.value_counts(normalize=True)
# Out:
# Apprentice Electrician                          0.361816
# Cosmetology Operator                            0.312718
# Journeyman Electrician                          0.079480
# A/C Technician                                  0.065066
# Barber, Class A                                 0.028761
# Master Electrician                              0.017184
# Cosmetology Esthetician                         0.016846
# Tow Truck Operator (Consent Tow)                0.015653
# Cosmetology Manicurist                          0.014256
# Tow Truck Operator (Incident Management)        0.013964
# Apprentice Sign Electrician                     0.013558
# Legal Service Contract Sales Rep                0.009347
# Cosmetology Operator Instructor                 0.009009
# Used Auto Parts Recycler Employee               0.008761
# VSF Employee                                    0.005923
# Residential Wireman                             0.005653
# Dual Towing Operator(IM)/VSF Employee           0.005360
# Property Tax Appraiser                          0.003040
# Maintenance Electrician                         0.001712
# Appliance Installer                             0.001644
# Cosmetologist                                   0.001059
# Property Tax Consultant                         0.000811
# Tow Truck Operator (Private Property)           0.000788
# Water Well Driller/Pump Installer Apprentice    0.000766
# Journeyman Sign Electrician                     0.000743
# Property Tax Assessor/Collector                 0.000721
# Water Well Driller/Pump Installer               0.000676
# Barber Instructor                               0.000563
# Barber Manicurist                               0.000518
# Registered Accessibility Specialist             0.000450
# Dual Towing Operator(CT)/VSF Employee           0.000428
# Master Sign Electrician                         0.000383
# Auctioneer                                      0.000360
# Booting Operator                                0.000338
# Property Tax Collector                          0.000315
# Cosmetology Shampoo Specialist                  0.000248
# Polygraph Examiner                              0.000248
# Cosmetology Esthetic Instructor                 0.000203
# Cosmetology Hair Braider                        0.000180
# Cosmetology Manicurist Instructor               0.000158
# Tow Truck Operator Trainee                      0.000068
# Dual Towing Operator(PP)/VSF Employee           0.000045
# Associate Auctioneer                            0.000045
# Qualified Elevator Inspector                    0.000023
# Electrical Contractor                           0.000023
# Polygraph Examiner Trainee                      0.000023
# Barber Technician                               0.000023
# Cos Mini Salon                                  0.000023
# Barber Hair Braiding Specialist                 0.000023
# Name: LICTYPE, dtype: float64

# %% [markdown]
# # PART FOUR: LOOKING AT FIRST NAMES

# %% [markdown]
# ## 21. Extract the owner's first name
#
# First, a little example of how regular expressions work with pandas.

# %%
# Build a dataframe
sample_df = pd.DataFrame([
    { 'name': 'Mary', 'sentence': "I am 90 years old" },
    { 'name': 'Jack', 'sentence': "I am 4 years old" },
    { 'name': 'Anne', 'sentence': "I am 27 years old" },
    { 'name': 'Joel', 'sentence': "I am 13 years old" },
])
# Look at the dataframe
sample_df
# Out:
#    name           sentence
# 0  Mary  I am 90 years old
# 1  Jack   I am 4 years old
# 2  Anne  I am 27 years old
# 3  Joel  I am 13 years old

# %%
# Given the sentence, "I am X years old", extract digits from the middle using ()
# Anything you put in () will be saved as an output.
# If you do expand=True it makes you a dataframe, but we don't want that.
sample_df['sentence'].str.extract("I am (\d+) years old", expand=False)
# Out:
# 0    90
# 1     4
# 2    27
# 3    13
# Name: sentence, dtype: object

# %%
# Save it into a new column
sample_df['age'] = sample_df['sentence'].str.extract("I am (\d+) years old", expand=False)
sample_df.head()
# Out:
#    name           sentence age
# 0  Mary  I am 90 years old  90
# 1  Jack   I am 4 years old   4
# 2  Anne  I am 27 years old  27
# 3  Joel  I am 13 years old  13

# %% [markdown]
# **Now let's think about how we're going to extract the first names.** Begin by looking at a few full names.

# %%
df['OWNER'].head(10)
# Out:
# 0        RISINGER, JIM MARVIN
# 1         WILLIAMS, JON ANDRE
# 2       GUEVARA, JUAN ANTONIO
# 3    BOWERS, JAMES BRISCOE II
# 4         DEMSKY, JOHN EDWARD
# 5           THOMPSON, RANDY D
# 6          TUCKER, MONTE EARL
# 7        COOPER, THOMAS JAMES
# 8     BLANKENSHIP, KERRY NEIL
# 9      DAWES, NICHOLAS MORGAN
# Name: OWNER, dtype: object

# %% [markdown]
# What can you use to find the first name? It helps to say "this is to the left and this is to the right, and I'm going to take anything in the middle."
#
# Once you figure out how to extract it, you can do a `.head(10)` to just look at the first few.

# %%
df.OWNER.str.extract(", (.*) ",expand=False).head(10)
# Out:
# 0              JIM
# 1              JON
# 2             JUAN
# 3    JAMES BRISCOE
# 4             JOHN
# 5            RANDY
# 6            MONTE
# 7           THOMAS
# 8            KERRY
# 9         NICHOLAS
# Name: OWNER, dtype: object

# %% [markdown]
# ## 22. Saving the owner's first name
#
# Save the name to a new column, `FIRSTNAME`.

# %%
df['FIRSTNAME'] = df.OWNER.str.extract(", (.*) ",expand=False)

# %% [markdown]
# # 23. Examine everyone without a first name
#
# I purposefully didn't do a nicer regex in order to have some screwed-up results. **How many people are there without an entry in the first name column?**
#
# Your numbers might be different than mine.

# %%
df.FIRSTNAME.isnull().sum()
# Out:
# 212305

# %% [markdown]
# What do their names look like?

# %%
df[df.FIRSTNAME.isnull()]
# Out:
#                                   LICTYPE LICNUMBER     BIZCOUNTY  \
# 29                   Associate Auctioneer     17699       EL PASO
# 63                         A/C Technician       104         TITUS
# 64                         A/C Technician       105        UPSHUR
# 73                         A/C Technician       143       HOPKINS
# 76                         A/C Technician       147    WILLIAMSON
# 77                         A/C Technician       157       BASTROP
# 87                         A/C Technician       192        TAYLOR
# 92                         A/C Technician       207         GREGG
# 96                         A/C Technician       239        DENTON
# 109                        A/C Technician       283        HARRIS
# 119                        A/C Technician       299         BEXAR
# 120                        A/C Technician       302         BEXAR
# 136                        A/C Technician       348         TITUS
# 139                        A/C Technician       356           NaN
# 140                        A/C Technician       358         GREGG
# 141                        A/C Technician       364          HAYS
# 150                        A/C Technician       389         TITUS
# 151                        A/C Technician       393     VAL VERDE
# 158                        A/C Technician       416       GRAYSON
# 159                        A/C Technician       418        COLLIN
# 161                        A/C Technician       421         TITUS
# 163                        A/C Technician       427       GRAYSON
# 166                        A/C Technician       441      FRANKLIN
# 169                        A/C Technician       453        HARRIS
# 175                        A/C Technician       473        MEDINA
# 177                        A/C Technician       475        HARRIS
# 182                        A/C Technician       493         BEXAR
# 185                        A/C Technician       504     LIMESTONE
# 188                        A/C Technician       514        DENTON
# 191                        A/C Technician       523       JOHNSON
# ...                                   ...       ...           ...
# 597406  Water Well Driller/Pump Installer     58962         UPTON
# 597409  Water Well Driller/Pump Installer     58987          HALE
# 597417  Water Well Driller/Pump Installer     59027        GAINES
# 597421  Water Well Driller/Pump Installer     59061       KENDALL
# 597442  Water Well Driller/Pump Installer     59245        DIMMIT
# 597447  Water Well Driller/Pump Installer     59274        GRIMES
# 597455  Water Well Driller/Pump Installer     59313        BOSQUE
# 597481  Water Well Driller/Pump Installer     59353         DUVAL
# 597501  Water Well Driller/Pump Installer     59377         COMAL
# 597518  Water Well Driller/Pump Installer     59397         STARR
# 597528  Water Well Driller/Pump Installer     59410       KAUFMAN
# 597530  Water Well Driller/Pump Installer     59413  OUT OF STATE
# 597537  Water Well Driller/Pump Installer     59425          HALE
# 597554  Water Well Driller/Pump Installer     59446        DAWSON
# 597563  Water Well Driller/Pump Installer     59456          LEON
# 597570  Water Well Driller/Pump Installer     59466      HEMPHILL
# 597623  Water Well Driller/Pump Installer     59525      ROCKWALL
# 597624  Water Well Driller/Pump Installer     59526     HENDERSON
# 597636  Water Well Driller/Pump Installer     59539      CROCKETT
# 597640  Water Well Driller/Pump Installer     59544       RANDALL
# 597650  Water Well Driller/Pump Installer     59554         BEXAR
# 597680  Water Well Driller/Pump Installer     59585      ATASCOSA
# 597681  Water Well Driller/Pump Installer     59586       REFUGIO
# 597704  Water Well Driller/Pump Installer     59615        HARRIS
# 597712  Water Well Driller/Pump Installer     59623        GAINES
# 597723  Water Well Driller/Pump Installer     59637        DALLAS
# 597730  Water Well Driller/Pump Installer     59644         BEXAR
# 597751  Water Well Driller/Pump Installer     59665         PECOS
# 597780  Water Well Driller/Pump Installer     59823       MIDLAND
# 597809  Water Well Driller/Pump Installer     59926     HENDERSON
#
#                     BIZNAME  BIZLINE1  BIZLINE2  BIZCITYSTATE BIZTELEPHONE  \
# 29         MARTINEZ, ARTURO       NaN       NaN           NaN          NaN
# 63       VANGINAULT, FREDDY       NaN       NaN           NaN          NaN
# 64       VANSICKLE, MICHAEL       NaN       NaN           NaN          NaN
# 73           COFFMAN, ERICK       NaN       NaN           NaN          NaN
# 76            HUNTER, SCOTT       NaN       NaN           NaN          NaN
# 77            WATTS, EDWARD       NaN       NaN           NaN          NaN
# 87           SERRATO, ZENON       NaN       NaN           NaN          NaN
# 92            ASHLEY, WAYNE       NaN       NaN           NaN          NaN
# 96        MARSLAND, RICHARD       NaN       NaN           NaN          NaN
# 109         RICHARD, MEDINA       NaN       NaN           NaN          NaN
# 119            LUCIO, JAIME       NaN       NaN           NaN          NaN
# 120       ESCAMILLA, ROBERT       NaN       NaN           NaN          NaN
# 136          ARCIGA, HECTOR       NaN       NaN           NaN          NaN
# 139       ROBINSON, RICHARD       NaN       NaN           NaN          NaN
# 140              BELL, JANA       NaN       NaN           NaN          NaN
# 141             BETHKE, MAX       NaN       NaN           NaN          NaN
# 150           SIBLEY, SHAWN       NaN       NaN           NaN          NaN
# 151          REYES, OCTAVIO       NaN       NaN           NaN          NaN
# 158      BAKER, CHRISTOPHER       NaN       NaN           NaN          NaN
# 159             CLARK, JOSH       NaN       NaN           NaN          NaN
# 161          NIETO, ARNULFO       NaN       NaN           NaN          NaN
# 163          EDWARDS, BRIAN       NaN       NaN           NaN          NaN
# 166          FLORES, ISIDRO       NaN       NaN           NaN          NaN
# 169        HALKARD, KENNETH       NaN       NaN           NaN          NaN
# 175     ESPINOSA, NATIVIDAD       NaN       NaN           NaN          NaN
# 177         PADILLA, ERASTO       NaN       NaN           NaN          NaN
# 182              ADAM, ARCE       NaN       NaN           NaN          NaN
# 185     HERNANDEZ, JONATHAN       NaN       NaN           NaN          NaN
# 188         SEELING, NORMAN       NaN       NaN           NaN          NaN
# 191          STEVENS, CHUCK       NaN       NaN           NaN          NaN
# ...                     ...       ...       ...           ...          ...
# 597406        LATZEL, DEREK       NaN       NaN           NaN          NaN
# 597409        TORREZ, SELSO       NaN       NaN           NaN          NaN
# 597417        LOEWEN, JOHNY       NaN       NaN           NaN          NaN
# 597421         BROWN, DAREL       NaN       NaN           NaN          NaN
# 597442       GARZA, GILBERT       NaN       NaN           NaN          NaN
# 597447       KASHWER, KLENT       NaN       NaN           NaN          NaN
# 597455         LAWSON, JODY       NaN       NaN           NaN          NaN
# 597481          HANER, BERT       NaN       NaN           NaN          NaN
# 597501        NEWBORN, MARK       NaN       NaN           NaN          NaN
# 597518       SALINAS, DAVID       NaN       NaN           NaN          NaN
# 597528        SINGLETON, BO       NaN       NaN           NaN          NaN
# 597530         STEERE, MATT       NaN       NaN           NaN          NaN
# 597537      MCKINNEY, BOBBY       NaN       NaN           NaN          NaN
# 597554       MARTENS, PETER       NaN       NaN           NaN          NaN
# 597563      GARRISON, FLOYD       NaN       NaN           NaN          NaN
# 597570  CERVANTES, EZEQUIEL       NaN       NaN           NaN          NaN
# 597623           SCHAR, ROY       NaN       NaN           NaN          NaN
# 597624       STANTON, JACOB       NaN       NaN           NaN          NaN
# 597636          STOKES, SOL       NaN       NaN           NaN          NaN
# 597640       GARCIA, MANUEL       NaN       NaN           NaN          NaN
# 597650  MARTINEZ, HERIBERTO       NaN       NaN           NaN          NaN
# 597680         KOTZUR, TONY       NaN       NaN           NaN          NaN
# 597681       RIVERA, DANIEL       NaN       NaN           NaN          NaN
# 597704      BAUTISTA, ERICK       NaN       NaN           NaN          NaN
# 597712       HARMS, ABRAHAM       NaN       NaN           NaN          NaN
# 597723   FIGUEROA, HIPOLITO       NaN       NaN           NaN          NaN
# 597730        GARZA, JESSIE       NaN       NaN           NaN          NaN
# 597751       YANEZ, SALOMON       NaN       NaN           NaN          NaN
# 597780      WILLEKE, JOSPEH       NaN       NaN           NaN          NaN
# 597809      LILLEY, CLINTON       NaN       NaN           NaN          NaN
#
#        EXPIRATION                OWNER  ... MAILLINE2  \
# 29     2017-04-18     MARTINEZ, ARTURO  ...       NaN
# 63     2017-05-06   VANGINAULT, FREDDY  ...       NaN
# 64     2017-05-17   VANSICKLE, MICHAEL  ...       NaN
# 73     2017-07-10       COFFMAN, ERICK  ...       NaN
# 76     2018-01-23        HUNTER, SCOTT  ...       NaN
# 77     2018-02-06        WATTS, EDWARD  ...       NaN
# 87     2017-09-12       SERRATO, ZENON  ...       NaN
# 92     2018-01-28        ASHLEY, WAYNE  ...       NaN
# 96     2017-05-11    MARSLAND, RICHARD  ...       NaN
# 109    2017-05-13      RICHARD, MEDINA  ...       NaN
# 119    2018-02-07         LUCIO, JAIME  ...       NaN
# 120    2017-05-16    ESCAMILLA, ROBERT  ...       NaN
# 136    2017-05-07       ARCIGA, HECTOR  ...       NaN
# 139    2017-05-07    ROBINSON, RICHARD  ...       NaN
# 140    2017-08-19           BELL, JANA  ...       NaN
# 141    2017-12-27          BETHKE, MAX  ...       NaN
# 150    2017-05-07        SIBLEY, SHAWN  ...       NaN
# 151    2017-08-20       REYES, OCTAVIO  ...       NaN
# 158    2017-07-18   BAKER, CHRISTOPHER  ...       NaN
# 159    2017-04-28          CLARK, JOSH  ...       NaN
# 161    2017-05-07       NIETO, ARNULFO  ...       NaN
# 163    2017-06-01       EDWARDS, BRIAN  ...       NaN
# 166    2017-11-05       FLORES, ISIDRO  ...       NaN
# 169    2018-01-07     HALKARD, KENNETH  ...       NaN
# 175    2017-05-07  ESPINOSA, NATIVIDAD  ...       NaN
# 177    2017-10-13      PADILLA, ERASTO  ...       NaN
# 182    2017-05-07           ADAM, ARCE  ...       NaN
# 185    2018-02-01  HERNANDEZ, JONATHAN  ...       NaN
# 188    2017-04-12      SEELING, NORMAN  ...       NaN
# 191    2017-05-16       STEVENS, CHUCK  ...       NaN
# ...           ...                  ...  ...       ...
# 597406 2017-09-16        LATZEL, DEREK  ...       NaN
# 597409 2017-10-19        TORREZ, SELSO  ...       NaN
# 597417 2017-12-12        LOEWEN, JOHNY  ...       NaN
# 597421 2018-02-02         BROWN, DAREL  ...       NaN
# 597442 2017-08-09       GARZA, GILBERT  ...       NaN
# 597447 2017-09-14       KASHWER, KLENT  ...       NaN
# 597455 2017-10-25         LAWSON, JODY  ...       NaN
# 597481 2017-05-09          HANER, BERT  ...       NaN
# 597501 2017-07-31        NEWBORN, MARK  ...       NaN
# 597518 2017-10-10       SALINAS, DAVID  ...       NaN
# 597528 2016-11-11        SINGLETON, BO  ...       NaN
# 597530 2018-01-13         STEERE, MATT  ...       NaN
# 597537 2018-01-14      MCKINNEY, BOBBY  ...       NaN
# 597554 2018-03-04       MARTENS, PETER  ...       NaN
# 597563 2018-03-20      GARRISON, FLOYD  ...       NaN
# 597570 2017-04-17  CERVANTES, EZEQUIEL  ...       NaN
# 597623 2018-02-14           SCHAR, ROY  ...       NaN
# 597624 2016-10-30       STANTON, JACOB  ...       NaN
# 597636 2017-12-09          STOKES, SOL  ...       NaN
# 597640 2018-01-13       GARCIA, MANUEL  ...       NaN
# 597650 2018-02-02  MARTINEZ, HERIBERTO  ...       NaN
# 597680 2017-06-02         KOTZUR, TONY  ...       NaN
# 597681 2017-06-03       RIVERA, DANIEL  ...       NaN
# 597704 2017-11-04      BAUTISTA, ERICK  ...       NaN
# 597712 2018-01-03       HARMS, ABRAHAM  ...       NaN
# 597723 2017-02-01   FIGUEROA, HIPOLITO  ...       NaN
# 597730 2018-02-22        GARZA, JESSIE  ...       NaN
# 597751 2017-05-03       YANEZ, SALOMON  ...       NaN
# 597780 2017-08-23      WILLEKE, JOSPEH  ...       NaN
# 597809 2018-01-13      LILLEY, CLINTON  ...       NaN
#
#                         MAILCITYSTATE MAILCOUNTYCODE    MAILCOUNTY MAILZIP  \
# 29              EL PASO TX 79912-2104           0141       EL PASO   79912
# 63                                NaN            NaN         TITUS   75455
# 64                                NaN            NaN        UPSHUR   75644
# 73                                NaN            NaN       HOPKINS   75437
# 76                                NaN            NaN    WILLIAMSON   78626
# 77                                NaN            NaN       BASTROP   78602
# 87                                NaN            NaN        TAYLOR   79601
# 92                                NaN            NaN         GREGG   75604
# 96                                NaN            NaN        DENTON   76262
# 109                               NaN            NaN        HARRIS   77038
# 119                               NaN            NaN         BEXAR   78023
# 120                               NaN            NaN         BEXAR   78244
# 136                               NaN            NaN         TITUS   75455
# 139                               NaN            NaN           NaN   77346
# 140                               NaN            NaN         GREGG   75605
# 141                               NaN            NaN          HAYS   78666
# 150                               NaN            NaN         TITUS   75455
# 151                               NaN            NaN     VAL VERDE   78840
# 158                               NaN            NaN       GRAYSON   75076
# 159                               NaN            NaN        COLLIN   75074
# 161                               NaN            NaN         TITUS   75455
# 163                               NaN            NaN       GRAYSON   75491
# 166                               NaN            NaN      FRANKLIN   75457
# 169                               NaN            NaN        HARRIS   77062
# 175                               NaN            NaN        MEDINA   78861
# 177                               NaN            NaN        HARRIS   77073
# 182                               NaN            NaN         BEXAR   78101
# 185                               NaN            NaN     LIMESTONE   76667
# 188                               NaN            NaN        DENTON   76247
# 191                               NaN            NaN       JOHNSON   76097
# ...                               ...            ...           ...     ...
# 597406          MIDKIFF TX 79755-0127           0461         UPTON   79755
# 597409        ABERNATHY TX 79311-0730           0189          HALE   79311
# 597417         SEMINOLE TX 79360-0123           0165        GAINES   79360
# 597421           BOERNE TX 78006-0733           0259       KENDALL   78006
# 597442     CRYSTAL CITY TX 78839-2828           0507        ZAVALA   78839
# 597447              NAVASOTA TX 77868           0185        GRIMES   77868
# 597455           MORGAN TX 76671-3097           0035        BOSQUE   76671
# 597481         REALITOS TX 78376-0130           0131         DUVAL   78376
# 597501      SAN ANTONIO TX 78266-2228           0091         COMAL   78266
# 597518  RIO GRANDE CITY TX 78582-1195           0427         STARR   78582
# 597528         MESQUITE TX 75149-5809           0113        DALLAS   75149
# 597530           GOLDEN CO 80403-1800           0999  OUT OF STATE   80403
# 597537        ABERNATHY TX 79311-0490           0189          HALE   79311
# 597554           LAMESA TX 79331-3840           0115        DAWSON   79331
# 597563           CURLEW WA 99118-9669           0999  OUT OF STATE   99118
# 597570         CANADIAN TX 79014-5018           0211      HEMPHILL   79014
# 597623         MESQUITE TX 75149-5033           0113        DALLAS   75149
# 597624           ATHENS TX 75751-2236           0213     HENDERSON   75751
# 597636                 OZONA TX 76943           0105      CROCKETT   76943
# 597640         HEREFORD TX 79045-4612           0117    DEAF SMITH   79045
# 597650      SAN ANTONIO TX 78212-1352           0029         BEXAR   78212
# 597680       PLEASANTON TX 78064-2336           0013      ATASCOSA   78064
# 597681        WOODSBORO TX 78393-0856           0391       REFUGIO   78393
# 597704          HOUSTON TX 77041-5619           0201        HARRIS   77041
# 597712         SEMINOLE TX 79360-3336           0165        GAINES   79360
# 597723            BOWIE TX 76230-2716           0337      MONTAGUE   76230
# 597730      SAN ANTONIO TX 78227-4204           0029         BEXAR   78227
# 597751    FORT STOCKTON TX 79735-1892           0371         PECOS   79735
# 597780          MIDLAND TX 79701-5118           0329       MIDLAND   79701
# 597809           ATHENS TX 75751-2236           0213     HENDERSON   75751
#
#           TELEPHONE LICSUBTYPE CEFLAG    LASTNAME FIRSTNAME
# 29       9153733887        NaN      N    MARTINEZ       NaN
# 63              NaN        CER      N  VANGINAULT       NaN
# 64              NaN        CER      N   VANSICKLE       NaN
# 73              NaN        REG      N     COFFMAN       NaN
# 76              NaN        REG      N      HUNTER       NaN
# 77              NaN        REG      N       WATTS       NaN
# 87              NaN        REG      N     SERRATO       NaN
# 92              NaN        REG      N      ASHLEY       NaN
# 96              NaN        REG      N    MARSLAND       NaN
# 109             NaN        REG      N     RICHARD       NaN
# 119             NaN        REG      N       LUCIO       NaN
# 120             NaN        REG      N   ESCAMILLA       NaN
# 136             NaN        REG      N      ARCIGA       NaN
# 139             NaN        REG      N    ROBINSON       NaN
# 140             NaN        CER      N        BELL       NaN
# 141             NaN        CER      N      BETHKE       NaN
# 150             NaN        REG      N      SIBLEY       NaN
# 151             NaN        REG      N       REYES       NaN
# 158             NaN        REG      N       BAKER       NaN
# 159             NaN        REG      N       CLARK       NaN
# 161             NaN        REG      N       NIETO       NaN
# 163             NaN        REG      N     EDWARDS       NaN
# 166             NaN        REG      N      FLORES       NaN
# 169             NaN        REG      N     HALKARD       NaN
# 175             NaN        REG      N    ESPINOSA       NaN
# 177             NaN        REG      N     PADILLA       NaN
# 182             NaN        REG      N        ADAM       NaN
# 185             NaN        REG      N   HERNANDEZ       NaN
# 188             NaN        REG      N     SEELING       NaN
# 191             NaN        REG      N     STEVENS       NaN
# ...             ...        ...    ...         ...       ...
# 597406  4.32535e+09          W      N      LATZEL       NaN
# 597409  8.06298e+09          W      N      TORREZ       NaN
# 597417  4.32759e+09          W      N      LOEWEN       NaN
# 597421  8.30816e+09          P      N       BROWN       NaN
# 597442  8.30374e+09        KPT      N       GARZA       NaN
# 597447  9.36873e+09          P      N     KASHWER       NaN
# 597455  2.54387e+09        KLP      N      LAWSON       NaN
# 597481  3.61215e+09         PW      N       HANER       NaN
# 597501  2.10652e+09        KLP      N     NEWBORN       NaN
# 597518    9.565e+09         LP      N     SALINAS       NaN
# 597528  9.72286e+09          W      N   SINGLETON       NaN
# 597530  3.03277e+09          M      N      STEERE       NaN
# 597537  8.06298e+09        KPT      N    MCKINNEY       NaN
# 597554  8.06201e+09         KP      N     MARTENS       NaN
# 597563  5.09691e+09        KPW      N    GARRISON       NaN
# 597570  8.06324e+09       KLPT      N   CERVANTES       NaN
# 597623  2.14661e+09          C      N       SCHAR       NaN
# 597624  9.03675e+09         KP      N     STANTON       NaN
# 597636  3.25392e+09        KLP      N      STOKES       NaN
# 597640  8.06345e+09         KT      N      GARCIA       NaN
# 597650  2.10697e+09          M      N    MARTINEZ       NaN
# 597680  8.30569e+09        KPT      N      KOTZUR       NaN
# 597681  3.61543e+09          W      N      RIVERA       NaN
# 597704  7.13467e+09         KT      N    BAUTISTA       NaN
# 597712   4.3221e+09          W      N       HARMS       NaN
# 597723  9.40873e+09          W      N    FIGUEROA       NaN
# 597730  2.10435e+09        KPT      N       GARZA       NaN
# 597751  4.32337e+09         KP      N       YANEZ       NaN
# 597780  4.32705e+09          W      N     WILLEKE       NaN
# 597809  9.03675e+09        KLP      N      LILLEY       NaN
#
# [212305 rows x 21 columns]

# %% [markdown]
# ## 24. If it's a problem, you can fix it (if you'd like!)
#
# Maybe you have another regular expression that works better with JUST these people? It really depends on how you've put together your previous regex!
#
# If you'd like to use a separate regex for this group, you can use code like this:
#
# `df.loc[df.FIRSTNAME.isnull(), 'FIRSTNAME'] = .....`
#
# That will only set the `FIRSTNAME` for people where `FIRSTNAME` is null.

# %%
df.loc[df.FIRSTNAME.isnull(), 'FIRSTNAME'] = df['OWNER'].str.extract(", (.*)",expand=False)

# %% [markdown]
# How many empty first names do we have now?

# %%
df.FIRSTNAME.isnull().sum()
# Out:
# 82099

# %% [markdown]
# My code before only worked for people with middle names, but now it got people without middle names, too. Looking much better!

# %% [markdown]
# ## 25. Most popular first names?

# %%
df.FIRSTNAME.value_counts().head(20)
# Out:
# JOSE           6462
# MICHAEL        5447
# DAVID          4960
# MARIA          4647
# JAMES          4217
# JUAN           3797
# ROBERT         3791
# JOHN           3777
# CHRISTOPHER    3044
# DANIEL         2866
# WILLIAM        2439
# RICHARD        2202
# JENNIFER       2102
# LUIS           2095
# JESUS          1905
# CARLOS         1870
# JASON          1845
# JESSICA        1790
# JOSEPH         1749
# MARK           1746
# Name: FIRSTNAME, dtype: int64

# %% [markdown]
# ## 26. Most popular first names for a Cosmetology Operator, Cosmetology Esthetician, Cosmetologist, and okay honestly anything that seems similar?
#
# If you get an error about "cannot index vector containing NA / NaN values" remember `.fillna(False)` - if a row doesn't have a license, it doesn't give a `True`/`False`, so we force all of the empty rows to be `False`.

# %%
df[df.LICTYPE.str.contains("Cosmet").fillna(False)].FIRSTNAME.value_counts().head(20)
# Out:
# MARIA        4169
# JENNIFER     1884
# JESSICA      1619
# PHUONG       1429
# THUY         1394
# ASHLEY       1348
# MARY         1339
# AMANDA       1180
# ELIZABETH    1179
# KIMBERLY     1139
# LINDA        1087
# MICHELLE     1066
# STEPHANIE    1021
# PATRICIA     1015
# SANDRA       1007
# LISA         1006
# LAURA         998
# KIM           964
# MELISSA       944
# THANH         937
# Name: FIRSTNAME, dtype: int64

# %% [markdown]
# ## 27. Most popular first names for anything involving electricity?

# %%
df[df.LICTYPE.str.contains("Electr").fillna(False)].FIRSTNAME.value_counts().head(20)
# Out:
# JOSE           4676
# MICHAEL        3264
# DAVID          3053
# JUAN           2739
# JAMES          2513
# ROBERT         2164
# JOHN           2155
# CHRISTOPHER    1905
# DANIEL         1888
# LUIS           1543
# JESUS          1458
# WILLIAM        1447
# CARLOS         1317
# RICHARD        1274
# JOSHUA         1166
# JASON          1152
# JORGE          1129
# JOSEPH         1058
# MARK           1014
# MIGUEL          984
# Name: FIRSTNAME, dtype: int64

# %% [markdown]
# ## 28. Can we be any more obnoxious in this assignment?
#
# Not only are we going to detect gender from first names, but we're also going to use a library that has the terrible name of [sex machine](https://github.com/ferhatelmas/sexmachine/). Once upon a time there was Ruby package named sex machine and everyone was like "come on are you six years old? is this how we do things?" and the guy was like "you're completely right I'm renaming it to [gender detector](https://github.com/bmuller/gender_detector)" and the world was Nice and Good again. Apparently Python didn't get the message.
#
# Except actually sexmachine doesn't work on Python 3 because it's from 300 BC so we're going to use a Python 3 fork called [gender guesser](https://pypi.python.org/pypi/gender-guesser/) (hooray!).
#
# #### Use `pip` or `pip3` to install gender-guesser.

# %%
# !pip install gender-guesser
# Out:
# Requirement already satisfied: gender-guesser in /Users/aseemshukla/.pyenv/versions/3.7.1/lib/python3.7/site-packages (0.4.0)

# %% [markdown]
# #### Test to see that it works

# %%
import gender_guesser.detector as gender

detector = gender.Detector(case_sensitive=False)
detector.get_gender('David')
# Out:
# 'male'

# %%
detector.get_gender('Jose')
# Out:
# 'male'

# %%
detector.get_gender('Maria')
# Out:
# 'female'

# %% [markdown]
# #### Use it on a dataframe
#
# To use something fancy like that on a dataframe, you use `.apply`. Check it out:

# %%
df['FIRSTNAME'].fillna('').apply(lambda name: detector.get_gender(name)).head()
# Out:
# 0       male
# 1       male
# 2       male
# 3    unknown
# 4       male
# Name: FIRSTNAME, dtype: object

# %% [markdown]
# ## 29. Calculate the gender of everyone's first name and save it to a column
#
# Confirm by see how many people of each gender we have

# %%
df['GENDER'] = df['FIRSTNAME'].fillna('').apply(lambda name: detector.get_gender(name))

# %%
df.GENDER.value_counts()
# Out:
# male             208826
# unknown          169859
# female           145492
# mostly_female     33024
# mostly_male       24038
# andy              16577
# Name: GENDER, dtype: int64

# %% [markdown]
# ## 30. We like taking risks - get rid of ambiguity
#
# * Combine the `mostly_female` into `female`
# * Combine the `mostly_male` into `male`
# * Replace `andy` (androgynous) and `unknown` with `NaN`
#
# you can get NaN not by making a string, but with `import numpy as np` and then using `np.nan`.

# %%
import numpy as np

df['GENDER'] = df.GENDER.replace({
    'mostly_female' : 'female',
    'mostly_male' : 'male',
    'andy' : np.nan,
    'unknown' : np.nan
})

# %% [markdown]
# ## 31. Do men or women have more licenses? What is the percentage of unknown genders?

# %%
df.GENDER.value_counts()
# Out:
# male      232864
# female    178516
# Name: GENDER, dtype: int64

# %%
df.GENDER.value_counts(normalize=True,dropna=False)
# Out:
# male      0.389525
# NaN       0.311862
# female    0.298614
# Name: GENDER, dtype: float64

# %% [markdown]
# ## 32. What are the popular unknown- or ambiguous gender first names?
#
# Yours might be different! Mine is a combination of actual ambiguity, cultural bias and dirty data.

# %%
df[df.GENDER.isna()].FIRSTNAME.value_counts().head(20)
# Out:
# THANH        985
# DUNG         807
# TRANG        771
# INC          715
# LINH         667
# HONG         625
# LAN          611
# LLC          608
# HUNG         473
# YEN          456
# HANG         442
# CHAU         389
# HAI          348
# CASEY        340
# TUYEN        300
# CHI          295
# MARIA DEL    294
# THUY THI     289
# BINH         277
# INC.         270
# Name: FIRSTNAME, dtype: int64

# %% [markdown]
# ## 31. What are the most popular licenses for men? For women?

# %%
df[df.GENDER=='male'].LICTYPE.value_counts().head(10)
# Out:
# Apprentice Electrician                      86648
# Journeyman Electrician                      32258
# A/C Technician                              22538
# Master Electrician                          14302
# Cosmetology Operator                        12945
# Cosmetology Manicurist                       9528
# Barber, Class A                              9236
# Tow Truck Operator (Incident Management)     6169
# Tow Truck Operator (Consent Tow)             5234
# Legal Service Contract Sales Rep             5110
# Name: LICTYPE, dtype: int64

# %%
df[df.GENDER=='female'].LICTYPE.value_counts().head(10)
# Out:
# Cosmetology Operator                111573
# Cosmetology Manicurist               19199
# Cosmetology Esthetician              15562
# Apprentice Electrician                4625
# Legal Service Contract Sales Rep      4397
# Cosmetology Operator Instructor       4326
# Barber, Class A                       4036
# Cosmetologist                         3570
# VSF Employee                          1751
# Property Tax Appraiser                1172
# Name: LICTYPE, dtype: int64

# %% [markdown]
# ## 32. What is the gender breakdown for Property Tax Appraiser? How about anything involving Tow Trucks?
#
# If you're in need, remember your good friend `.fillna(False)` to get rid of NaN values.

# %%
df[df.LICTYPE=='Property Tax Appraiser'].GENDER.value_counts(normalize=True,dropna=False)
# Out:
# male      0.488053
# female    0.411806
# NaN       0.100141
# Name: GENDER, dtype: float64

# %%
df[df.LICTYPE.str.contains("Tow Truck",na=False)].GENDER.value_counts(normalize=True,dropna=False)
# Out:
# male      0.785207
# NaN       0.173283
# female    0.041510
# Name: GENDER, dtype: float64

# %% [markdown]
# (By the way, what are those tow truck jobs?)

# %%
df[df.LICTYPE.str.contains("Tow Truck",na=False)].LICTYPE.value_counts()
# Out:
# Tow Truck Operator (Incident Management)    7804
# Tow Truck Operator (Consent Tow)            6703
# Tow Truck Operator (Private Property)        352
# Tow Truck Operator Trainee                    53
# Name: LICTYPE, dtype: int64

# %% [markdown]
# ## 33. Graph them!
#
# And let's **give them titles** so we know which is which.

# %%
df[df.LICTYPE.str.contains("Tow Truck",na=False)].LICTYPE.value_counts().sort_values().plot(kind='barh')

# %% [markdown]
# ## 34. Calcuate the gender bias for profession
#
# I spent like an hour on this and then realized a super easy way to do it. Welcome to programming! I'll do this part for you.

# %%
# So when you do .value_counts(), it gives you an index and a value
df[df['GENDER'] == 'male'].LICTYPE.value_counts().head()
# Out:
# Apprentice Electrician    86648
# Journeyman Electrician    32258
# A/C Technician            22538
# Master Electrician        14302
# Cosmetology Operator      12945
# Name: LICTYPE, dtype: int64

# %% [markdown]
# We did `pd.concat` to combine dataframes, but you can also use it to combine series (like the results of `value_counts()`). If you give it a few `value_counts()` and give it some column names it'll make something real nice.

# %%
# All of the values_counts() we will be combining
vc_series = [
    df[df['GENDER'] == 'male'].LICTYPE.value_counts(),
    df[df['GENDER'] == 'female'].LICTYPE.value_counts(),
    df[df['GENDER'].isnull()].LICTYPE.value_counts()
]
# You need axis=1 so it combines them as columns
gender_df = pd.concat(vc_series, axis=1)
gender_df.head()
# Out:
# /Users/aseemshukla/.pyenv/versions/3.7.1/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#                                    LICTYPE  LICTYPE  LICTYPE
# A/C CE Provider                        NaN      NaN     56.0
# A/C Contractor                         NaN      NaN  16376.0
# A/C Technician                     22538.0    841.0   4580.0
# Appliance Installation Contractor      NaN      NaN    668.0
# Appliance Installer                 1636.0     61.0    263.0

# %%
# Turn "A/C Contractor" etc into an actual column instead of an index
gender_df.reset_index(inplace=True)
gender_df.head()
# Out:
#                                index  LICTYPE  LICTYPE  LICTYPE
# 0                    A/C CE Provider      NaN      NaN     56.0
# 1                     A/C Contractor      NaN      NaN  16376.0
# 2                     A/C Technician  22538.0    841.0   4580.0
# 3  Appliance Installation Contractor      NaN      NaN    668.0
# 4                Appliance Installer   1636.0     61.0    263.0

# %%
# Rename the columns appropriately
gender_df.columns = ["license", "male", "female", "unknown"]
# Clean up the NaN by replacing them with zeroes
gender_df.fillna(0, inplace=True)
gender_df.head()
# Out:
#                              license     male  female  unknown
# 0                    A/C CE Provider      0.0     0.0     56.0
# 1                     A/C Contractor      0.0     0.0  16376.0
# 2                     A/C Technician  22538.0   841.0   4580.0
# 3  Appliance Installation Contractor      0.0     0.0    668.0
# 4                Appliance Installer   1636.0    61.0    263.0

# %% [markdown]
# ## 35. Add new columns for total licenses, percent known (not percent unknown!), percent male (of known), percent female (of known)
#
# And replace any `NaN`s with `0`.

# %%
gender_df['total_licenses'] = ((gender_df['male'] + gender_df['female'] + gender_df['unknown'])).fillna(0)
gender_df['pct_known'] = (((gender_df['male'] + gender_df['female']) / gender_df['total_licenses']) * 100).fillna(0)
gender_df['pct_male_of_known'] = ((gender_df['male'] / gender_df['total_licenses']) * 100).fillna(0)
gender_df['pct_female_of_known'] = ((gender_df['female'] / gender_df['total_licenses']) * 100).fillna(0)

# %% [markdown]
# ## 35. What 10 licenses with more than 2,000 people and over 75% known has the most male owners? The most female?

# %%
gender_df[(gender_df['total_licenses']>2000)&(gender_df['pct_known']>75)].sort_values(by='pct_male_of_known',ascending=False).head(10)
# Out:
#                                      license     male  female  unknown  \
# 68                        Master Electrician  14302.0   374.0   2134.0
# 60                    Journeyman Electrician  32258.0   983.0   4929.0
# 2                             A/C Technician  22538.0   841.0   4580.0
# 94  Tow Truck Operator (Incident Management)   6169.0   331.0   1304.0
# 52     Dual Towing Operator(IM)/VSF Employee   3294.0   264.0    615.0
# 5                     Apprentice Electrician  86648.0  4625.0  19320.0
# 93          Tow Truck Operator (Consent Tow)   5234.0   268.0   1201.0
# 6                Apprentice Sign Electrician   3015.0   168.0    811.0
# 8                                 Auctioneer   1788.0   308.0    284.0
# 98         Used Auto Parts Recycler Employee   1709.0   430.0    370.0
#
#     total_licenses  pct_known  pct_male_of_known  pct_female_of_known
# 68         16810.0  87.305175          85.080309             2.224866
# 60         38170.0  87.086717          84.511396             2.575321
# 2          27959.0  83.618870          80.610895             3.007976
# 94          7804.0  83.290620          79.049206             4.241415
# 52          4173.0  85.262401          78.936017             6.326384
# 5         110593.0  82.530540          78.348539             4.182001
# 93          6703.0  82.082650          78.084440             3.998210
# 6           3994.0  79.694542          75.488232             4.206309
# 8           2380.0  88.067227          75.126050            12.941176
# 98          2509.0  85.253089          68.114787            17.138302

# %%
gender_df[(gender_df['total_licenses']>2000)&(gender_df['pct_known']>75)].sort_values(by='pct_female_of_known',ascending=False).head(10)
# Out:
#                                      license     male    female  unknown  \
# 42           Cosmetology Operator Instructor    524.0    4326.0    895.0
# 41                      Cosmetology Operator  12945.0  111573.0  26688.0
# 99                              VSF Employee   1280.0    1751.0    459.0
# 79                    Property Tax Appraiser   1389.0    1172.0    285.0
# 64          Legal Service Contract Sales Rep   5110.0    4397.0   1929.0
# 21                           Barber, Class A   9236.0    4036.0   2747.0
# 98         Used Auto Parts Recycler Employee   1709.0     430.0    370.0
# 8                                 Auctioneer   1788.0     308.0    284.0
# 52     Dual Towing Operator(IM)/VSF Employee   3294.0     264.0    615.0
# 94  Tow Truck Operator (Incident Management)   6169.0     331.0   1304.0
#
#     total_licenses  pct_known  pct_male_of_known  pct_female_of_known
# 42          5745.0  84.421236           9.120975            75.300261
# 41        151206.0  82.349907           8.561168            73.788739
# 99          3490.0  86.848138          36.676218            50.171920
# 79          2846.0  89.985945          48.805341            41.180604
# 64         11436.0  83.132214          44.683456            38.448758
# 21         16019.0  82.851614          57.656533            25.195081
# 98          2509.0  85.253089          68.114787            17.138302
# 8           2380.0  88.067227          75.126050            12.941176
# 52          4173.0  85.262401          78.936017             6.326384
# 94          7804.0  83.290620          79.049206             4.241415

# %% [markdown]
# ## 36. Let's say you have to call a few people about being in a profession dominated by the other gender. What are their phone numbers?
#
# This will involve doing some research in one dataframe, then the other one. I didn't put an answer here because I'm interested in what you come up with!

# %%
male_dom = gender_df[(gender_df['total_licenses']>2000)&(gender_df['pct_known']>75)].sort_values(by='pct_male_of_known',ascending=False).head(10).license.to_list()
female_dom = gender_df[(gender_df['total_licenses']>2000)&(gender_df['pct_known']>75)].sort_values(by='pct_female_of_known',ascending=False).head(10).license.to_list()

# %%
df[(df.LICTYPE.isin(male_dom))&(df.TELEPHONE.notna())].TELEPHONE
# Out:
# 47025      9798284713
# 47026      2104887491
# 47027      7133824802
# 47028      9035634950
# 47029      9039462547
# 47030      8325285241
# 47031      7372474738
# 47032      9036392017
# 47033      7134406945
# 47034      4095390843
# 47035      8323098491
# 47036      2543192035
# 47037      8327381356
# 47038      7137214669
# 47039      7133920280
# 47040      7138225726
# 47041      7132691041
# 47042      9032276918
# 47043      9796658700
# 47044      7136762352
# 47045      4097399612
# 47046      5124702626
# 47047      2819102908
# 47048      8328530763
# 47049      3462080924
# 47050      8325972890
# 47051      8323509473
# 47052      8327369000
# 47053      8327381356
# 47054      7139722948
#              ...
# 569539     7372028067
# 569540     2145361782
# 569541     4692164741
# 569542     9565591718
# 569543     4094975341
# 569544     8173746117
# 569545     3047779007
# 569546     4237656317
# 569547     9408674318
# 569548     4093133718
# 588895     2819316161
# 588922     2102540272
# 589029     3256468254
# 589329     4097703350
# 589379     2818201333
# 589740     2106800300
# 590266    9.03567e+09
# 590541      9.563e+09
# 590613    9.56533e+09
# 590622    7.13692e+09
# 590625     7.1396e+09
# 590626    8.32298e+09
# 590640    9.36257e+09
# 590646    2.81448e+09
# 590894    7.13695e+09
# 590981    9.15859e+09
# 591174    9.79778e+09
# 591199    2.81793e+09
# 591343    5.12903e+09
# 591749    9.03495e+09
# Name: TELEPHONE, Length: 171658, dtype: object

# %%
df[(df.LICTYPE.isin(female_dom))&(df.TELEPHONE.notna())].TELEPHONE
# Out:
# 157618     8174731060
# 157619     9406827360
# 157620     2143301800
# 157621     2546625571
# 157622     9127431511
# 157623     9368972828
# 157624     2814936386
# 157625     4056583434
# 157626     4053355732
# 157627     9724753724
# 157628     2103448300
# 157629     5123853126
# 157630     9728248677
# 157631     2106965256
# 157632     9036404135
# 157633     8308335449
# 157634     8173469030
# 157635     9722438899
# 157636     8063642250
# 157637     3613625863
# 157638     8066553900
# 157640     5124820270
# 157641     9727099255
# 157642     2819310100
# 157643     2548532738
# 157644     7134853576
# 157645     3185482903
# 157646     4177762231
# 157647     5802765961
# 157648     8175731534
#              ...
# 588875     5129303787
# 588876     5129303787
# 588877     8067625000
# 588878     2548656593
# 588879     3252473065
# 588880     9795429618
# 588881     9795429618
# 588882     8307413035
# 588883     2146310520
# 588884     5128349317
# 588895     2819316161
# 588922     2102540272
# 589029     3256468254
# 589329     4097703350
# 589379     2818201333
# 589740     2106800300
# 590266    9.03567e+09
# 590541      9.563e+09
# 590613    9.56533e+09
# 590622    7.13692e+09
# 590625     7.1396e+09
# 590626    8.32298e+09
# 590640    9.36257e+09
# 590646    2.81448e+09
# 590894    7.13695e+09
# 590981    9.15859e+09
# 591174    9.79778e+09
# 591199    2.81793e+09
# 591343    5.12903e+09
# 591749    9.03495e+09
# Name: TELEPHONE, Length: 188686, dtype: object

# %% [markdown]
# ## PART FIVE: Violations
#
# ### 37. Read in **violations.csv** as `violations_df`, make sure it looks right

# %%
violations_df = pd.read_csv('violations.csv')

# %%
violations_df.dtypes
# Out:
# basis          object
# city           object
# complaintno    object
# county         object
# licenseno      object
# name           object
# order          object
# orderDate      object
# zipcode         int64
# dtype: object

# %%
violations_df.shape
# Out:
# (115, 9)

# %% [markdown]
# ### 38. Combine with your original licenses dataset dataframe to get phone numbers and addresses for each violation. Check that it is 90 rows, 28 columns.

# %%
df_lics = df.LICNUMBER.astype(str).to_list()
vi_lics = violations_df.licenseno.astype(str).to_list()

len(list(set(df_lics) & set(vi_lics)))
# Out:
# 87

# %%
df['LICNUMBER'] = df.LICNUMBER.astype(str)
violations_df['licenseno'] = violations_df.licenseno.astype(str)
merged = violations_df.merge(df,right_on='LICNUMBER',left_on='licenseno')

# %%
merged.shape
# Out:
# (90, 31)

# %% [markdown]
# ## 39. Find each violation involving a failure with records. Use a regular expression.

# %%
merged[merged['basis'].str.contains('fail.*record')]
# Out:
#                                                 basis      city  \
# 0   Respondent failed to keep a record of the date...   HOUSTON
# 1   Respondent failed to keep a record of the date...   HOUSTON
# 3   Respondent failed to maintain the required cle...   HOUSTON
# 4   Respondent failed to keep a record of the date...   HOUSTON
# 6   Respondent failed to keep a record of the date...      KATY
# 7   Respondent failed to keep a record of the date...    HUMBLE
# 8   Respondent failed to keep a record of the date...   HOUSTON
# 10  Respondent failed to dispose of single use ite...   HOUSTON
# 14  Respondent failed to keep a record of the date...   HOUSTON
# 17  Respondent failed to keep a record of the date...    SPRING
# 18  Respondent failed to keep a record of the date...   HOUSTON
# 19  Respondent failed to keep a record of the date...      KATY
# 20  Respondent failed to keep a record of the date...   CYPRESS
# 21  Respondent failed to keep a record of the date...   HOUSTON
# 23  Respondent failed to clean diamond, carbide, n...   CYPRESS
# 24  Respondent failed to keep a record of the date...   HOUSTON
# 25  Respondent failed to wash towels in hot water ...   HOUSTON
# 28  Respondent failed to follow whirlpool foot spa...   HOUSTON
# 29  Respondent failed to keep a record of the date...   HOUSTON
# 31  Respondent failed to keep a record of the date...   TOMBALL
# 32  Respondent failed to keep a record of the date...  LA PORTE
# 33  Respondent failed to keep a record of the date...   HOUSTON
# 35  Respondent failed to keep a record of the date...   HOUSTON
# 36  Respondent failed to keep a record of the date...   TOMBALL
# 37  Respondent failed to clean and sanitize whirlp...    SPRING
# 40  Respondent failed to keep a record of the date...  PASADENA
# 43  Respondent failed to keep a record of the date...   HOUSTON
# 45  Respondent failed to keep a record of the date...   HOUSTON
# 46  Respondent failed to wash towels in hot water ...   HOUSTON
# 47  Respondent failed to keep a record of the date...   HOUSTON
# 48  Respondent failed to make records, on a depart...   HOUSTON
# 49  Respondent failed to keep a record of the date...    HUMBLE
# 50  Respondent failed to make cleaning and disinfe...   HOUSTON
# 51  Respondent leased space in a salon to multiple...   HOUSTON
# 52  Respondent failed to keep a record of the date...   HOUSTON
# 53  Respondent failed to clean diamond, carbide, n...   HOUSTON
# 56  Respondent failed to keep a record of the date...   HOUSTON
# 57  Respondent operated a cosmetology salon with a...   HOUSTON
# 58  Respondent failed to make records, on a depart...   HOUSTON
# 61  Respondent failed to clean and disinfect all w...    SPRING
# 62  Respondent operated a cosmetology salon with a...   HOUSTON
# 68  Respondent failed to keep a record of the date...    SPRING
# 69  Respondent failed to keep a record of the date...   HOUSTON
# 73  Respondent failed to clean and sanitize whirlp...   HOUSTON
# 75  Respondent leased space in a salon to an indiv...   HOUSTON
# 76  Respondent failed to keep a record of the date...   HOUSTON
# 80  Respondent failed to keep a record of the date...   HOUSTON
# 82  Respondent failed to keep a record of the date...   HOUSTON
# 84  Respondent failed to keep a record of the date...   HOUSTON
# 88  Respondent failed to keep a record of the date...   HOUSTON
# 89  Respondent failed to clean, disinfect, and ste...   HOUSTON
#
#        complaintno  county licenseno                      name  \
# 0   COS20160024894  HARRIS    748459          NGUYEN, PHUONG T
# 1   COS20170004646  HARRIS    742837        NGUYEN, SUYEN THI
# 3   COS20170007996  HARRIS    729680         NGUYEN, XUONG MY
# 4   COS20170003822  HARRIS    688518      NGUYEN, NHUNG TUYET
# 6   COS20160026587  HARRIS    747353       NGUYEN, LEDAI NGOC
# 7   COS20170000591  HARRIS    742122              NGUYEN, NGA
# 8   COS20160024172  HARRIS    756241           NGUYEN, IVANNA
# 10  COS20160022958  HARRIS    711110          NGUYEN, DUC THI
# 14  COS20160023083  HARRIS    743934           NGUYEN, CHANH V
# 17  COS20160021148  HARRIS    748989          NGUYEN, TRUONG V
# 18  COS20160019227  HARRIS    741533             NGUYEN, HUNG
# 19  COS20160006471  HARRIS    727442   NGUYEN, JULIE LUU ANH H
# 20  COS20160019355  HARRIS    761084          NGUYEN, THU THI
# 21  COS20160021024  HARRIS    760672    NGUYEN, ANH TRAM PHAM
# 23  COS20160018772  HARRIS    746604             NGUYEN, TOM T
# 24  COS20160011021  HARRIS    745638              NGUYEN, HAI
# 25  COS20160007894  HARRIS    679282            NGUYEN, LIEN T
# 28  COS20160010390  HARRIS    746451      NGUYEN, THANH DUONG
# 29  COS20160011922  HARRIS    743952           NGUYEN, MY THI
# 31  COS20160012011  HARRIS    745664             NGUYEN, HAU V
# 32  COS20160012089  HARRIS    741785            NGUYEN, TRAM B
# 33  COS20160004267  HARRIS    678516         NGUYEN, DIET THI
# 35  COS20160007763  HARRIS    740590          NGUYEN, YEN THI
# 36  COS20160008123  HARRIS    739716  NGUYEN, KENNEDY DANG KH
# 37  COS20160007323  HARRIS    723469     NGUYEN, XUAN LAN THI
# 40  COS20160005971  HARRIS    750887           NGUYEN, CY VAN
# 43  COS20150011681  HARRIS    685660           NGUYEN, LE THI
# 45  COS20150023722  HARRIS    751033  NGUYEN, MINH PHUONG THI
# 46  COS20150015433  HARRIS    734013            NGUYEN, JOHN H
# 47  COS20150021335  HARRIS    749505            NGUYEN, TRACY
# 48  COS20150023047  HARRIS    758213            NGUYEN, CHINH
# 49  COS20140015066  HARRIS    682850             NGUYEN, DUNG
# 50  COS20150017977  HARRIS    750542     NGUYEN, NGOC THI KIM
# 51  COS20150019662  HARRIS    756072         NGUYEN, HONG ANH
# 52  COS20150004749  HARRIS    729124        NGUYEN, PHUNG THI
# 53  COS20150011167  HARRIS    668738             NGUYEN, THU T
# 56  COS20150020881  HARRIS    737066          NGUYEN, THI LAN
# 57  COS20150012248  HARRIS    694585     NGUYEN-PHAM, CHI KIM
# 58  COS20150014950  HARRIS    716042         NGUYEN, HANG THU
# 61  COS20150011465  HARRIS    749719          NGUYEN, LE UYEN
# 62  COS20150010173  HARRIS    752114   NGUYEN, JENNY YEN BACH
# 68  COS20140001311  HARRIS    729511   NGUYEN, HANNAH MY HANH
# 69  COS20130021724  HARRIS    746184           NGUYEN, THANH T
# 73  COS20130018039  HARRIS    694394        NGUYEN, CHAU MINH
# 75  COS20150004764  HARRIS    729985  NGUYEN, TIFFANY THOM TH
# 76  COS20140018205  HARRIS    739743       NGUYEN, KIM AN THI
# 80  COS20140001207  HARRIS    718098            NGUYEN, JAMES
# 82  COS20140008556  HARRIS    714450             NGUYEN, TUY T
# 84  COS20140015709  HARRIS    724124            NGUYEN, LIEM T
# 88  COS20130020057  HARRIS    743316         NGUYEN, HANG THI
# 89  COS20140013051  HARRIS   1439723            NGUYEN, MINH V
#
#                                                 order   orderDate  zipcode  \
# 0   Respondent is assessed an administrative penal...   3/21/2017    77083
# 1   Respondent is assessed an administrative penal...   3/21/2017    77072
# 3   Respondent is assessed an administrative penal...   3/21/2017    77066
# 4   Respondent is assessed an administrative penal...    3/8/2017    77083
# 6   Respondent is assessed an administrative penal...   1/11/2017    77494
# 7   Respondent is assessed an administrative penal...   1/11/2017    77346
# 8   Respondent is assessed an administrative penal...  11/30/2016    77099
# 10  Respondent is assessed an administrative penal...   10/3/2016    77084
# 14  Respondent is assessed an administrative penal...   8/29/2016    77088
# 17  Respondent is assessed an administrative penal...   8/24/2016    77388
# 18  Respondent is assessed an administrative penal...   8/15/2016    77099
# 19  Respondent is assessed an administrative penal...   8/11/2016    77450
# 20  Respondent is assessed an administrative penal...   7/27/2016    77429
# 21  Respondent is assessed an administrative penal...   7/27/2016    77083
# 23  Respondent is assessed an administrative penal...    7/5/2016    77429
# 24  Respondent is assessed an administrative penal...   6/22/2016    77016
# 25  Respondent is assessed an administrative penal...    6/1/2016    77099
# 28  Respondent is assessed an administrative penal...   5/18/2016    77064
# 29  Respondent is assessed an administrative penal...   5/18/2016    77016
# 31  Respondent is assessed an administrative penal...    5/2/2016    77377
# 32  Respondent is assessed an administrative penal...   4/26/2016    77571
# 33  Respondent is assessed an administrative penal...   4/11/2016    77083
# 35  Respondent is assessed an administrative penal...   3/28/2016    77034
# 36  Respondent is assessed an administrative penal...   3/28/2016    77377
# 37  Respondent is assessed an administrative penal...   3/15/2016    77373
# 40  Respondent is assessed an administrative penal...   2/16/2016    77505
# 43  Respondent is assessed an administrative penal...   1/26/2016    77083
# 45  Respondent is assessed an administrative penal...   1/14/2016    77083
# 46  Respondent is assessed an administrative penal...   1/11/2016    77084
# 47  Respondent is assessed an administrative penal...   12/3/2015    77083
# 48  Respondent is assessed an administrative penal...   12/1/2015    77095
# 49  Respondent is assessed an administrative penal...  11/18/2015    77396
# 50  Respondent is assessed an administrative penal...  11/16/2015    77066
# 51  Respondent is assessed an administrative penal...  10/14/2015    77065
# 52  Respondent is assessed an administrative penal...  10/13/2015    77064
# 53  Respondent is assessed an administrative penal...    9/8/2015    77064
# 56  Respondent is assessed an administrative penal...   8/26/2015    77009
# 57  Respondent is assessed an administrative penal...   8/12/2015    77066
# 58  Respondent is assessed an administrative penal...   7/29/2015    77084
# 61  Respondent is assessed an administrative penal...   7/17/2015    77379
# 62  Respondent is assessed an administrative penal...   7/13/2015    77064
# 68  Respondent is assessed an administrative penal...   5/28/2015    77388
# 69  Respondent is assessed an administrative penal...   5/26/2015    77065
# 73  Respondent is assessed an administrative penal...   3/27/2015    77021
# 75  Respondent is assessed an administrative penal...   3/19/2015    77041
# 76  Respondent is assessed an administrative penal...   2/26/2015    77022
# 80  Respondent is assessed an administrative penal...   11/6/2014    77034
# 82  Respondent is assessed an administrative penal...  10/29/2014    77072
# 84  Respondent is assessed an administrative penal...   9/29/2014    77028
# 88  Respondent is assessed an administrative penal...    9/8/2014    77021
# 89  Respondent is assessed an administrative penal...   8/12/2014    77064
#
#                                    LICTYPE  ...           MAILCITYSTATE  \
# 0   Cosmetology Esthetician/Manicure Salon  ...        HOUSTON TX 77031
# 1   Cosmetology Esthetician/Manicure Salon  ...       PEARLAND TX 77584
# 3   Cosmetology Esthetician/Manicure Salon  ...         HUMBLE TX 77346
# 4                 Cosmetology Beauty Salon  ...        HOUSTON TX 77083
# 6   Cosmetology Esthetician/Manicure Salon  ...           KATY TX 77494
# 7   Cosmetology Esthetician/Manicure Salon  ...         HUMBLE TX 77346
# 8   Cosmetology Esthetician/Manicure Salon  ...        HOUSTON TX 77099
# 10  Cosmetology Esthetician/Manicure Salon  ...        HOUSTON TX 77084
# 14  Cosmetology Esthetician/Manicure Salon  ...        HOUSTON TX 77088
# 17                Cosmetology Beauty Salon  ...         SPRING TX 77388
# 18  Cosmetology Esthetician/Manicure Salon  ...       ONALASKA TX 77360
# 19  Cosmetology Esthetician/Manicure Salon  ...      KATY TX 77450-3075
# 20  Cosmetology Esthetician/Manicure Salon  ...        CYPRESS TX 77429
# 21  Cosmetology Esthetician/Manicure Salon  ...           KATY TX 77449
# 23              Cosmetology Manicure Salon  ...         SPRING TX 77389
# 24  Cosmetology Esthetician/Manicure Salon  ...        HOUSTON TX 77016
# 25  Cosmetology Esthetician/Manicure Salon  ...      SOUTHLAKE TX 76092
# 28  Cosmetology Esthetician/Manicure Salon  ...        TOMBALL TX 77375
# 29                Cosmetology Beauty Salon  ...        HOUSTON TX 77067
# 31                Cosmetology Beauty Salon  ...   TOMBALL TX 77377-8273
# 32  Cosmetology Esthetician/Manicure Salon  ...       LA PORTE TX 77571
# 33                Cosmetology Beauty Salon  ...   HOUSTON TX 77072-5130
# 35              Cosmetology Manicure Salon  ...         KENEDY TX 78119
# 36  Cosmetology Esthetician/Manicure Salon  ...        TOMBALL TX 77375
# 37  Cosmetology Esthetician/Manicure Salon  ...         SPRING TX 77373
# 40  Cosmetology Esthetician/Manicure Salon  ...       PASADENA TX 77505
# 43  Cosmetology Esthetician/Manicure Salon  ...        HOUSTON TX 77054
# 45  Cosmetology Esthetician/Manicure Salon  ...       MISSOURI TX 77459
# 46  Cosmetology Esthetician/Manicure Salon  ...         WALLER TX 77484
# 47  Cosmetology Esthetician/Manicure Salon  ...        HOUSTON TX 77027
# 48  Cosmetology Esthetician/Manicure Salon  ...       RICHMOND TX 77407
# 49  Cosmetology Esthetician/Manicure Salon  ...        HOUSTON TX 77044
# 50  Cosmetology Esthetician/Manicure Salon  ...         SPRING TX 77379
# 51  Cosmetology Esthetician/Manicure Salon  ...        HOUSTON TX 77014
# 52  Cosmetology Esthetician/Manicure Salon  ...        HOUSTON TX 77086
# 53  Cosmetology Esthetician/Manicure Salon  ...        HOUSTON TX 77088
# 56  Cosmetology Esthetician/Manicure Salon  ...   HOUSTON TX 77009-3212
# 57                Cosmetology Beauty Salon  ...         SPRING TX 77373
# 58  Cosmetology Esthetician/Manicure Salon  ...        HOUSTON TX 77084
# 61  Cosmetology Esthetician/Manicure Salon  ...         SPRING TX 77379
# 62              Cosmetology Manicure Salon  ...   CYPRESS TX 77429-2786
# 68  Cosmetology Esthetician/Manicure Salon  ...         SPRING TX 77386
# 69  Cosmetology Esthetician/Manicure Salon  ...  THE WOODLANDS TX 77380
# 73              Cosmetology Manicure Salon  ...        HOUSTON TX 77021
# 75  Cosmetology Esthetician/Manicure Salon  ...        HOUSTON TX 77077
# 76  Cosmetology Esthetician/Manicure Salon  ...        HOUSTON TX 77022
# 80  Cosmetology Esthetician/Manicure Salon  ...        HOUSTON TX 77015
# 82  Cosmetology Esthetician/Manicure Salon  ...        HOUSTON TX 77023
# 84  Cosmetology Esthetician/Manicure Salon  ...        HOUSTON TX 77059
# 88  Cosmetology Esthetician/Manicure Salon  ...        HOUSTON TX 77021
# 89                  Cosmetology Manicurist  ...   HOUSTON TX 77017-5817
#
#    MAILCOUNTYCODE  MAILCOUNTY  MAILZIP    TELEPHONE  LICSUBTYPE CEFLAG  \
# 0            0201      HARRIS    77031   7132701521          FM      N
# 1            0039    BRAZORIA    77584   8325337866          FM      N
# 3            0201      HARRIS    77346   2818525330          FM      N
# 4            0201      HARRIS    77083   2814956262          CS      N
# 6            0157   FORT BEND    77494   2816937777          FM      N
# 7            0201      HARRIS    77346   2818122269          FM      N
# 8            0201      HARRIS    77099   2815758181          FM      N
# 10           0201      HARRIS    77084   2818557033          FM      N
# 14           0201      HARRIS    77088   2814476950          FM      N
# 17           0201      HARRIS    77388   2815285801          CS      N
# 18           0373        POLK    77360   9369339444          FM      N
# 19           0201      HARRIS    77450   4086468192          FM      N
# 20           0201      HARRIS    77429   2812560577          FM      N
# 21           0201      HARRIS    77449   8326834318          FM      N
# 23           0201      HARRIS    77389   8326061093          MS      N
# 24           0201      HARRIS    77016   8322353873          FM      N
# 25           0439     TARRANT    76092   8174165300          FM      N
# 28           0201      HARRIS    77375   8324344781          FM      N
# 29           0201      HARRIS    77067   7138940051          CS      N
# 31           0201      HARRIS    77377   2814607150          CS      N
# 32           0201      HARRIS    77571   2814702211          FM      N
# 33           0201      HARRIS    77072   2814959244          CS      N
# 35           0255      KARNES    78119   7132988788          MS      N
# 36           0201      HARRIS    77375   8322025889          FM      N
# 37           0201      HARRIS    77373   2813555595          FM      N
# 40           0201      HARRIS    77505   2819981000          FM      N
# 43           0201      HARRIS    77054   7137954008          FM      N
# 45           0157   FORT BEND    77459   2814039600          FM      N
# 46           0473      WALLER    77484   7138979795          FM      N
# 47           0201      HARRIS    77027   2818270807          FM      N
# 48           0157   FORT BEND    77407   2812409442          FM      N
# 49           0201      HARRIS    77044   2812254535          FM      N
# 50           0201      HARRIS    77379   2816558815          FM      N
# 51           0201      HARRIS    77014   2815375051          FM      N
# 52           0201      HARRIS    77086   2818473596          FM      N
# 53           0201      HARRIS    77088   2814050607          FM      N
# 56           0201      HARRIS    77009   7136942745          FM      N
# 57           0201      HARRIS    77373   2814433372          CS      N
# 58           0201      HARRIS    77084   2818557788          FM      N
# 61           0201      HARRIS    77379   2812880906          FM      N
# 62           0201      HARRIS    77429   2812579995          MS      N
# 68           0339  MONTGOMERY    77386   2818772478          FM      N
# 69           0339  MONTGOMERY    77380   2818944111          FM      N
# 73           0201      HARRIS    77021   8326050860          MS      N
# 75           0201      HARRIS    77077   2814934229          FM      N
# 76           0201      HARRIS    77022   7136917221          FM      N
# 80           0201      HARRIS    77015   7134513800          FM      N
# 82           0201      HARRIS    77023   7139262334          FM      N
# 84           0201      HARRIS    77059   2819981053          FM      N
# 88           0201      HARRIS    77021   7137477705          FM      N
# 89           0201      HARRIS    77017  7.13459e+09          MA      N
#
#    LASTNAME FIRSTNAME  GENDER
# 0       NaN       NaN     NaN
# 1       NaN       NaN     NaN
# 3       NaN       NaN     NaN
# 4       NaN       NaN     NaN
# 6       NaN       NaN     NaN
# 7       NaN       NaN     NaN
# 8       NaN       NaN     NaN
# 10      NaN       NaN     NaN
# 14      NaN       NaN     NaN
# 17      NaN       NaN     NaN
# 18      NaN       NaN     NaN
# 19      NaN       NaN     NaN
# 20      NaN       NaN     NaN
# 21      NaN       NaN     NaN
# 23      NaN       NaN     NaN
# 24      NaN       NaN     NaN
# 25      NaN       NaN     NaN
# 28      NaN       NaN     NaN
# 29      NaN       NaN     NaN
# 31      NaN       NaN     NaN
# 32      NaN       NaN     NaN
# 33      NaN       NaN     NaN
# 35      NaN       NaN     NaN
# 36      NaN       NaN     NaN
# 37      NaN       NaN     NaN
# 40      NaN       NaN     NaN
# 43      NaN       NaN     NaN
# 45      NaN       NaN     NaN
# 46      NaN       NaN     NaN
# 47      NaN       NaN     NaN
# 48      NaN       NaN     NaN
# 49      NaN       NaN     NaN
# 50      NaN       NaN     NaN
# 51      NaN       NaN     NaN
# 52      NaN       NaN     NaN
# 53      NaN       NaN     NaN
# 56      NaN       NaN     NaN
# 57      NaN       NaN     NaN
# 58      NaN       NaN     NaN
# 61      NaN       NaN     NaN
# 62      NaN       NaN     NaN
# 68      NaN       NaN     NaN
# 69      NaN       NaN     NaN
# 73      NaN       NaN     NaN
# 75      NaN       NaN     NaN
# 76      NaN       NaN     NaN
# 80      NaN       NaN     NaN
# 82      NaN       NaN     NaN
# 84      NaN       NaN     NaN
# 88      NaN       NaN     NaN
# 89   NGUYEN      MINH  female
#
# [51 rows x 31 columns]

# %% [markdown]
# ## 40. How much money was each fine? Use a regular expression and .str.extract (we talked about it before!)
#
# Unfortunately large and helpful troubleshooting tip: `$` means "end of a line" in regex, so `.extract` isn't going to accept it as a dollar sign. You need to escape it by using `\$` instead.

# %%
merged['order'].str.extract('(\$.*)\.')
# Out:
#          0
# 0     $300
# 1     $500
# 2     $750
# 3   $1,875
# 4     $375
# 5   $1,800
# 6   $1,125
# 7     $750
# 8     $925
# 9     $575
# 10  $1,000
# 11    $550
# 12    $500
# 13    $750
# 14  $1,125
# 15    $500
# 16    $500
# 17  $1,500
# 18    $375
# 19    $500
# 20    $500
# 21    $750
# 22    $500
# 23  $1,250
# 24    $750
# 25  $1,500
# 26    $400
# 27    $500
# 28  $2,250
# 29    $375
# ..     ...
# 60    $550
# 61    $625
# 62  $1,625
# 63    $375
# 64    $375
# 65    $375
# 66    $500
# 67    $500
# 68    $500
# 69  $1,000
# 70  $1,000
# 71  $2,200
# 72    $875
# 73    $750
# 74    $750
# 75    $750
# 76  $1,000
# 77    $375
# 78    $250
# 79    $225
# 80    $750
# 81    $875
# 82    $750
# 83    $625
# 84  $1,695
# 85    $150
# 86    $575
# 87    $500
# 88  $1,000
# 89  $1,250
#
# [90 rows x 1 columns]

# %% [markdown]
# ## 41. Clean those results (no commas, no dollar signs, and it should be an integer) and save it to a new column called `fine`
#
# `.replace` is for *entire cells*, you're interested in `.str.replace`, which treats each value like a string, not like a... pandas thing.
#
# `.astype(int)` will convert it into an integer for you.

# %%
merged['fine'] = merged['order'].str.extract('\$(.*)\.',expand=False).str.replace(",","").astype(int)

# %% [markdown]
# ## 42. Which orders results in the top fines?

# %%
merged.sort_values(by='fine',ascending=False).head(10)
# Out:
#                                                 basis      city  \
# 40  Respondent failed to keep a record of the date...  PASADENA
# 28  Respondent failed to follow whirlpool foot spa...   HOUSTON
# 71  Respondent failed to disinfect tools, implemen...   HOUSTON
# 3   Respondent failed to maintain the required cle...   HOUSTON
# 5   Respondent failed to disinfect shampoo bowls p...   HOUSTON
# 84  Respondent failed to keep a record of the date...   HOUSTON
# 46  Respondent failed to wash towels in hot water ...   HOUSTON
# 62  Respondent operated a cosmetology salon with a...   HOUSTON
# 32  Respondent failed to keep a record of the date...  LA PORTE
# 17  Respondent failed to keep a record of the date...    SPRING
#
#        complaintno  county licenseno                     name  \
# 40  COS20160005971  HARRIS    750887          NGUYEN, CY VAN
# 28  COS20160010390  HARRIS    746451     NGUYEN, THANH DUONG
# 71  COS20140013768  HARRIS    711709         NGUYEN, LINH CHI
# 3   COS20170007996  HARRIS    729680        NGUYEN, XUONG MY
# 5   COS20160003461  HARRIS    742061  NGUYEN, KIM THUAN-NGOC
# 84  COS20140015709  HARRIS    724124           NGUYEN, LIEM T
# 46  COS20150015433  HARRIS    734013           NGUYEN, JOHN H
# 62  COS20150010173  HARRIS    752114  NGUYEN, JENNY YEN BACH
# 32  COS20160012089  HARRIS    741785           NGUYEN, TRAM B
# 17  COS20160021148  HARRIS    748989         NGUYEN, TRUONG V
#
#                                                 order  orderDate  zipcode  \
# 40  Respondent is assessed an administrative penal...  2/16/2016    77505
# 28  Respondent is assessed an administrative penal...  5/18/2016    77064
# 71  Respondent is assessed an administrative penal...  4/13/2015    77065
# 3   Respondent is assessed an administrative penal...  3/21/2017    77066
# 5   Respondent is assessed an administrative penal...   2/3/2017    77074
# 84  Respondent is assessed an administrative penal...  9/29/2014    77028
# 46  Respondent is assessed an administrative penal...  1/11/2016    77084
# 62  Respondent is assessed an administrative penal...  7/13/2015    77064
# 32  Respondent is assessed an administrative penal...  4/26/2016    77571
# 17  Respondent is assessed an administrative penal...  8/24/2016    77388
#
#                                    LICTYPE  ... MAILCOUNTYCODE MAILCOUNTY  \
# 40  Cosmetology Esthetician/Manicure Salon  ...           0201     HARRIS
# 28  Cosmetology Esthetician/Manicure Salon  ...           0201     HARRIS
# 71  Cosmetology Esthetician/Manicure Salon  ...           0201     HARRIS
# 3   Cosmetology Esthetician/Manicure Salon  ...           0201     HARRIS
# 5                 Cosmetology Beauty Salon  ...           0201     HARRIS
# 84  Cosmetology Esthetician/Manicure Salon  ...           0201     HARRIS
# 46  Cosmetology Esthetician/Manicure Salon  ...           0473     WALLER
# 62              Cosmetology Manicure Salon  ...           0201     HARRIS
# 32  Cosmetology Esthetician/Manicure Salon  ...           0201     HARRIS
# 17                Cosmetology Beauty Salon  ...           0201     HARRIS
#
#    MAILZIP   TELEPHONE  LICSUBTYPE  CEFLAG LASTNAME FIRSTNAME GENDER  fine
# 40   77505  2819981000          FM       N      NaN       NaN    NaN  4000
# 28   77375  8324344781          FM       N      NaN       NaN    NaN  2250
# 71   77090  2818735734          FM       N      NaN       NaN    NaN  2200
# 3    77346  2818525330          FM       N      NaN       NaN    NaN  1875
# 5    77074  8324885863          CS       N      NaN       NaN    NaN  1800
# 84   77059  2819981053          FM       N      NaN       NaN    NaN  1695
# 46   77484  7138979795          FM       N      NaN       NaN    NaN  1650
# 62   77429  2812579995          MS       N      NaN       NaN    NaN  1625
# 32   77571  2814702211          FM       N      NaN       NaN    NaN  1600
# 17   77388  2815285801          CS       N      NaN       NaN    NaN  1500
#
# [10 rows x 32 columns]

# %% [markdown]
# ## 43. Are you still here???
#
# I'm sure impressed.
